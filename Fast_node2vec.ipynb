# %%
#!/usr/bin/env python
# encoding: utf-8
#from scipy.spatial.distance import cdist
from nltk import bigrams
import networkx as nx
#similarity score concat before fc1 
import tldextract
from itertools import combinations
from shutil import which
import torch.nn.functional as F
from statistics import mean


from gensim.models import KeyedVectors
from cleantext import clean
from tqdm import tqdm
from nltk.tokenize import TweetTokenizer
import preprocessor as p 
import numpy as np

import torch
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import LongformerModel, LongformerTokenizer, LongformerConfig
from tqdm import tqdm
tqdm.pandas(desc="my bar!")
import pandas as pd 
import numpy as np 
from collections import defaultdict
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import time
#import wandb
#import numpy as np
from pprint import pprint


from nltk.corpus import stopwords
import preprocessor as p  #pip install tweet-preprocessor
import logging  # Setting up the loggings to monitor gensim
from nltk.stem import WordNetLemmatizer
from string import punctuation as punc

import gensim
import gensim.corpora as corpora
#from gensim.utils import simple_preprocess
import gensim.models as gsm



import emoji #pip install emoji --upgrade
# Internal dependencies


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd
import torchvision.transforms as transforms
from torch.autograd import Variable

import os
import torch.multiprocessing as mp
import torchvision.transforms as transforms


#os.environ['CUDA_VISIBLE_DEVICES'] = '1, 2, 3' 
#....to install apex...
#pip install -v --no-cache-dir ./

#!/usr/bin/env python
# encoding: utf-8
import time
import torch.optim as optim
from torch.utils.data import TensorDataset, random_split
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
#from torchnlp.nn import Attention #pip imstall pytorch-nlp

from gensim.models import KeyedVectors
#from fastnode2vec import Graph, Node2Vec
import pandas as pd
import networkx as nx
import os

from torch.utils.data import TensorDataset, random_split
from cleantext import clean
from tqdm import tqdm
from nltk.tokenize import TweetTokenizer
import preprocessor as p 
import numpy as np
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import LongformerModel, LongformerTokenizer, LongformerConfig
from tqdm import tqdm
tqdm.pandas(desc="my bar!")
import pandas as pd 
import numpy as np 
from collections import defaultdict

from sklearn.model_selection import train_test_split
import datetime
import matplotlib.pyplot as plt
import time
#import numpy as np
from pprint import pprint

from nltk.corpus import stopwords
import preprocessor as p  #pip install tweet-preprocessor
import logging  # Setting up the loggings to monitor gensim
from nltk.stem import WordNetLemmatizer
from string import punctuation as punc

import gensim
import gensim.corpora as corpora
#from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import gensim.models as gsm
from gensim.test.utils import datapath

import regex 
#pip install emoji --upgrade
# Internal dependencies



import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd
import torchvision.transforms as transforms
from torch.autograd import Variable

import os
import torch.multiprocessing as mp
import torchvision.transforms as transforms
import torch.distributed as dist

from urllib.parse import urlparse
import tldextract
from fastnode2vec import Graph, Node2Vec
import tldextract
import networkx as nx
from nltk import bigrams
def makefolder(save):
    if  os.path.exists(save) == False:
        os.makedirs(save)
    else:
        print('Floder:',save,'Exsit!')
    return save
def extract_domain(x):
    '''
    e.g. x='http://www.bbc.co.uk'
    '''
    ext = tldextract.extract(x)
    return ext.registered_domain
def updatecol(df1,df2,colname,index):
    df1[colname]=''

    df1.set_index(index,inplace=True)

    df2.set_index(index,inplace=True)

    df1.update(df2)

    df1.reset_index(inplace=True)
    df2.reset_index(inplace=True)
    return df1
def fast_node2vec(_df):
                '''
                _df:retweetdf,mentiondf
                _save:saving folder path
                _file:csv name, e.g., vaccine, mask
                saving_name: RT or MT
                '''

                _tuples=_df.to_records(index=False)

                _lst=list(_tuples)

                _graph = Graph(_lst, directed=False, weighted=False)

                _n2v = Node2Vec(_graph, dim=300, walk_length=500, context=10, p=2.0, q=0.5, workers=-1)

                _n2v.train(epochs=1000)


                return _n2v
def bihashtagGraph(_lst,_i):
    _i=0
    #terms_bigram = [list(bigrams(tweet)) if len(tweet)>1 else (tweet,'') for tweet in _lst]
    terms_bigram = [list(bigrams(tweet)) for tweet in _lst]

    d=[x for x in terms_bigram if x!=[]]

    lst=[]
    for each in d:
        if len(each)==0:
            lst.append(each)
        else:
            [lst.append(x) for x in each]

    _hadf=pd.DataFrame(lst)

    _K=nx.from_pandas_edgelist(_hadf,0,1)

    nx.write_gexf(_K,'../Project2/'+topic+'/'+str(_i)+'_cooccur.gexf')
    return _K,_hadf
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.manifold import TSNE
import time
import matplotlib.pyplot as plt
# %matplotlib inline

def export_tSNE(_data,save):
    _array = _data.iloc[:,0:300].to_numpy()
    time_start = time.time()
    tsne = TSNE(n_components=2, verbose=1, random_state=42)
    z = tsne.fit_transform(_array) 
    print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

    df = pd.DataFrame()
    df["y"] = _data.labels
    df["comp-1"] = z[:,0]
    df["comp-2"] = z[:,1]

    sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),data=df).set(title=_target.capitalize()+" tSNE projection") 
    plt.savefig('../Project2/'+topic+'/figs/tSNE_'+_target+'_'+save+'_drop_duplicates.pdf')






for topic in ['Ivermectin']:
    file_name=topic
    path = '../Project2/'+topic+'/'
    ranking='random'
    
    batch_size = 16
    which_time = 0
    
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print('Training')
    print('Device:',device)
    N_EPOCHS = 200
    HIDDEN_DIM = 300 
    OUTPUT_DIM = 8000#5000#7000
    N_LAYERS = 3#5
    DROPOUT = 0.0

    for _target in ['domain']:
        

        if topic=='biden':
                ndf=pd.read_csv(path+topic+'_selected.csv')
                print(ndf.shape)
                ndf.dropna(subset=['retweeted_status_screen_name'],inplace=True)
                print(ndf.shape)
                m2=52
                label1='Democratic'
                label2='Republican'

        elif topic=='Ivermectin':
                ndf=pd.read_csv(path+topic+'_selected_noNA.csv')

                m2=241
                label1='Misinformation-related'
                label2='Mainstream'
                
        
            
            
        ndf['urls']=ndf['urls'].str.split()
        ndf=ndf.explode('urls')
        ndf['domain']=ndf['urls'].apply(lambda x:  extract_domain(x))
        modularity=pd.read_csv(path+file_name+'_networkx.csv')

        modularity=modularity.rename(columns={'Id':'user_screen_name'})
        ndf=updatecol(ndf,modularity,'modularity_class','user_screen_name')


        nodes1=modularity[modularity['modularity_class']==38]['user_screen_name'].drop_duplicates().tolist()# Iverlectin related
        nodes2=modularity[modularity['modularity_class']==m2]['user_screen_name'].drop_duplicates().tolist()# 241 mainstream related


        print('Processing finished!')



        ndf1=ndf.groupby(['user_screen_name'])[_target].apply(list).reset_index()
        lst=ndf1[_target].apply(list).tolist()
        G,hdf=bihashtagGraph(lst,topic+'_'+_target)



        print(len(G.nodes()))

        model=fast_node2vec(hdf)

        print(len(model.wv.index2entity))

        ndf1=ndf.groupby(['user_screen_name'])[_target].apply(list).reset_index()

        import gensim
        def convert_vec(_model,x):
            try:
                if len(x)==0:
                    if int(gensim.__version__[0])<4:

                        return _model.wv.get_vector(x[0])
                    else:
                        return _model.get_vector(x[0])

                else:
                    if int(gensim.__version__[0])<4:
                        _lst= [_model.wv.get_vector(y) for y in x]
                    else:
                         _lst= [_model.get_vector(y) for y in x]

                    _sum=0
                    for each in _lst:
                        _sum=_sum+each
                    return _sum
            except Exception as e:
                pass
            return None



        if _target=='domain':
            ndf=ndf.explode(['domain'])
            #ndf[_target]=ndf[_target].apply(lambda x: ','.join(x))

            ndf1=ndf.groupby(by='user_screen_name').agg(domain=('domain', lambda x: ",".join(set(x)))).reset_index()

        elif _target=='hashtag':


            ndf1=ndf.groupby(by='user_screen_name').agg(hashtags=(_target, lambda x: ",".join(set(x)))).reset_index()

        #ndf1[_target]=ndf1[_target].str.split(',')



        ndf1[_target]=ndf1[_target].str.split(',')

        ndf1['vec']=ndf1[_target].apply(lambda x: convert_vec(model,x))

        #ndf1=ndf1.rename(columns={_target:'vec'})

        ndf1.dropna(subset=['vec'], inplace=True)

        ndf1.reset_index(inplace=True,drop=True)

        dfv=ndf1['vec']
        dfv=pd.DataFrame(dfv)

        values=np.array([x[0] for x in dfv.values])

        df_values=pd.DataFrame(values)

        df_values['user_screen_name']=ndf1['user_screen_name']

        data=df_values

        data.drop_duplicates(subset=list(range(300)),inplace=True)
        

        data.loc[data['user_screen_name'].isin(nodes1),'labels']=label1

        data.loc[data['user_screen_name'].isin(nodes2),'labels']=label2
        
        data.dropna(subset=['labels'],inplace=True)

        smaller_sample=500
        Nums=[smaller_sample, 
              data.groupby('labels').size().reset_index().loc[0,0],
              data.groupby('labels').size().reset_index().loc[1,0]]
        num = min(Nums)
        savingname=topic+'_'+_target+'_'+str(num*2)
        print('Num of samples:',num)

        ndf_c=data[data.labels==label1]

        ndf_n=data[data.labels==label2]

        ndf_c=ndf_c.sample(num)

        ndf_n=ndf_n.sample(num)

        df=pd.concat([ndf_c,ndf_n])

        export_tSNE(df,str(num)+topic+ranking)

    df.loc[df['labels']==label1, 'labels']=1

    df.loc[df['labels']==label2, 'labels']=0
    df['labels']=df['labels'].apply('int32')

    def split_data(_df):
        np.random.seed(42)
        msk = np.random.rand(len(_df)) < 0.8
        df_train = _df[msk]
        df_left = _df[~msk]
        np.random.seed(42)
        msk = np.random.rand(len(df_left)) < 0.5
        df_valid = df_left[msk]
        df_test = df_left[~msk]

        print(df.shape)
        print('train:',df_train.shape)
        print('validation',df_valid.shape)
        print('test',df_test.shape)

        # Get the lists of sentences and their labels.

        training_data = torch.from_numpy(df_train.iloc[:,0:300].to_numpy())
        validation_data = torch.from_numpy(df_valid.iloc[:,0:300].to_numpy())
        testing_data = torch.from_numpy(df_test.iloc[:,0:300].to_numpy())

        labels_train = torch.tensor(df_train['labels'].to_numpy())
        labels_valid = torch.tensor(df_valid['labels'].to_numpy())
        labels_test = torch.tensor(df_test['labels'].to_numpy()) 


        _train_dataset = TensorDataset(training_data, labels_train)
        _val_dataset =   TensorDataset(validation_data, labels_valid)
        _test_dataset =  TensorDataset(testing_data, labels_test)


        return _train_dataset, _val_dataset, _test_dataset
    train_dataset, val_dataset, test_dataset= split_data(df)

    import wandb
    class NetworkMLP(nn.Module):
        def __init__(self):
            super(NetworkMLP, self).__init__() 
            self.fc1 = nn.Linear(300, 150)

        def forward(self, X):
            z1 = self.fc1(X)
            return z1 

    class JointModel(nn.Module):

        def __init__(self,hidden_dim, output_dim, n_layers, dropout):
            super().__init__()
            self.model_net = NetworkMLP()
            self.fc1 = nn.Linear(150*1, 600)
            self.fc2 = nn.Linear(600, output_dim) #original
            self.dropout = nn.Dropout(dropout)


        def forward(self, _net): 
            prediction= self.model_net(_net)

            #prediction_twtNews = self.model_twt(x_tNews)

            #concat_pred = torch.cat((prediction_RT, prediction_MT), 1)
            output = self.fc1(prediction)

            output = self.dropout(output) # add dropout
            output = self.fc2(F.relu(output)) #original
            #output = self.dropout(output)#add dropout
            #output = self.fc3(F.relu(output))
            return output

    def count_parameters(model):
        return sum(p.numel() for p in model.parameters() if p.requires_grad)

    def binary_accuracy(preds, y):
        """
        Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
        """

        #round predictions to the closest integer
        #rounded_preds = torch.round(torch.sigmoid(preds))
        #rounded_preds = torch.round(preds)
        correct = (preds == y).float() #convert into float for division 
        acc = correct.sum() / len(correct)

        from sklearn.metrics import f1_score
        macro_f1 = f1_score(y.to("cpu"), preds.to("cpu"), average='macro')
        #print("macro_f1", macro_f1)

        return acc, macro_f1


    def train(model, iterator, optimizer, criterion):

        epoch_loss = 0
        epoch_acc = 0
        epoch_macro = 0
        model.train()
        for step, batch in enumerate(iterator):    
        #for batch in iterator:
            #print("batch", batch)
            # `batch` contains three pytorch tensors:
            #   [0]: input ids 
            #   [1]: attention masks
            #   [2]: labels 
            #   b_input_ids = batch[0].to(device)
            #   b_input_mask = batch[1].to(device)
            #   b_labels = batch[2].to(device)

            optimizer.zero_grad()

            net = batch[0].to(device)
            #netMT = batch[1].to(device)
            #feature1=batch[0]
            #print('feature1:',feature1)
            #feature2=batch[1]
            #cosine_score=emb_similarity(feature1, feature2)
            #cosine_score_view=cosine_score.view(cosine_score.size()[0],1)

            #twt = batch[0].to(device)
            #news= batch[1].to(device)

            #print('text.size:',twt.size())
            #print('news.size:',news.size())

            #cosine_similarity=cosine_similarity.to(device)
            label = batch[1].to(device)

            #print("label", label, type(label),label.size()) #torch.Size([32])
            #label = label.unsqueeze(1)
            #print("label", label, type(label),label.size())
            #predictions = model(batch.text).squeeze(1)
            #predictions = model(text)
            predictions = model(net)#,cosine_similarity)

            #cosine_score_view=cosine_score.view(cosine_score.size()[0],1)



            #print('cosine_similarity.size:',cosine_score.size())
            #predictions=torch.cat((predictions,cosine_score_view), dim = 1)
            #print('predictions.size:',predictions.size())
            label = label.type(torch.LongTensor)


            loss = criterion(predictions, label)

            acc, macro_f1 = binary_accuracy(torch.argmax(predictions, dim = 1), label)

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            epoch_acc += acc.item()
            epoch_macro += macro_f1.item()
        return epoch_loss / len(iterator), epoch_acc / len(iterator), epoch_macro / len(iterator)

    def evaluate(model, iterator, criterion):
        epoch_loss = 0
        epoch_acc = 0
        epoch_macro = 0
        model.eval()

        with torch.no_grad():

            #for batch in iterator:
            for step, batch in enumerate(iterator):    
                #des = batch[0].to(device)
                #loc = batch[1].to(device)
                net = batch[0].to(device)
                #netMT = batch[1].to(device)
                #twt = batch[0].to(device)
                #news= batch[1].to(devifce)
                label = batch[1].to(device)
                #predictions = model(batch.text).squeeze(1)
                label = label.type(torch.LongTensor)
                predictions = model(net)
                #loss = criterion(predictions, batch.label)
                loss = criterion(predictions, label)
                #acc = binary_accuracy(predictions, batch.label)
                acc, macro_f1 = binary_accuracy(torch.argmax(predictions, dim = 1), label)
                epoch_loss += loss.item()
                epoch_acc += acc.item()
                epoch_macro += macro_f1.item()
        return epoch_loss / len(iterator), epoch_acc / len(iterator), epoch_macro / len(iterator)


    def epoch_time(start_time, end_time):
        elapsed_time = end_time - start_time
        elapsed_mins = int(elapsed_time / 60)
        elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
        return elapsed_mins, elapsed_secs

    def save_plots(train_losses, val_losses, train_f1, val_f1, train_accs, val_accs,test_accs,test_f1s):
        """Plot

            Plot two figures: loss vs. epoch and accuracy vs. epoch
        """
        n = len(train_losses)
        xs = np.arange(1,n+1,1)
        xs = xs.astype(int)

        # plot train and val losses
        fig, ax = plt.subplots()
        ax.plot(xs, train_losses, '--', linewidth=2, label='train loss')
        ax.plot(xs, val_losses, '-', linewidth=2, label='validation loss')
        #ax.set_xlim(0, 10)
        ax.set_xlabel("Epoch")
        ax.set_ylabel("Loss")
        ax.legend(loc='upper right')
        plt.savefig('../Project2/'+topic+'/figs/'+savingname+'_'+str(DROPOUT)+'_'+str(OUTPUT_DIM)+'_Loss.png')

        # plot train and val f1-score
        #plt.clf()
        fig, ax = plt.subplots()
        ax.plot(xs, train_f1, '--', linewidth=2, label='train')
        ax.plot(xs, val_f1, '-', linewidth=2, label='validation')
        ax.plot(xs, test_f1s, '-', linewidth=2, label='test')

        ax.set_xlabel("Epoch")
        ax.set_ylabel("Macro-avg F1")
        ax.legend(loc='lower right')
        plt.savefig('../Project2/'+topic+'/figs/'+savingname+'_'+str(DROPOUT)+'_'+str(OUTPUT_DIM)+'_Macro-avgF1.png')

        # plot train and val accuracy
        #plt.clf()
        fig, ax = plt.subplots()
        ax.plot(xs, train_accs, '--', linewidth=2, label='train')
        ax.plot(xs, val_accs, '-', linewidth=2, label='validation')
        ax.plot(xs, test_accs, '-', linewidth=2, label='test')
        #ax.set_xlim(0, 10)
        ax.set_xlabel("Epoch")
        ax.set_ylabel("Accuracy")
        ax.legend(loc='lower right')
        plt.savefig('../Project2/'+topic+'/figs/'+savingname+'_'+str(DROPOUT)+'_'+str(OUTPUT_DIM)+'_ACC.png')



    

    train_dataloader = DataLoader(
                        train_dataset,  # The training samples.
                        sampler = RandomSampler(train_dataset), # Select batches randomly
                        batch_size = batch_size # Trains with this batch size.
                    )
    validation_dataloader = DataLoader(
                val_dataset, # The validation samples.
                sampler = SequentialSampler(val_dataset), # Pull out batches sequentially.
                batch_size = batch_size # Evaluate with this batch size.
            )
    test_dataloader = DataLoader(
                test_dataset, # The validation samples.
                sampler = SequentialSampler(test_dataset), # Pull out batches sequentially.
                batch_size = batch_size # Evaluate with this batch size.
            ) 

    model = JointModel(HIDDEN_DIM, OUTPUT_DIM, N_LAYERS,DROPOUT)
    optimizer = optim.Adam(model.parameters())
    criterion = nn.CrossEntropyLoss()
    criterion = criterion.to(device) 
    wandb.login()
    wandb.init(project='Project2_joint',name=savingname)#wandb.init(project='Project2_joint',name=savingname+'_'+str(eachtime))
    wandb.config = {
            "epochs": N_EPOCHS,
            "batch_size": batch_size
            }

    resume_training = False
    if resume_training == True:
        eachtime = 0
        which_time = 6
        path= '../Project2/pt/'+savingname+'_'+str(eachtime)+'/'
        checkpoint = torch.load(path+str(which_time)+'.pt')
        model.load_state_dict(checkpoint)
    model = model.to(device)





    pt=makefolder('../Project2/pt/'+savingname+'/')#pt=makefolder('../Project2/pt/'+savingname+'_'+str(eachtime)+'/')
    pt_best=makefolder('../Project2/pt_best/'+savingname+'/')#pt_best=makefolder('../Project2/pt_best/'+savingname+'_'+str(eachtime)+'/')


    best_valid_loss = float('inf')
    per_epoch_train_loss = []
    per_epoch_val_loss = []
    per_epoch_train_f1 = []
    per_epoch_val_f1 = []
    per_epoch_train_acc = []
    per_epoch_val_acc = []
    import time
    t1=time.time()
    for epoch in range(which_time, N_EPOCHS):
        print(epoch)

        start_time = time.time()

        train_loss, train_acc, train_f1 = train(model, train_dataloader, optimizer, criterion)
        valid_loss, valid_acc, valid_f1 = evaluate(model, validation_dataloader, criterion)

        end_time = time.time()

        epoch_mins, epoch_secs = epoch_time(start_time, end_time)
        per_epoch_train_loss.append(train_loss)
        per_epoch_val_loss.append(valid_loss)
        per_epoch_train_f1.append(train_f1)
        per_epoch_val_f1.append(valid_f1)
        per_epoch_train_acc.append(train_acc)
        per_epoch_val_acc.append(valid_acc)
        Val_aver_acc=mean(per_epoch_val_acc)
        Val_aver_f1=mean(per_epoch_val_f1)


        if valid_loss <= best_valid_loss:
            best_valid_loss = valid_loss
            print("best model saved in epoch :", epoch+1 )
            torch.save(model.state_dict(), pt_best +str(epoch+1)+'.pt')
        torch.save(model.state_dict(), pt +'/'+str(epoch+1)+'.pt')

        print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
        print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f} | Train macro-avg-f1: {train_f1*100:.2f}%')
        print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f} |  Val. macro-avg-f1: {valid_f1*100:.2f}%')
        print(f'\t Aver. ACC: {Val_aver_acc*100:.2f}%')
        wandb.log({'Max Val Acc':max(per_epoch_val_acc),'Average Val. Acc': Val_aver_acc,'Val. accuracy': valid_acc, 'Val. loss': valid_loss,'Val. macro-avg-f1':valid_f1})


    Test_Acc = []
    Test_f1=[]
    for epoch in range(N_EPOCHS):
        print(epoch)
        model.load_state_dict(torch.load(pt+str(epoch+1)+'.pt')) 
        test_loss, test_acc, test_f1 = evaluate(model, test_dataloader, criterion)

        Test_Acc.append(test_acc)
        Test_f1.append(test_f1)
        Test_aver_acc=mean(Test_Acc)
        Test_test_f1=mean(Test_f1)
        t2=time.time()
        print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f} | Test macro-avg-f1: {test_f1*100:.2f}%')
        print(f'\t Aver. TEST ACC: {Test_aver_acc*100:.2f}%')
        wandb.log({'Max TEST Acc':max(Test_Acc),'Average TEST Acc': Test_aver_acc,'Test accuracy': test_acc, 'Test loss': test_loss,'Test macro-avg-f1':Test_test_f1})
    _time=t2-t1
    wandb.finish()
    save_plots(per_epoch_train_loss, per_epoch_val_loss, per_epoch_train_f1, 
    per_epoch_val_f1, per_epoch_train_acc, per_epoch_val_acc,Test_Acc,Test_f1)
    re=pd.DataFrame([[topic,N_LAYERS,DROPOUT, N_EPOCHS,OUTPUT_DIM, _target,num*2,Val_aver_acc,Test_aver_acc, Val_aver_f1, Test_test_f1,_time]],columns=['Topic','Layer','Dropout','Epochs','Output_dim','NEWS/TEXT','samples','Avg. Val. Acc.','Avg. Test.Acc','Avg. Val. macro-avg-f1','Avg. Test. macro-avg-f1','Time'])
    re.to_csv('../Project2/DOMAIN_HASHTAG_classification_results_drop_duplicates.csv',index=None,mode='a')
# Out:
# Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.
# /opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
#   return f(*args, **kwds)
# /opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
#   return f(*args, **kwds)
# /opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
#   return f(*args, **kwds)
# /opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
#   return f(*args, **kwds)
# Training
# Device: cpu
# Processing finished!
# 502
# Reading graph: 100%|██████████| 5315/5315 [00:00<00:00, 94731.25it/s]
# Training:   2%|▏         | 7741/502000 [00:00<00:12, 38266.26it/s]
# 502
# Training: 100%|██████████| 502000/502000 [00:16<00:00, 31226.81it/s]
# Num of samples: 156
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 312 samples in 0.001s...
# [t-SNE] Computed neighbors for 312 samples in 0.011s...
# [t-SNE] Computed conditional probabilities for sample 312 / 312
# [t-SNE] Mean sigma: 0.009767
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.766235
# [t-SNE] KL divergence after 1000 iterations: 1.114089
# t-SNE done! Time elapsed: 4.773744821548462 seconds
# (312, 302)
# train: (248, 302)
# validation (35, 302)
# test (29, 302)
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: lawrencexu (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.14 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/lawrencexu/Project2_joint/runs/2o9uuwac" target="_blank">Ivermectin_domain_312</a></strong> to <a href="https://wandb.ai/lawrencexu/Project2_joint" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Floder: ../Project2/pt/Ivermectin_domain_312/ Exsit!
# Floder: ../Project2/pt_best/Ivermectin_domain_312/ Exsit!
# 0
# best model saved in epoch : 1
# Epoch: 01 | Epoch Time: 0m 0s
# 	Train Loss: 8.466 | Train Acc: 44.14 | Train macro-avg-f1: 29.08%
# 	 Val. Loss: 7.569 |  Val. Acc: 60.42 |  Val. macro-avg-f1: 48.28%
# 	 Aver. ACC: 60.42%
# 1
# best model saved in epoch : 2
# Epoch: 02 | Epoch Time: 0m 0s
# 	Train Loss: 5.581 | Train Acc: 50.39 | Train macro-avg-f1: 33.07%
# 	 Val. Loss: 2.278 |  Val. Acc: 60.42 |  Val. macro-avg-f1: 48.28%
# 	 Aver. ACC: 60.42%
# 2
# best model saved in epoch : 3
# Epoch: 03 | Epoch Time: 0m 0s
# 	Train Loss: 0.984 | Train Acc: 50.39 | Train macro-avg-f1: 33.14%
# 	 Val. Loss: 0.679 |  Val. Acc: 60.42 |  Val. macro-avg-f1: 48.28%
# 	 Aver. ACC: 60.42%
# 3
# best model saved in epoch : 4
# Epoch: 04 | Epoch Time: 0m 0s
# 	Train Loss: 0.702 | Train Acc: 44.92 | Train macro-avg-f1: 31.01%
# 	 Val. Loss: 0.678 |  Val. Acc: 60.42 |  Val. macro-avg-f1: 48.28%
# 	 Aver. ACC: 60.42%
# 4
# Epoch: 05 | Epoch Time: 0m 0s
# 	Train Loss: 0.700 | Train Acc: 47.27 | Train macro-avg-f1: 31.75%
# 	 Val. Loss: 0.684 |  Val. Acc: 60.42 |  Val. macro-avg-f1: 48.28%
# 	 Aver. ACC: 60.42%
# 5
# Epoch: 06 | Epoch Time: 0m 0s
# 	Train Loss: 0.698 | Train Acc: 53.52 | Train macro-avg-f1: 34.51%
# 	 Val. Loss: 0.775 |  Val. Acc: 39.58 |  Val. macro-avg-f1: 38.60%
# 	 Aver. ACC: 56.94%
# 6
# Epoch: 07 | Epoch Time: 0m 0s
# 	Train Loss: 0.723 | Train Acc: 43.75 | Train macro-avg-f1: 29.79%
# 	 Val. Loss: 0.732 |  Val. Acc: 39.58 |  Val. macro-avg-f1: 38.60%
# 	 Aver. ACC: 54.46%
# 7
# best model saved in epoch : 8
# Epoch: 08 | Epoch Time: 0m 0s
# 	Train Loss: 0.707 | Train Acc: 50.00 | Train macro-avg-f1: 33.54%
# 	 Val. Loss: 0.672 |  Val. Acc: 60.42 |  Val. macro-avg-f1: 48.28%
# 	 Aver. ACC: 55.21%
# 8
# Epoch: 09 | Epoch Time: 0m 0s
# 	Train Loss: 0.699 | Train Acc: 47.66 | Train macro-avg-f1: 31.53%
# 	 Val. Loss: 0.686 |  Val. Acc: 60.42 |  Val. macro-avg-f1: 48.28%
# 	 Aver. ACC: 55.79%
# 9
# Epoch: 10 | Epoch Time: 0m 0s
# 	Train Loss: 0.698 | Train Acc: 49.22 | Train macro-avg-f1: 33.28%
# 	 Val. Loss: 0.696 |  Val. Acc: 39.58 |  Val. macro-avg-f1: 38.60%
# 	 Aver. ACC: 54.17%
# 10
# Epoch: 11 | Epoch Time: 0m 0s
# 	Train Loss: 0.694 | Train Acc: 47.27 | Train macro-avg-f1: 35.00%
# 	 Val. Loss: 0.679 |  Val. Acc: 60.42 |  Val. macro-avg-f1: 48.28%
# 	 Aver. ACC: 54.73%
# 11
# Epoch: 12 | Epoch Time: 0m 0s
# 	Train Loss: 0.693 | Train Acc: 53.12 | Train macro-avg-f1: 40.74%
# 	 Val. Loss: 0.680 |  Val. Acc: 60.42 |  Val. macro-avg-f1: 48.28%
# 	 Aver. ACC: 55.21%
# 12
# Epoch: 13 | Epoch Time: 0m 0s
# 	Train Loss: 0.689 | Train Acc: 51.95 | Train macro-avg-f1: 38.10%
# 	 Val. Loss: 0.700 |  Val. Acc: 39.58 |  Val. macro-avg-f1: 38.60%
# 	 Aver. ACC: 54.01%
# 13
# Epoch: 14 | Epoch Time: 0m 0s
# 	Train Loss: 0.696 | Train Acc: 50.78 | Train macro-avg-f1: 36.81%
# 	 Val. Loss: 0.690 |  Val. Acc: 61.11 |  Val. macro-avg-f1: 58.07%
# 	 Aver. ACC: 54.51%
# 14
# best model saved in epoch : 15
# Epoch: 15 | Epoch Time: 0m 0s
# 	Train Loss: 0.693 | Train Acc: 53.52 | Train macro-avg-f1: 36.96%
# 	 Val. Loss: 0.665 |  Val. Acc: 60.42 |  Val. macro-avg-f1: 48.28%
# 	 Aver. ACC: 54.91%
# 15
# Epoch: 16 | Epoch Time: 0m 0s
# 	Train Loss: 0.685 | Train Acc: 53.91 | Train macro-avg-f1: 36.85%
# 	 Val. Loss: 0.716 |  Val. Acc: 39.58 |  Val. macro-avg-f1: 38.60%
# 	 Aver. ACC: 53.95%
# 16
# best model saved in epoch : 17
# Epoch: 17 | Epoch Time: 0m 0s
# 	Train Loss: 0.691 | Train Acc: 50.00 | Train macro-avg-f1: 33.50%
# 	 Val. Loss: 0.660 |  Val. Acc: 60.42 |  Val. macro-avg-f1: 48.28%
# 	 Aver. ACC: 54.33%
# 17
# Epoch: 18 | Epoch Time: 0m 0s
# 	Train Loss: 0.692 | Train Acc: 48.83 | Train macro-avg-f1: 33.74%
# 	 Val. Loss: 0.717 |  Val. Acc: 39.58 |  Val. macro-avg-f1: 38.60%
# 	 Aver. ACC: 53.51%
# 18
# Epoch: 19 | Epoch Time: 0m 0s
# 	Train Loss: 0.674 | Train Acc: 60.55 | Train macro-avg-f1: 53.94%
# 	 Val. Loss: 0.678 |  Val. Acc: 67.36 |  Val. macro-avg-f1: 63.46%
# 	 Aver. ACC: 54.24%
# 19
# Epoch: 20 | Epoch Time: 0m 0s
# 	Train Loss: 0.663 | Train Acc: 62.50 | Train macro-avg-f1: 54.90%
# 	 Val. Loss: 0.686 |  Val. Acc: 59.03 |  Val. macro-avg-f1: 56.18%
# 	 Aver. ACC: 54.48%
# 20
# best model saved in epoch : 21
# Epoch: 21 | Epoch Time: 0m 0s
# 	Train Loss: 0.662 | Train Acc: 59.77 | Train macro-avg-f1: 48.76%
# 	 Val. Loss: 0.641 |  Val. Acc: 62.50 |  Val. macro-avg-f1: 50.24%
# 	 Aver. ACC: 54.86%
# 21
# Epoch: 22 | Epoch Time: 0m 0s
# 	Train Loss: 0.639 | Train Acc: 73.83 | Train macro-avg-f1: 69.73%
# 	 Val. Loss: 0.656 |  Val. Acc: 67.36 |  Val. macro-avg-f1: 49.49%
# 	 Aver. ACC: 55.43%
# 22
# best model saved in epoch : 23
# Epoch: 23 | Epoch Time: 0m 0s
# 	Train Loss: 0.619 | Train Acc: 81.25 | Train macro-avg-f1: 80.69%
# 	 Val. Loss: 0.622 |  Val. Acc: 59.72 |  Val. macro-avg-f1: 43.81%
# 	 Aver. ACC: 55.62%
# 23
# best model saved in epoch : 24
# Epoch: 24 | Epoch Time: 0m 0s
# 	Train Loss: 0.603 | Train Acc: 72.27 | Train macro-avg-f1: 68.96%
# 	 Val. Loss: 0.597 |  Val. Acc: 55.56 |  Val. macro-avg-f1: 33.54%
# 	 Aver. ACC: 55.61%
# 24
# best model saved in epoch : 25
# Epoch: 25 | Epoch Time: 0m 0s
# 	Train Loss: 0.572 | Train Acc: 73.83 | Train macro-avg-f1: 71.28%
# 	 Val. Loss: 0.591 |  Val. Acc: 76.39 |  Val. macro-avg-f1: 56.30%
# 	 Aver. ACC: 56.44%
# 25
# Epoch: 26 | Epoch Time: 0m 0s
# 	Train Loss: 0.518 | Train Acc: 82.03 | Train macro-avg-f1: 80.80%
# 	 Val. Loss: 0.606 |  Val. Acc: 67.36 |  Val. macro-avg-f1: 49.49%
# 	 Aver. ACC: 56.86%
# 26
# Epoch: 27 | Epoch Time: 0m 0s
# 	Train Loss: 0.482 | Train Acc: 80.86 | Train macro-avg-f1: 79.82%
# 	 Val. Loss: 0.612 |  Val. Acc: 69.44 |  Val. macro-avg-f1: 50.07%
# 	 Aver. ACC: 57.33%
# 27
# best model saved in epoch : 28
# Epoch: 28 | Epoch Time: 0m 0s
# 	Train Loss: 0.440 | Train Acc: 83.20 | Train macro-avg-f1: 82.10%
# 	 Val. Loss: 0.558 |  Val. Acc: 78.47 |  Val. macro-avg-f1: 60.25%
# 	 Aver. ACC: 58.09%
# 28
# Epoch: 29 | Epoch Time: 0m 0s
# 	Train Loss: 0.392 | Train Acc: 85.16 | Train macro-avg-f1: 84.29%
# 	 Val. Loss: 0.579 |  Val. Acc: 82.64 |  Val. macro-avg-f1: 61.61%
# 	 Aver. ACC: 58.93%
# 29
# Epoch: 30 | Epoch Time: 0m 0s
# 	Train Loss: 0.362 | Train Acc: 87.11 | Train macro-avg-f1: 86.09%
# 	 Val. Loss: 0.729 |  Val. Acc: 67.36 |  Val. macro-avg-f1: 63.46%
# 	 Aver. ACC: 59.21%
# 30
# Epoch: 31 | Epoch Time: 0m 0s
# 	Train Loss: 0.347 | Train Acc: 83.59 | Train macro-avg-f1: 83.12%
# 	 Val. Loss: 0.699 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 67.27%
# 	 Aver. ACC: 59.61%
# 31
# Epoch: 32 | Epoch Time: 0m 0s
# 	Train Loss: 0.324 | Train Acc: 86.33 | Train macro-avg-f1: 84.96%
# 	 Val. Loss: 0.608 |  Val. Acc: 82.64 |  Val. macro-avg-f1: 61.61%
# 	 Aver. ACC: 60.33%
# 32
# Epoch: 33 | Epoch Time: 0m 0s
# 	Train Loss: 0.306 | Train Acc: 87.11 | Train macro-avg-f1: 86.01%
# 	 Val. Loss: 0.603 |  Val. Acc: 82.64 |  Val. macro-avg-f1: 61.61%
# 	 Aver. ACC: 61.01%
# 33
# Epoch: 34 | Epoch Time: 0m 0s
# 	Train Loss: 0.292 | Train Acc: 87.50 | Train macro-avg-f1: 86.74%
# 	 Val. Loss: 0.711 |  Val. Acc: 67.36 |  Val. macro-avg-f1: 49.49%
# 	 Aver. ACC: 61.19%
# 34
# Epoch: 35 | Epoch Time: 0m 0s
# 	Train Loss: 0.277 | Train Acc: 88.28 | Train macro-avg-f1: 87.79%
# 	 Val. Loss: 0.728 |  Val. Acc: 67.36 |  Val. macro-avg-f1: 49.49%
# 	 Aver. ACC: 61.37%
# 35
# Epoch: 36 | Epoch Time: 0m 0s
# 	Train Loss: 0.255 | Train Acc: 89.06 | Train macro-avg-f1: 88.45%
# 	 Val. Loss: 0.713 |  Val. Acc: 67.36 |  Val. macro-avg-f1: 51.05%
# 	 Aver. ACC: 61.54%
# 36
# Epoch: 37 | Epoch Time: 0m 0s
# 	Train Loss: 0.247 | Train Acc: 89.45 | Train macro-avg-f1: 88.89%
# 	 Val. Loss: 0.744 |  Val. Acc: 69.44 |  Val. macro-avg-f1: 51.67%
# 	 Aver. ACC: 61.75%
# 37
# Epoch: 38 | Epoch Time: 0m 0s
# 	Train Loss: 0.235 | Train Acc: 89.84 | Train macro-avg-f1: 89.25%
# 	 Val. Loss: 0.729 |  Val. Acc: 69.44 |  Val. macro-avg-f1: 53.56%
# 	 Aver. ACC: 61.95%
# 38
# Epoch: 39 | Epoch Time: 0m 0s
# 	Train Loss: 0.247 | Train Acc: 89.45 | Train macro-avg-f1: 88.25%
# 	 Val. Loss: 0.745 |  Val. Acc: 69.44 |  Val. macro-avg-f1: 53.56%
# 	 Aver. ACC: 62.14%
# 39
# Epoch: 40 | Epoch Time: 0m 0s
# 	Train Loss: 0.226 | Train Acc: 90.23 | Train macro-avg-f1: 89.75%
# 	 Val. Loss: 0.737 |  Val. Acc: 69.44 |  Val. macro-avg-f1: 53.56%
# 	 Aver. ACC: 62.33%
# 40
# Epoch: 41 | Epoch Time: 0m 0s
# 	Train Loss: 0.214 | Train Acc: 91.41 | Train macro-avg-f1: 91.18%
# 	 Val. Loss: 0.764 |  Val. Acc: 69.44 |  Val. macro-avg-f1: 53.56%
# 	 Aver. ACC: 62.50%
# 41
# Epoch: 42 | Epoch Time: 0m 0s
# 	Train Loss: 0.214 | Train Acc: 91.41 | Train macro-avg-f1: 91.05%
# 	 Val. Loss: 0.794 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 54.75%
# 	 Aver. ACC: 62.76%
# 42
# Epoch: 43 | Epoch Time: 0m 0s
# 	Train Loss: 0.206 | Train Acc: 90.62 | Train macro-avg-f1: 90.06%
# 	 Val. Loss: 0.700 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 62.97%
# 43
# Epoch: 44 | Epoch Time: 0m 1s
# 	Train Loss: 0.199 | Train Acc: 92.19 | Train macro-avg-f1: 90.18%
# 	 Val. Loss: 0.783 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 54.17%
# 	 Aver. ACC: 63.16%
# 44
# Epoch: 45 | Epoch Time: 0m 0s
# 	Train Loss: 0.196 | Train Acc: 91.80 | Train macro-avg-f1: 91.49%
# 	 Val. Loss: 0.760 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 63.35%
# 45
# Epoch: 46 | Epoch Time: 0m 0s
# 	Train Loss: 0.221 | Train Acc: 89.84 | Train macro-avg-f1: 89.16%
# 	 Val. Loss: 0.660 |  Val. Acc: 82.64 |  Val. macro-avg-f1: 61.61%
# 	 Aver. ACC: 63.77%
# 46
# Epoch: 47 | Epoch Time: 0m 0s
# 	Train Loss: 0.188 | Train Acc: 91.02 | Train macro-avg-f1: 90.66%
# 	 Val. Loss: 0.690 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 63.93%
# 47
# Epoch: 48 | Epoch Time: 0m 0s
# 	Train Loss: 0.182 | Train Acc: 91.02 | Train macro-avg-f1: 90.65%
# 	 Val. Loss: 0.884 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 54.75%
# 	 Aver. ACC: 64.13%
# 48
# Epoch: 49 | Epoch Time: 0m 0s
# 	Train Loss: 0.167 | Train Acc: 93.36 | Train macro-avg-f1: 92.85%
# 	 Val. Loss: 0.811 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 64.33%
# 49
# Epoch: 50 | Epoch Time: 0m 0s
# 	Train Loss: 0.176 | Train Acc: 91.80 | Train macro-avg-f1: 91.45%
# 	 Val. Loss: 0.709 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 64.47%
# 50
# Epoch: 51 | Epoch Time: 0m 0s
# 	Train Loss: 0.164 | Train Acc: 94.14 | Train macro-avg-f1: 93.91%
# 	 Val. Loss: 0.746 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 64.61%
# 51
# Epoch: 52 | Epoch Time: 0m 0s
# 	Train Loss: 0.161 | Train Acc: 90.62 | Train macro-avg-f1: 90.05%
# 	 Val. Loss: 0.896 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 54.75%
# 	 Aver. ACC: 64.78%
# 52
# Epoch: 53 | Epoch Time: 0m 0s
# 	Train Loss: 0.152 | Train Acc: 94.92 | Train macro-avg-f1: 94.44%
# 	 Val. Loss: 0.774 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 64.91%
# 53
# Epoch: 54 | Epoch Time: 0m 0s
# 	Train Loss: 0.145 | Train Acc: 94.92 | Train macro-avg-f1: 94.79%
# 	 Val. Loss: 0.866 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 65.07%
# 54
# Epoch: 55 | Epoch Time: 0m 0s
# 	Train Loss: 0.139 | Train Acc: 95.70 | Train macro-avg-f1: 95.50%
# 	 Val. Loss: 0.751 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 65.19%
# 55
# Epoch: 56 | Epoch Time: 0m 0s
# 	Train Loss: 0.137 | Train Acc: 96.09 | Train macro-avg-f1: 95.61%
# 	 Val. Loss: 0.800 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 65.30%
# 56
# Epoch: 57 | Epoch Time: 0m 0s
# 	Train Loss: 0.126 | Train Acc: 96.48 | Train macro-avg-f1: 96.39%
# 	 Val. Loss: 0.866 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 65.45%
# 57
# Epoch: 58 | Epoch Time: 0m 0s
# 	Train Loss: 0.121 | Train Acc: 96.88 | Train macro-avg-f1: 96.81%
# 	 Val. Loss: 0.821 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 65.59%
# 58
# Epoch: 59 | Epoch Time: 0m 0s
# 	Train Loss: 0.122 | Train Acc: 96.09 | Train macro-avg-f1: 95.87%
# 	 Val. Loss: 0.782 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 65.69%
# 59
# Epoch: 60 | Epoch Time: 0m 0s
# 	Train Loss: 0.135 | Train Acc: 94.14 | Train macro-avg-f1: 93.67%
# 	 Val. Loss: 0.779 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 65.79%
# 60
# Epoch: 61 | Epoch Time: 0m 0s
# 	Train Loss: 0.112 | Train Acc: 96.09 | Train macro-avg-f1: 95.99%
# 	 Val. Loss: 1.107 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 54.75%
# 	 Aver. ACC: 65.92%
# 61
# Epoch: 62 | Epoch Time: 0m 0s
# 	Train Loss: 0.122 | Train Acc: 96.88 | Train macro-avg-f1: 96.28%
# 	 Val. Loss: 0.949 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 66.04%
# 62
# Epoch: 63 | Epoch Time: 0m 0s
# 	Train Loss: 0.106 | Train Acc: 97.27 | Train macro-avg-f1: 97.03%
# 	 Val. Loss: 1.007 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 66.19%
# 63
# Epoch: 64 | Epoch Time: 0m 0s
# 	Train Loss: 0.098 | Train Acc: 98.44 | Train macro-avg-f1: 98.41%
# 	 Val. Loss: 0.835 |  Val. Acc: 69.44 |  Val. macro-avg-f1: 55.95%
# 	 Aver. ACC: 66.24%
# 64
# Epoch: 65 | Epoch Time: 0m 0s
# 	Train Loss: 0.094 | Train Acc: 97.66 | Train macro-avg-f1: 97.10%
# 	 Val. Loss: 1.212 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 66.39%
# 65
# Epoch: 66 | Epoch Time: 0m 0s
# 	Train Loss: 0.119 | Train Acc: 94.92 | Train macro-avg-f1: 94.63%
# 	 Val. Loss: 1.104 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 66.53%
# 66
# Epoch: 67 | Epoch Time: 0m 0s
# 	Train Loss: 0.100 | Train Acc: 97.27 | Train macro-avg-f1: 97.02%
# 	 Val. Loss: 1.073 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 66.67%
# 67
# Epoch: 68 | Epoch Time: 0m 0s
# 	Train Loss: 0.091 | Train Acc: 98.44 | Train macro-avg-f1: 98.25%
# 	 Val. Loss: 1.170 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 66.80%
# 68
# Epoch: 69 | Epoch Time: 0m 0s
# 	Train Loss: 0.105 | Train Acc: 96.48 | Train macro-avg-f1: 96.37%
# 	 Val. Loss: 1.127 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 66.93%
# 69
# Epoch: 70 | Epoch Time: 0m 0s
# 	Train Loss: 0.088 | Train Acc: 98.44 | Train macro-avg-f1: 98.42%
# 	 Val. Loss: 1.194 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 67.05%
# 70
# Epoch: 71 | Epoch Time: 0m 0s
# 	Train Loss: 0.079 | Train Acc: 98.83 | Train macro-avg-f1: 98.78%
# 	 Val. Loss: 1.057 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 67.15%
# 71
# Epoch: 72 | Epoch Time: 0m 0s
# 	Train Loss: 0.073 | Train Acc: 98.83 | Train macro-avg-f1: 98.81%
# 	 Val. Loss: 1.061 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 67.21%
# 72
# Epoch: 73 | Epoch Time: 0m 0s
# 	Train Loss: 0.077 | Train Acc: 98.83 | Train macro-avg-f1: 98.63%
# 	 Val. Loss: 1.224 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 67.32%
# 73
# Epoch: 74 | Epoch Time: 0m 0s
# 	Train Loss: 0.069 | Train Acc: 99.22 | Train macro-avg-f1: 99.19%
# 	 Val. Loss: 1.113 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 67.44%
# 74
# Epoch: 75 | Epoch Time: 0m 0s
# 	Train Loss: 0.078 | Train Acc: 98.05 | Train macro-avg-f1: 97.81%
# 	 Val. Loss: 0.883 |  Val. Acc: 67.36 |  Val. macro-avg-f1: 55.25%
# 	 Aver. ACC: 67.44%
# 75
# Epoch: 76 | Epoch Time: 0m 0s
# 	Train Loss: 0.067 | Train Acc: 98.83 | Train macro-avg-f1: 98.76%
# 	 Val. Loss: 1.195 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 67.54%
# 76
# Epoch: 77 | Epoch Time: 0m 0s
# 	Train Loss: 0.058 | Train Acc: 99.22 | Train macro-avg-f1: 99.22%
# 	 Val. Loss: 1.080 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 67.60%
# 77
# Epoch: 78 | Epoch Time: 0m 0s
# 	Train Loss: 0.064 | Train Acc: 98.83 | Train macro-avg-f1: 98.59%
# 	 Val. Loss: 1.054 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 67.65%
# 78
# Epoch: 79 | Epoch Time: 0m 0s
# 	Train Loss: 0.066 | Train Acc: 98.05 | Train macro-avg-f1: 97.76%
# 	 Val. Loss: 1.026 |  Val. Acc: 69.44 |  Val. macro-avg-f1: 55.95%
# 	 Aver. ACC: 67.67%
# 79
# Epoch: 80 | Epoch Time: 0m 0s
# 	Train Loss: 0.071 | Train Acc: 98.05 | Train macro-avg-f1: 97.89%
# 	 Val. Loss: 1.157 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 67.72%
# 80
# Epoch: 81 | Epoch Time: 0m 0s
# 	Train Loss: 0.055 | Train Acc: 99.22 | Train macro-avg-f1: 99.22%
# 	 Val. Loss: 1.220 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 67.79%
# 81
# Epoch: 82 | Epoch Time: 0m 0s
# 	Train Loss: 0.054 | Train Acc: 98.44 | Train macro-avg-f1: 97.88%
# 	 Val. Loss: 1.331 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 67.89%
# 82
# Epoch: 83 | Epoch Time: 0m 0s
# 	Train Loss: 0.048 | Train Acc: 99.61 | Train macro-avg-f1: 99.61%
# 	 Val. Loss: 1.231 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 67.93%
# 83
# Epoch: 84 | Epoch Time: 0m 0s
# 	Train Loss: 0.044 | Train Acc: 99.61 | Train macro-avg-f1: 99.26%
# 	 Val. Loss: 1.321 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 68.02%
# 84
# Epoch: 85 | Epoch Time: 0m 1s
# 	Train Loss: 0.046 | Train Acc: 99.61 | Train macro-avg-f1: 99.60%
# 	 Val. Loss: 1.181 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 68.06%
# 85
# Epoch: 86 | Epoch Time: 0m 0s
# 	Train Loss: 0.042 | Train Acc: 99.61 | Train macro-avg-f1: 99.61%
# 	 Val. Loss: 1.265 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 68.13%
# 86
# Epoch: 87 | Epoch Time: 0m 0s
# 	Train Loss: 0.039 | Train Acc: 99.61 | Train macro-avg-f1: 99.52%
# 	 Val. Loss: 1.307 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 68.19%
# 87
# Epoch: 88 | Epoch Time: 0m 0s
# 	Train Loss: 0.043 | Train Acc: 99.61 | Train macro-avg-f1: 99.52%
# 	 Val. Loss: 1.361 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 68.28%
# 88
# Epoch: 89 | Epoch Time: 0m 0s
# 	Train Loss: 0.043 | Train Acc: 99.22 | Train macro-avg-f1: 99.17%
# 	 Val. Loss: 1.342 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 68.36%
# 89
# Epoch: 90 | Epoch Time: 0m 0s
# 	Train Loss: 0.043 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.400 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 68.44%
# 90
# Epoch: 91 | Epoch Time: 0m 0s
# 	Train Loss: 0.038 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.300 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 68.50%
# 91
# Epoch: 92 | Epoch Time: 0m 0s
# 	Train Loss: 0.035 | Train Acc: 99.61 | Train macro-avg-f1: 99.60%
# 	 Val. Loss: 1.205 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 68.53%
# 92
# Epoch: 93 | Epoch Time: 0m 0s
# 	Train Loss: 0.033 | Train Acc: 99.61 | Train macro-avg-f1: 99.52%
# 	 Val. Loss: 1.294 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 68.59%
# 93
# Epoch: 94 | Epoch Time: 0m 0s
# 	Train Loss: 0.033 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.324 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 68.64%
# 94
# Epoch: 95 | Epoch Time: 0m 0s
# 	Train Loss: 0.031 | Train Acc: 99.61 | Train macro-avg-f1: 99.60%
# 	 Val. Loss: 1.282 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 68.67%
# 95
# Epoch: 96 | Epoch Time: 0m 0s
# 	Train Loss: 0.028 | Train Acc: 99.61 | Train macro-avg-f1: 99.61%
# 	 Val. Loss: 1.356 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 68.72%
# 96
# Epoch: 97 | Epoch Time: 0m 0s
# 	Train Loss: 0.029 | Train Acc: 99.61 | Train macro-avg-f1: 99.57%
# 	 Val. Loss: 1.384 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 68.79%
# 97
# Epoch: 98 | Epoch Time: 0m 0s
# 	Train Loss: 0.027 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.319 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 68.84%
# 98
# Epoch: 99 | Epoch Time: 0m 0s
# 	Train Loss: 0.027 | Train Acc: 99.61 | Train macro-avg-f1: 99.43%
# 	 Val. Loss: 1.358 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 68.89%
# 99
# Epoch: 100 | Epoch Time: 0m 0s
# 	Train Loss: 0.026 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.382 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 68.94%
# 100
# Epoch: 101 | Epoch Time: 0m 0s
# 	Train Loss: 0.023 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.341 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 68.98%
# 101
# Epoch: 102 | Epoch Time: 0m 0s
# 	Train Loss: 0.023 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.552 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.05%
# 102
# Epoch: 103 | Epoch Time: 0m 0s
# 	Train Loss: 0.029 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.453 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.11%
# 103
# Epoch: 104 | Epoch Time: 0m 0s
# 	Train Loss: 0.029 | Train Acc: 99.61 | Train macro-avg-f1: 99.61%
# 	 Val. Loss: 1.368 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 69.16%
# 104
# Epoch: 105 | Epoch Time: 0m 0s
# 	Train Loss: 0.023 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.384 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 69.20%
# 105
# Epoch: 106 | Epoch Time: 0m 0s
# 	Train Loss: 0.021 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.532 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.26%
# 106
# Epoch: 107 | Epoch Time: 0m 0s
# 	Train Loss: 0.020 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.434 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 69.30%
# 107
# Epoch: 108 | Epoch Time: 0m 0s
# 	Train Loss: 0.018 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.561 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.36%
# 108
# Epoch: 109 | Epoch Time: 0m 0s
# 	Train Loss: 0.022 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.625 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.42%
# 109
# Epoch: 110 | Epoch Time: 0m 0s
# 	Train Loss: 0.018 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.367 |  Val. Acc: 71.53 |  Val. macro-avg-f1: 56.61%
# 	 Aver. ACC: 69.44%
# 110
# Epoch: 111 | Epoch Time: 0m 0s
# 	Train Loss: 0.018 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.569 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.49%
# 111
# Epoch: 112 | Epoch Time: 0m 0s
# 	Train Loss: 0.017 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.509 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.55%
# 112
# Epoch: 113 | Epoch Time: 0m 0s
# 	Train Loss: 0.017 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.452 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 69.59%
# 113
# Epoch: 114 | Epoch Time: 0m 0s
# 	Train Loss: 0.018 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.598 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.64%
# 114
# Epoch: 115 | Epoch Time: 0m 0s
# 	Train Loss: 0.015 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.496 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 69.67%
# 115
# Epoch: 116 | Epoch Time: 0m 0s
# 	Train Loss: 0.016 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.467 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 69.71%
# 116
# Epoch: 117 | Epoch Time: 0m 0s
# 	Train Loss: 0.014 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.520 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.76%
# 117
# Epoch: 118 | Epoch Time: 0m 0s
# 	Train Loss: 0.015 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.539 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.81%
# 118
# Epoch: 119 | Epoch Time: 0m 0s
# 	Train Loss: 0.014 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.612 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.86%
# 119
# Epoch: 120 | Epoch Time: 0m 0s
# 	Train Loss: 0.014 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.585 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.91%
# 120
# Epoch: 121 | Epoch Time: 0m 0s
# 	Train Loss: 0.013 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.515 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 69.94%
# 121
# Epoch: 122 | Epoch Time: 0m 0s
# 	Train Loss: 0.012 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.566 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 69.99%
# 122
# Epoch: 123 | Epoch Time: 0m 0s
# 	Train Loss: 0.012 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.576 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.03%
# 123
# Epoch: 124 | Epoch Time: 0m 0s
# 	Train Loss: 0.012 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.655 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.08%
# 124
# Epoch: 125 | Epoch Time: 0m 0s
# 	Train Loss: 0.012 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.504 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 70.11%
# 125
# Epoch: 126 | Epoch Time: 0m 0s
# 	Train Loss: 0.011 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.643 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.15%
# 126
# Epoch: 127 | Epoch Time: 0m 0s
# 	Train Loss: 0.011 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.538 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.19%
# 127
# Epoch: 128 | Epoch Time: 0m 0s
# 	Train Loss: 0.011 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.605 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.24%
# 128
# Epoch: 129 | Epoch Time: 0m 0s
# 	Train Loss: 0.010 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.596 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.28%
# 129
# Epoch: 130 | Epoch Time: 0m 0s
# 	Train Loss: 0.011 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.618 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.32%
# 130
# Epoch: 131 | Epoch Time: 0m 0s
# 	Train Loss: 0.011 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.503 |  Val. Acc: 73.61 |  Val. macro-avg-f1: 57.22%
# 	 Aver. ACC: 70.35%
# 131
# Epoch: 132 | Epoch Time: 0m 0s
# 	Train Loss: 0.010 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.741 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.39%
# 132
# Epoch: 133 | Epoch Time: 0m 0s
# 	Train Loss: 0.011 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.572 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.43%
# 133
# Epoch: 134 | Epoch Time: 0m 0s
# 	Train Loss: 0.010 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.574 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.47%
# 134
# Epoch: 135 | Epoch Time: 0m 0s
# 	Train Loss: 0.009 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.638 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.50%
# 135
# Epoch: 136 | Epoch Time: 0m 0s
# 	Train Loss: 0.010 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.654 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.54%
# 136
# Epoch: 137 | Epoch Time: 0m 0s
# 	Train Loss: 0.008 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.677 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.58%
# 137
# Epoch: 138 | Epoch Time: 0m 0s
# 	Train Loss: 0.008 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.609 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.62%
# 138
# Epoch: 139 | Epoch Time: 0m 1s
# 	Train Loss: 0.008 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.643 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.65%
# 139
# Epoch: 140 | Epoch Time: 0m 5s
# 	Train Loss: 0.008 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.610 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.69%
# 140
# Epoch: 141 | Epoch Time: 0m 0s
# 	Train Loss: 0.007 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.654 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.72%
# 141
# Epoch: 142 | Epoch Time: 0m 0s
# 	Train Loss: 0.007 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.535 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.76%
# 142
# Epoch: 143 | Epoch Time: 0m 0s
# 	Train Loss: 0.008 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.585 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.79%
# 143
# Epoch: 144 | Epoch Time: 0m 0s
# 	Train Loss: 0.008 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.864 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.83%
# 144
# Epoch: 145 | Epoch Time: 0m 0s
# 	Train Loss: 0.011 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.676 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.86%
# 145
# Epoch: 146 | Epoch Time: 0m 0s
# 	Train Loss: 0.008 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.551 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.90%
# 146
# Epoch: 147 | Epoch Time: 0m 0s
# 	Train Loss: 0.008 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.744 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.93%
# 147
# Epoch: 148 | Epoch Time: 0m 0s
# 	Train Loss: 0.006 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.594 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.96%
# 148
# Epoch: 149 | Epoch Time: 0m 0s
# 	Train Loss: 0.006 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.642 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 70.99%
# 149
# Epoch: 150 | Epoch Time: 0m 0s
# 	Train Loss: 0.006 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.706 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.02%
# 150
# Epoch: 151 | Epoch Time: 0m 0s
# 	Train Loss: 0.006 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.662 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.05%
# 151
# Epoch: 152 | Epoch Time: 0m 0s
# 	Train Loss: 0.006 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.630 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.08%
# 152
# Epoch: 153 | Epoch Time: 0m 0s
# 	Train Loss: 0.006 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.614 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.11%
# 153
# Epoch: 154 | Epoch Time: 0m 0s
# 	Train Loss: 0.006 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.788 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.14%
# 154
# Epoch: 155 | Epoch Time: 0m 0s
# 	Train Loss: 0.006 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.717 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.17%
# 155
# Epoch: 156 | Epoch Time: 0m 0s
# 	Train Loss: 0.005 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.623 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.20%
# 156
# Epoch: 157 | Epoch Time: 0m 0s
# 	Train Loss: 0.005 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.695 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.23%
# 157
# Epoch: 158 | Epoch Time: 0m 0s
# 	Train Loss: 0.005 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.679 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.26%
# 158
# Epoch: 159 | Epoch Time: 0m 0s
# 	Train Loss: 0.005 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.707 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.29%
# 159
# Epoch: 160 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.686 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.32%
# 160
# Epoch: 161 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.677 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.34%
# 161
# Epoch: 162 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.656 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.37%
# 162
# Epoch: 163 | Epoch Time: 0m 0s
# 	Train Loss: 0.005 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.708 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.40%
# 163
# Epoch: 164 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.664 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.42%
# 164
# Epoch: 165 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.802 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.45%
# 165
# Epoch: 166 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.669 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.47%
# 166
# Epoch: 167 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.777 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.50%
# 167
# Epoch: 168 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.690 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.52%
# 168
# Epoch: 169 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.766 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.55%
# 169
# Epoch: 170 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.736 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.57%
# 170
# Epoch: 171 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.727 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.60%
# 171
# Epoch: 172 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.739 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.62%
# 172
# Epoch: 173 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.852 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.64%
# 173
# Epoch: 174 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.688 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.67%
# 174
# Epoch: 175 | Epoch Time: 0m 0s
# 	Train Loss: 0.004 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.840 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.69%
# 175
# Epoch: 176 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.780 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.71%
# 176
# Epoch: 177 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.785 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.74%
# 177
# Epoch: 178 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.743 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.76%
# 178
# Epoch: 179 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.801 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.78%
# 179
# Epoch: 180 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.786 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.80%
# 180
# Epoch: 181 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.741 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.82%
# 181
# Epoch: 182 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.738 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.84%
# 182
# Epoch: 183 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.798 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.87%
# 183
# Epoch: 184 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.802 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.89%
# 184
# Epoch: 185 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.799 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.91%
# 185
# Epoch: 186 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.746 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.93%
# 186
# Epoch: 187 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.796 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.95%
# 187
# Epoch: 188 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.789 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.97%
# 188
# Epoch: 189 | Epoch Time: 0m 1s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.789 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 71.99%
# 189
# Epoch: 190 | Epoch Time: 0m 0s
# 	Train Loss: 0.002 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.755 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 72.01%
# 190
# Epoch: 191 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.782 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 72.03%
# 191
# Epoch: 192 | Epoch Time: 0m 0s
# 	Train Loss: 0.002 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.759 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 72.04%
# 192
# Epoch: 193 | Epoch Time: 0m 0s
# 	Train Loss: 0.003 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.772 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 72.06%
# 193
# Epoch: 194 | Epoch Time: 0m 0s
# 	Train Loss: 0.002 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.768 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 72.08%
# 194
# Epoch: 195 | Epoch Time: 0m 0s
# 	Train Loss: 0.002 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.782 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 72.10%
# 195
# Epoch: 196 | Epoch Time: 0m 0s
# 	Train Loss: 0.002 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.793 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 72.12%
# 196
# Epoch: 197 | Epoch Time: 0m 0s
# 	Train Loss: 0.002 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.820 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 72.14%
# 197
# Epoch: 198 | Epoch Time: 0m 0s
# 	Train Loss: 0.002 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.794 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 72.16%
# 198
# Epoch: 199 | Epoch Time: 0m 0s
# 	Train Loss: 0.002 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.819 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 72.17%
# 199
# Epoch: 200 | Epoch Time: 0m 0s
# 	Train Loss: 0.002 | Train Acc: 100.00 | Train macro-avg-f1: 100.00%
# 	 Val. Loss: 1.805 |  Val. Acc: 75.69 |  Val. macro-avg-f1: 57.80%
# 	 Aver. ACC: 72.19%
# 0
# Test Loss: 7.573 | Test Acc: 56.25 | Test macro-avg-f1: 55.56%
# 	 Aver. TEST ACC: 56.25%
# 1
# Test Loss: 2.300 | Test Acc: 56.25 | Test macro-avg-f1: 55.56%
# 	 Aver. TEST ACC: 56.25%
# 2
# Test Loss: 0.686 | Test Acc: 56.25 | Test macro-avg-f1: 55.56%
# 	 Aver. TEST ACC: 56.25%
# 3
# Test Loss: 0.686 | Test Acc: 56.25 | Test macro-avg-f1: 55.56%
# 	 Aver. TEST ACC: 56.25%
# 4
# Test Loss: 0.688 | Test Acc: 56.25 | Test macro-avg-f1: 55.56%
# 	 Aver. TEST ACC: 56.25%
# 5
# Test Loss: 0.751 | Test Acc: 43.75 | Test macro-avg-f1: 23.33%
# 	 Aver. TEST ACC: 54.17%
# 6
# Test Loss: 0.718 | Test Acc: 43.75 | Test macro-avg-f1: 23.33%
# 	 Aver. TEST ACC: 52.68%
# 7
# Test Loss: 0.684 | Test Acc: 56.25 | Test macro-avg-f1: 55.56%
# 	 Aver. TEST ACC: 53.12%
# 8
# Test Loss: 0.688 | Test Acc: 56.25 | Test macro-avg-f1: 55.56%
# 	 Aver. TEST ACC: 53.47%
# 9
# Test Loss: 0.693 | Test Acc: 43.75 | Test macro-avg-f1: 23.33%
# 	 Aver. TEST ACC: 52.50%
# 10
# Test Loss: 0.684 | Test Acc: 56.25 | Test macro-avg-f1: 55.56%
# 	 Aver. TEST ACC: 52.84%
# 11
# Test Loss: 0.684 | Test Acc: 56.25 | Test macro-avg-f1: 55.56%
# 	 Aver. TEST ACC: 53.12%
# 12
# Test Loss: 0.694 | Test Acc: 43.75 | Test macro-avg-f1: 23.33%
# 	 Aver. TEST ACC: 52.40%
# 13
# Test Loss: 0.688 | Test Acc: 59.13 | Test macro-avg-f1: 35.10%
# 	 Aver. TEST ACC: 52.88%
# 14
# Test Loss: 0.678 | Test Acc: 56.25 | Test macro-avg-f1: 55.56%
# 	 Aver. TEST ACC: 53.11%
# 15
# Test Loss: 0.702 | Test Acc: 43.75 | Test macro-avg-f1: 23.33%
# 	 Aver. TEST ACC: 52.52%
# 16
# Test Loss: 0.674 | Test Acc: 56.25 | Test macro-avg-f1: 55.56%
# 	 Aver. TEST ACC: 52.74%
# 17
# Test Loss: 0.700 | Test Acc: 43.75 | Test macro-avg-f1: 23.33%
# 	 Aver. TEST ACC: 52.24%
# 18
# Test Loss: 0.671 | Test Acc: 70.67 | Test macro-avg-f1: 53.21%
# 	 Aver. TEST ACC: 53.21%
# 19
# Test Loss: 0.672 | Test Acc: 55.29 | Test macro-avg-f1: 32.71%
# 	 Aver. TEST ACC: 53.32%
# 20
# Test Loss: 0.646 | Test Acc: 59.38 | Test macro-avg-f1: 59.22%
# 	 Aver. TEST ACC: 53.61%
# 21
# Test Loss: 0.639 | Test Acc: 74.52 | Test macro-avg-f1: 54.76%
# 	 Aver. TEST ACC: 54.56%
# 22
# Test Loss: 0.612 | Test Acc: 75.00 | Test macro-avg-f1: 73.33%
# 	 Aver. TEST ACC: 55.45%
# 23
# Test Loss: 0.591 | Test Acc: 59.38 | Test macro-avg-f1: 59.22%
# 	 Aver. TEST ACC: 55.61%
# 24
# Test Loss: 0.555 | Test Acc: 83.65 | Test macro-avg-f1: 57.33%
# 	 Aver. TEST ACC: 56.73%
# 25
# Test Loss: 0.531 | Test Acc: 74.52 | Test macro-avg-f1: 54.76%
# 	 Aver. TEST ACC: 57.41%
# 26
# Test Loss: 0.504 | Test Acc: 74.52 | Test macro-avg-f1: 54.76%
# 	 Aver. TEST ACC: 58.05%
# 27
# Test Loss: 0.449 | Test Acc: 89.90 | Test macro-avg-f1: 63.74%
# 	 Aver. TEST ACC: 59.19%
# 28
# Test Loss: 0.425 | Test Acc: 86.78 | Test macro-avg-f1: 56.22%
# 	 Aver. TEST ACC: 60.14%
# 29
# Test Loss: 0.485 | Test Acc: 70.67 | Test macro-avg-f1: 53.21%
# 	 Aver. TEST ACC: 60.49%
# 30
# Test Loss: 0.433 | Test Acc: 74.52 | Test macro-avg-f1: 54.76%
# 	 Aver. TEST ACC: 60.94%
# 31
# Test Loss: 0.373 | Test Acc: 86.78 | Test macro-avg-f1: 56.22%
# 	 Aver. TEST ACC: 61.75%
# 32
# Test Loss: 0.365 | Test Acc: 86.78 | Test macro-avg-f1: 56.22%
# 	 Aver. TEST ACC: 62.51%
# 33
# Test Loss: 0.381 | Test Acc: 82.21 | Test macro-avg-f1: 57.45%
# 	 Aver. TEST ACC: 63.09%
# 34
# Test Loss: 0.376 | Test Acc: 78.37 | Test macro-avg-f1: 56.17%
# 	 Aver. TEST ACC: 63.52%
# 35
# Test Loss: 0.353 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 64.26%
# 36
# Test Loss: 0.355 | Test Acc: 86.06 | Test macro-avg-f1: 58.63%
# 	 Aver. TEST ACC: 64.85%
# 37
# Test Loss: 0.341 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 65.50%
# 38
# Test Loss: 0.340 | Test Acc: 86.06 | Test macro-avg-f1: 58.63%
# 	 Aver. TEST ACC: 66.03%
# 39
# Test Loss: 0.331 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 66.63%
# 40
# Test Loss: 0.337 | Test Acc: 86.06 | Test macro-avg-f1: 58.63%
# 	 Aver. TEST ACC: 67.10%
# 41
# Test Loss: 0.345 | Test Acc: 86.06 | Test macro-avg-f1: 58.63%
# 	 Aver. TEST ACC: 67.55%
# 42
# Test Loss: 0.303 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 68.07%
# 43
# Test Loss: 0.323 | Test Acc: 86.06 | Test macro-avg-f1: 58.63%
# 	 Aver. TEST ACC: 68.48%
# 44
# Test Loss: 0.309 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 68.96%
# 45
# Test Loss: 0.290 | Test Acc: 86.78 | Test macro-avg-f1: 56.22%
# 	 Aver. TEST ACC: 69.35%
# 46
# Test Loss: 0.281 | Test Acc: 86.78 | Test macro-avg-f1: 56.22%
# 	 Aver. TEST ACC: 69.72%
# 47
# Test Loss: 0.343 | Test Acc: 82.21 | Test macro-avg-f1: 57.45%
# 	 Aver. TEST ACC: 69.98%
# 48
# Test Loss: 0.304 | Test Acc: 86.06 | Test macro-avg-f1: 58.63%
# 	 Aver. TEST ACC: 70.31%
# 49
# Test Loss: 0.273 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 70.70%
# 50
# Test Loss: 0.270 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 71.07%
# 51
# Test Loss: 0.322 | Test Acc: 89.18 | Test macro-avg-f1: 63.72%
# 	 Aver. TEST ACC: 71.42%
# 52
# Test Loss: 0.272 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 71.77%
# 53
# Test Loss: 0.294 | Test Acc: 86.06 | Test macro-avg-f1: 58.63%
# 	 Aver. TEST ACC: 72.04%
# 54
# Test Loss: 0.254 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 72.36%
# 55
# Test Loss: 0.260 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 72.67%
# 56
# Test Loss: 0.271 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 72.98%
# 57
# Test Loss: 0.254 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 73.27%
# 58
# Test Loss: 0.240 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 73.55%
# 59
# Test Loss: 0.237 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 73.82%
# 60
# Test Loss: 0.367 | Test Acc: 85.34 | Test macro-avg-f1: 62.54%
# 	 Aver. TEST ACC: 74.01%
# 61
# Test Loss: 0.267 | Test Acc: 89.18 | Test macro-avg-f1: 63.72%
# 	 Aver. TEST ACC: 74.26%
# 62
# Test Loss: 0.287 | Test Acc: 89.18 | Test macro-avg-f1: 63.72%
# 	 Aver. TEST ACC: 74.49%
# 63
# Test Loss: 0.219 | Test Acc: 89.90 | Test macro-avg-f1: 59.71%
# 	 Aver. TEST ACC: 74.73%
# 64
# Test Loss: 0.386 | Test Acc: 85.34 | Test macro-avg-f1: 62.54%
# 	 Aver. TEST ACC: 74.90%
# 65
# Test Loss: 0.310 | Test Acc: 85.34 | Test macro-avg-f1: 62.54%
# 	 Aver. TEST ACC: 75.05%
# 66
# Test Loss: 0.283 | Test Acc: 89.18 | Test macro-avg-f1: 63.72%
# 	 Aver. TEST ACC: 75.27%
# 67
# Test Loss: 0.319 | Test Acc: 85.34 | Test macro-avg-f1: 62.54%
# 	 Aver. TEST ACC: 75.41%
# 68
# Test Loss: 0.281 | Test Acc: 89.18 | Test macro-avg-f1: 63.72%
# 	 Aver. TEST ACC: 75.61%
# 69
# Test Loss: 0.304 | Test Acc: 89.18 | Test macro-avg-f1: 63.72%
# 	 Aver. TEST ACC: 75.81%
# 70
# Test Loss: 0.233 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 76.05%
# 71
# Test Loss: 0.223 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 76.29%
# 72
# Test Loss: 0.303 | Test Acc: 89.18 | Test macro-avg-f1: 63.72%
# 	 Aver. TEST ACC: 76.46%
# 73
# Test Loss: 0.238 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 76.69%
# 74
# Test Loss: 0.184 | Test Acc: 93.03 | Test macro-avg-f1: 68.07%
# 	 Aver. TEST ACC: 76.90%
# 75
# Test Loss: 0.262 | Test Acc: 89.18 | Test macro-avg-f1: 63.72%
# 	 Aver. TEST ACC: 77.07%
# 76
# Test Loss: 0.203 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 77.27%
# 77
# Test Loss: 0.188 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 77.47%
# 78
# Test Loss: 0.176 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 77.67%
# 79
# Test Loss: 0.206 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 77.86%
# 80
# Test Loss: 0.224 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 78.05%
# 81
# Test Loss: 0.272 | Test Acc: 89.18 | Test macro-avg-f1: 63.72%
# 	 Aver. TEST ACC: 78.19%
# 82
# Test Loss: 0.208 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 78.37%
# 83
# Test Loss: 0.245 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 78.54%
# 84
# Test Loss: 0.187 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 78.71%
# 85
# Test Loss: 0.214 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 78.88%
# 86
# Test Loss: 0.225 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 79.04%
# 87
# Test Loss: 0.249 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 79.20%
# 88
# Test Loss: 0.236 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 79.35%
# 89
# Test Loss: 0.265 | Test Acc: 89.18 | Test macro-avg-f1: 63.72%
# 	 Aver. TEST ACC: 79.46%
# 90
# Test Loss: 0.210 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 79.61%
# 91
# Test Loss: 0.178 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 79.76%
# 92
# Test Loss: 0.197 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 79.90%
# 93
# Test Loss: 0.207 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 80.04%
# 94
# Test Loss: 0.184 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 80.18%
# 95
# Test Loss: 0.204 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 80.31%
# 96
# Test Loss: 0.215 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 80.44%
# 97
# Test Loss: 0.190 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 80.57%
# 98
# Test Loss: 0.203 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 80.70%
# 99
# Test Loss: 0.202 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 80.82%
# 100
# Test Loss: 0.185 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 80.94%
# 101
# Test Loss: 0.269 | Test Acc: 89.18 | Test macro-avg-f1: 63.72%
# 	 Aver. TEST ACC: 81.02%
# 102
# Test Loss: 0.215 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 81.14%
# 103
# Test Loss: 0.184 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 81.25%
# 104
# Test Loss: 0.188 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 81.36%
# 105
# Test Loss: 0.238 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 81.47%
# 106
# Test Loss: 0.188 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 81.58%
# 107
# Test Loss: 0.238 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 81.69%
# 108
# Test Loss: 0.268 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 81.79%
# 109
# Test Loss: 0.163 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 81.89%
# 110
# Test Loss: 0.236 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 81.99%
# 111
# Test Loss: 0.208 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 82.09%
# 112
# Test Loss: 0.178 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 82.19%
# 113
# Test Loss: 0.235 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 82.29%
# 114
# Test Loss: 0.197 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 82.38%
# 115
# Test Loss: 0.187 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 82.47%
# 116
# Test Loss: 0.199 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 82.56%
# 117
# Test Loss: 0.199 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 82.65%
# 118
# Test Loss: 0.236 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 82.74%
# 119
# Test Loss: 0.219 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 82.82%
# 120
# Test Loss: 0.194 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 82.91%
# 121
# Test Loss: 0.208 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 82.99%
# 122
# Test Loss: 0.211 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.07%
# 123
# Test Loss: 0.242 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.15%
# 124
# Test Loss: 0.185 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.23%
# 125
# Test Loss: 0.236 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.31%
# 126
# Test Loss: 0.191 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.39%
# 127
# Test Loss: 0.212 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.46%
# 128
# Test Loss: 0.203 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.53%
# 129
# Test Loss: 0.203 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.61%
# 130
# Test Loss: 0.167 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.68%
# 131
# Test Loss: 0.248 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.75%
# 132
# Test Loss: 0.186 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.82%
# 133
# Test Loss: 0.186 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.89%
# 134
# Test Loss: 0.211 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 83.96%
# 135
# Test Loss: 0.214 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.02%
# 136
# Test Loss: 0.221 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.09%
# 137
# Test Loss: 0.193 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.15%
# 138
# Test Loss: 0.205 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.22%
# 139
# Test Loss: 0.196 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.28%
# 140
# Test Loss: 0.213 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.34%
# 141
# Test Loss: 0.174 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.40%
# 142
# Test Loss: 0.187 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.46%
# 143
# Test Loss: 0.287 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.52%
# 144
# Test Loss: 0.212 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.58%
# 145
# Test Loss: 0.173 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.64%
# 146
# Test Loss: 0.242 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.70%
# 147
# Test Loss: 0.188 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.75%
# 148
# Test Loss: 0.202 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.81%
# 149
# Test Loss: 0.223 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.86%
# 150
# Test Loss: 0.206 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.92%
# 151
# Test Loss: 0.192 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 84.97%
# 152
# Test Loss: 0.189 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.02%
# 153
# Test Loss: 0.244 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.08%
# 154
# Test Loss: 0.215 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.13%
# 155
# Test Loss: 0.185 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.18%
# 156
# Test Loss: 0.207 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.23%
# 157
# Test Loss: 0.198 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.28%
# 158
# Test Loss: 0.216 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.33%
# 159
# Test Loss: 0.209 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.37%
# 160
# Test Loss: 0.203 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.42%
# 161
# Test Loss: 0.195 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.47%
# 162
# Test Loss: 0.210 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.51%
# 163
# Test Loss: 0.194 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.56%
# 164
# Test Loss: 0.235 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.61%
# 165
# Test Loss: 0.187 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.65%
# 166
# Test Loss: 0.223 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.69%
# 167
# Test Loss: 0.193 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.74%
# 168
# Test Loss: 0.219 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.78%
# 169
# Test Loss: 0.209 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.82%
# 170
# Test Loss: 0.203 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.87%
# 171
# Test Loss: 0.206 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.91%
# 172
# Test Loss: 0.243 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.95%
# 173
# Test Loss: 0.184 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 85.99%
# 174
# Test Loss: 0.233 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.03%
# 175
# Test Loss: 0.212 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.07%
# 176
# Test Loss: 0.214 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.11%
# 177
# Test Loss: 0.200 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.15%
# 178
# Test Loss: 0.221 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.19%
# 179
# Test Loss: 0.213 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.22%
# 180
# Test Loss: 0.200 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.26%
# 181
# Test Loss: 0.198 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.30%
# 182
# Test Loss: 0.218 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.34%
# 183
# Test Loss: 0.218 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.37%
# 184
# Test Loss: 0.219 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.41%
# 185
# Test Loss: 0.204 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.44%
# 186
# Test Loss: 0.220 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.48%
# 187
# Test Loss: 0.220 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.51%
# 188
# Test Loss: 0.217 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.55%
# 189
# Test Loss: 0.207 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.58%
# 190
# Test Loss: 0.213 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.62%
# 191
# Test Loss: 0.203 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.65%
# 192
# Test Loss: 0.205 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.68%
# 193
# Test Loss: 0.204 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.72%
# 194
# Test Loss: 0.206 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.75%
# 195
# Test Loss: 0.210 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.78%
# 196
# Test Loss: 0.217 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.81%
# 197
# Test Loss: 0.208 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.84%
# 198
# Test Loss: 0.215 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.87%
# 199
# Test Loss: 0.209 | Test Acc: 93.03 | Test macro-avg-f1: 64.80%
# 	 Aver. TEST ACC: 86.91%
# <br/>Waiting for W&B process to finish, PID 53790... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>Average TEST Acc</td><td>▂▁▁▁▁▂▃▃▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇████████████</td></tr><tr><td>Average Val. Acc</td><td>▃▂▁▁▂▂▃▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇███████████</td></tr><tr><td>Max TEST Acc</td><td>▁▁▁▂▄▆▇▇▇▇▇▇▇▇██████████████████████████</td></tr><tr><td>Max Val Acc</td><td>▁▁▁▁▃▆██████████████████████████████████</td></tr><tr><td>Test accuracy</td><td>▃▁▃▁▅▅▇█▇▇▇█▇▇██▇███▇███████████████████</td></tr><tr><td>Test loss</td><td>█▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Test macro-avg-f1</td><td>▆▃▂▁▁▂▃▃▄▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇███████████</td></tr><tr><td>Val. accuracy</td><td>▄▁▄▁▆▆█▆▇█▇▆▇▇▆▆▇▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>Val. loss</td><td>█▂▁▁▁▁▁▁▂▁▂▂▂▃▃▃▄▄▄▄▅▅▅▅▅▅▅▅▆▅▆▅▅▆▆▆▆▆▆▆</td></tr><tr><td>Val. macro-avg-f1</td><td>▄▁▄▁▄▄█▅▆█▆▆▇▇▆▆▇▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>Average TEST Acc</td><td>0.86905</td></tr><tr><td>Average Val. Acc</td><td>0.72191</td></tr><tr><td>Max TEST Acc</td><td>0.93029</td></tr><tr><td>Max Val Acc</td><td>0.82639</td></tr><tr><td>Test accuracy</td><td>0.93029</td></tr><tr><td>Test loss</td><td>0.20946</td></tr><tr><td>Test macro-avg-f1</td><td>0.61353</td></tr><tr><td>Val. accuracy</td><td>0.75694</td></tr><tr><td>Val. loss</td><td>1.80529</td></tr><tr><td>Val. macro-avg-f1</td><td>0.57796</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">Ivermectin_domain_312</strong>: <a href="https://wandb.ai/lawrencexu/Project2_joint/runs/2o9uuwac" target="_blank">https://wandb.ai/lawrencexu/Project2_joint/runs/2o9uuwac</a><br/>
# Find logs at: <code>./wandb/run-20220411_205204-2o9uuwac/logs</code><br/>
