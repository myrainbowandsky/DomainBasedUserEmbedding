# %%
#!/usr/bin/env python
# encoding: utf-8
#from scipy.spatial.distance import cdist
from nltk import bigrams
import networkx as nx
#similarity score concat before fc1 
import tldextract
from itertools import combinations
from shutil import which
import torch.nn.functional as F
from statistics import mean


from gensim.models import KeyedVectors
from cleantext import clean
from tqdm import tqdm
from nltk.tokenize import TweetTokenizer
import preprocessor as p 
import numpy as np

import torch
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import LongformerModel, LongformerTokenizer, LongformerConfig
from tqdm import tqdm
tqdm.pandas(desc="my bar!")
import pandas as pd 
import numpy as np 
from collections import defaultdict
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import time
#import wandb
#import numpy as np
from pprint import pprint


from nltk.corpus import stopwords
import preprocessor as p  #pip install tweet-preprocessor
import logging  # Setting up the loggings to monitor gensim
from nltk.stem import WordNetLemmatizer
from string import punctuation as punc

import gensim
import gensim.corpora as corpora
#from gensim.utils import simple_preprocess
import gensim.models as gsm



import emoji #pip install emoji --upgrade
# Internal dependencies


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd
import torchvision.transforms as transforms
from torch.autograd import Variable

import os
import torch.multiprocessing as mp
import torchvision.transforms as transforms


#os.environ['CUDA_VISIBLE_DEVICES'] = '1, 2, 3' 
#....to install apex...
#pip install -v --no-cache-dir ./

#!/usr/bin/env python
# encoding: utf-8
import time
import torch.optim as optim
from torch.utils.data import TensorDataset, random_split
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
#from torchnlp.nn import Attention #pip imstall pytorch-nlp

from gensim.models import KeyedVectors
#from fastnode2vec import Graph, Node2Vec
import pandas as pd
import networkx as nx
import os

from torch.utils.data import TensorDataset, random_split
from cleantext import clean
from tqdm import tqdm
from nltk.tokenize import TweetTokenizer
import preprocessor as p 
import numpy as np
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from transformers import LongformerModel, LongformerTokenizer, LongformerConfig
from tqdm import tqdm
tqdm.pandas(desc="my bar!")
import pandas as pd 
import numpy as np 
from collections import defaultdict

from sklearn.model_selection import train_test_split
import datetime
import matplotlib.pyplot as plt
import time
#import numpy as np
from pprint import pprint

from nltk.corpus import stopwords
import preprocessor as p  #pip install tweet-preprocessor
import logging  # Setting up the loggings to monitor gensim
from nltk.stem import WordNetLemmatizer
from string import punctuation as punc

import gensim
import gensim.corpora as corpora
#from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import gensim.models as gsm
from gensim.test.utils import datapath

import regex 
#pip install emoji --upgrade
# Internal dependencies



import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd
import torchvision.transforms as transforms
from torch.autograd import Variable

import os
import torch.multiprocessing as mp
import torchvision.transforms as transforms
import torch.distributed as dist

from urllib.parse import urlparse
import tldextract
# Out:
# Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.
# /opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
#   return f(*args, **kwds)
# /opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
#   return f(*args, **kwds)
# /opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
#   return f(*args, **kwds)
# /opt/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
#   return f(*args, **kwds)

# %%
#os.environ['CUDA_VISIBLE_DEVICES'] = '1, 2, 3' 
#....to install apex...
#pip install -v --no-cache-dir ./

def extract_domain(x):
    '''
    e.g. x='http://www.bbc.co.uk'
    '''
    ext = tldextract.extract(x)
    return ext.registered_domain

def retrieveRTMT(_df,n2vRT,n2vMT):
    '''
    #_names: nodes' name in RT or MT network
    '''
    
    dfRT=pd.DataFrame(n2vRT.wv.vectors,index=n2vRT.wv.index2entity)
    dfMT=pd.DataFrame(n2vMT.wv.vectors,index=n2vMT.wv.index2entity)
    RT=dfRT[dfRT.index.isin(_df['user_screen_name'])].values
    MT=dfMT[dfMT.index.isin(_df['user_screen_name'])].values
    
    
    RT=torch.tensor(RT)
    MT=torch.tensor(MT)
    return RT, MT

def prepro(ndf,col):
    
    import re
    def remove_rt(query):
        query=re.sub(r"\brt", "", query)
        return query
    ndf[col]=ndf[col].progress_apply(lambda x: remove_rt(x))

    def tokenizer(_text):
        return TweetTokenizer().tokenize(_text)

    ndf[col]=ndf[col].progress_apply(lambda x:tokenizer(x))

    from nltk.corpus import stopwords
    STOPWORDS=stopwords.words('english')
    def remove_stop(_text):
        return ' '.join([x for x in _text if x not in STOPWORDS])

    ndf[col]=ndf[col].progress_apply(lambda x: remove_stop(x))
    
    def preprocessing(string): 

        text=clean(string,lower=True, no_emails=True,no_numbers=True,no_punct=True,no_digits=False,no_currency_symbols=True,
                   replace_with_number="",
                   no_urls=True,replace_with_url="",
                   replace_with_email="",
                   replace_with_currency_symbol="")

        return text
    ndf[col]=ndf[col].progress_apply(lambda x: preprocessing(x))
    
    def remove_emoji(string):
        p.set_options(p.OPT.EMOJI, p.OPT.SMILEY)
        
        return p.clean(string)
    ndf[col]=ndf[col].progress_apply(lambda x: remove_emoji(x))
    
    ndf.reset_index(inplace=True,drop=True)
    return ndf

torch.manual_seed(1)
torch.cuda.manual_seed(1)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.enabled = False
np.random.seed(1)


def makefolder(save):
    if  os.path.exists(save) == False:
        os.makedirs(save)
    else:
        print('Floder:',save,'Exsit!')
    return save
def get_intersection(_df,_intersecion):
    for each  in ['source','target']:

        _df=_df[_df[each].isin(_intersecion)]
    return _df

def fast_node2vec(_df,_save,_file,saving_name,epochs):
    '''
    _df:retweetdf,mentiondf
    _save:saving folder path
    _file:csv name, e.g., vaccine, mask
    saving_name: RT or MT
    '''
    
    _tuples=_df.to_records(index=False)

    _lst=list(_tuples)

    _graph = Graph(_lst, directed=True, weighted=True)

    _n2v = Node2Vec(_graph, dim=300, walk_length=100, context=10, p=2.0, q=0.5, workers=-1)
    
    _n2v.train(epochs=epochs)

    _n2v.wv.save(_save+_file+'_'+saving_name+'.wv')
    return _n2v

def updatecol(df1,df2,colname,index):
    df1[colname]=''

    df1.set_index(index,inplace=True)

    df2.set_index(index,inplace=True)

    df1.update(df2)

    df1.reset_index(inplace=True)
    df2.reset_index(inplace=True)
    return df1

def updatecol_seperate(df1,df2,colname,index1,index2):
    df1[colname]=''

    df1.set_index(index1,inplace=True)

    df2.set_index(index2,inplace=True)

    df1.update(df2)

    df1.reset_index(inplace=True)
    df2.reset_index(inplace=True)
    return df1



def preproNetwork(_df,nettype,topn,Need,_name):
    '''
    target: 'retweeted_status_screen_name' or 'user_mentions_screen_names'
    return topn indegree dataframe
    _name: QAnon or Biden
    '''
    if nettype=='RT':
        target= 'retweeted_status_screen_name' 
    elif nettype=='MT':
        target= 'user_mentions_screen_names'
        
    file=_name
    save='../Project2/'+file+'_data_processed/'
    makefolder(save)
        
    #_df=_df.rename(columns={'user_screen_name':'users'})
    _df=_df[['user_screen_name',target]]
    _df.dropna(subset=[target],inplace=True)
    _df[target]=_df[target].str.replace('\'','')
    _df[target]=_df[target].apply(lambda x: x.split(','))
    _df=_df.explode([target])
    _df=_df[['user_screen_name',target]]
    #_df.columns=['source','target']
    
    
    _df=_df.explode([target])
    
    G=nx.from_pandas_edgelist(_df,source='user_screen_name',target=target,create_using=nx.DiGraph())

    nx.write_gexf(G, save+nettype+ '.gexf')
    mdf=pd.DataFrame(G.in_degree)
    mdf.columns=['Allusers','indegree']
    kdf=mdf.sort_values('indegree',ascending=False).head(topn)
    kdf.to_csv('../Project2/QAnon_data_processed/top'+str(topn)+nettype+'indegree.csv',index=None)
    #print(_df.columns)
    #print(kdf.columns)
    ndf=updatecol_seperate(_df,kdf,'indegree','user_screen_name','Allusers')
    ldf=ndf[ndf['indegree']!='']
    ldf['indegree']=ldf['indegree'].astype(int)
    ldf=ldf.sort_values('indegree',ascending=False)
    
    #produce node2vec
    if Need==True:
        __df=_df.groupby(['user_screen_name',target]).size().reset_index()
        __df=__df.rename(columns={0:'weight'})
        n2v=fast_node2vec(__df, save, file+'_'+nettype+'_weighted',nettype,500)
    else:
        n2v=None
    return ldf, n2v

def rank_indegree(_df1,_indegree,usertypes,rank):
    _df1p=updatecol_seperate(_df1,_indegree,'indegree',usertypes[rank],'user_screen_name')
    _df1p['indegree']=pd.to_numeric(_df1p['indegree'])
    #df1p['indegree']=df1p['indegree'].astype(int)
    _df1p=_df1p.sort_values('indegree',ascending=False).drop_duplicates(usertypes[rank])
    #print(df1p.shape)
    return _df1p


def get_textdf(_df):
    #_df=_df[['user_screen_name','text','news']]
    #_df=_df.groupby(by='user_screen_name').agg(text=("text", lambda x: ",".join(set(x))))
    #_df.reset_index(inplace=True)
    
    _t1=_df.groupby(by='user_screen_name').agg(text=("text", lambda x: ",".join(set(x))))

    _t2=_df.groupby(by='user_screen_name').agg(news=("news", lambda x: ",".join(set(x))))
    
    _t1['news']=''
    
    _t1.update(_t2)
    
    _t1.reset_index(inplace=True)
    return _t1

class cos_feature:
    def __init__(self, text, news):
        self.long_roberta = long_roberta
        self.text = text
        self.news = news

    def cos_similarity(self):

        with torch.no_grad():
            embedding = self.long_roberta(self.text)[0]
        return embedding

    def emb_similarity(self):

        emb1 = self.cos_similarity(self.text)
        emb2 = self.cos_similarity(self.news)
        emb1 = emb1.cpu().detach().numpy()
        emb2  = emb2.cpu().detach().numpy()
        print('tweet:',emb1.shape)
        print('news:', emb2.shape)
        Y = cdist(emb1[0], emb2[0], 'cosine')[0][0]
        cos_sim = 1.0 - Y
        print('similarity:',cos_sim)
        return cos_sim

class ROBERTALSTMSentiment(nn.Module):
        def __init__(self,
                    long_roberta,
                    hidden_dim,
                    output_dim,
                    n_layers,
                    bidirectional,
                    dropout):
            
            super().__init__()
            
            self.long_roberta = long_roberta
            
            embedding_dim = long_roberta.config.to_dict()['hidden_size'] #768
                
            self.rnn = nn.LSTM(embedding_dim,
                            hidden_dim,
                            num_layers = n_layers,
                            bidirectional = bidirectional,
                            batch_first = True,
                            dropout = 0 if n_layers < 2 else dropout)
            self.dropout = nn.Dropout(dropout)
            self.attn_fc = Attention(hidden_dim * 2 if bidirectional else hidden_dim) #attention layer from torchnlp
            self.out = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, output_dim)


        def forward(self, text):
            with torch.no_grad():
                embedded = self.long_roberta(text)[0]
            lstm_out, (hidden, c_n) = self.rnn(embedded)

            if self.rnn.bidirectional: #add dropout
                hidden = self.dropout(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1))
            else:
                hidden = self.dropout(hidden[-1,:,:])
  
            attn_out = self.attn_fc(hidden.unsqueeze(1), lstm_out)
           
            return attn_out[0].squeeze(1)

# Tokenize all of the sentences and map the tokens to thier word IDs.
def token_id_twt(sentences):
        input_ids = []
        attention_masks = []

        # For every sentence...
        for sent in sentences:
            # `encode_plus` will:
            #   (1) Tokenize the sentence.
            #   (2) Prepend the `[CLS]` token to the start.
            #   (3) Append the `[SEP]` token to the end.
            #   (4) Map tokens to their IDs.
            #   (5) Pad or truncate the sentence to `max_length`
            #   (6) Create attention masks for [PAD] tokens.
            encoded_dict = longformer_tokenizer.encode_plus(
                                sent,                      # Sentence to encode.
                                add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                                max_length = 4000,           # Pad & truncate all sentences.
                                pad_to_max_length = True,
                                return_attention_mask = True,   # Construct attn. masks.
                                truncation=True, #explicitely truncate examples to max length. #my add
                                return_tensors = 'pt',     # Return pytorch tensors.
                        )

            # Add the encoded sentence to the list.    
            input_ids.append(encoded_dict['input_ids'])
            #print(type(input_ids[0]), input_ids[0], input_ids[0].size())
            #sys.exit()

            # And its attention mask (simply differentiates padding from non-padding).
            attention_masks.append(encoded_dict['attention_mask'])

        # Convert the lists into tensors.
        input_ids = torch.cat(input_ids, dim=0)
        attention_masks = torch.cat(attention_masks, dim=0)
        #labels = torch.tensor(labels)

    #     # Print sentence 0, now as a list of IDs.
    #     print('Original: ', sentences_train[0])
    #     print('Token IDs:', input_ids_train[0])
        return input_ids, attention_masks

class NetworkMLP(nn.Module):
    def __init__(self):
        super(NetworkMLP, self).__init__() 
        self.fc1 = nn.Linear(300, 150)
            
    def forward(self, X):
        z1 = self.fc1(X)
        return z1 

class JointModel(nn.Module):
    
    def __init__(self,hidden_dim, output_dim, n_layers, bidirectional, dropout):
        super().__init__()
        self.model_net = NetworkMLP()
        self.model_twt = ROBERTALSTMSentiment(long_roberta, HIDDEN_DIM, OUTPUT_DIM, N_LAYERS, BIDIRECTIONAL, DROPOUT)
        self.fc1 = nn.Linear(600, 600)
        self.fc2 = nn.Linear(600, output_dim) #original
        self.dropout = nn.Dropout(dropout)


    def forward(self, x_t): 
        prediction_twt = self.model_twt(x_t)
        #prediction_twtNews = self.model_twt(x_tNews)
       
        #concat_pred = torch.cat((prediction_twt, prediction_twtNews), 1)
        output = self.fc1(prediction_twt)
        
        output = self.dropout(output) # add dropout
        output = self.fc2(F.relu(output)) #original
        #output = self.dropout(output)#add dropout
        #output = self.fc3(F.relu(output))
        return output
        
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def binary_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """

    #round predictions to the closest integer
    #rounded_preds = torch.round(torch.sigmoid(preds))
    #rounded_preds = torch.round(preds)
    correct = (preds == y).float() #convert into float for division 
    acc = correct.sum() / len(correct)
    
    from sklearn.metrics import f1_score
    macro_f1 = f1_score(y.to("cpu"), preds.to("cpu"), average='macro')
    #print("macro_f1", macro_f1)

    return acc, macro_f1


def train(model, iterator, optimizer, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    epoch_macro = 0
    model.train()
    for step, batch in enumerate(iterator):    
    #for batch in iterator:
        #print("batch", batch)
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        #   b_input_ids = batch[0].to(device)
        #   b_input_mask = batch[1].to(device)
        #   b_labels = batch[2].to(device)

        optimizer.zero_grad()
        
        #netRT = batch[0].to(device)
        #netMT = batch[1].to(device)
        #feature1=batch[0]
        #print('feature1:',feature1)
        #feature2=batch[1]
        #cosine_score=emb_similarity(feature1, feature2)
        #cosine_score_view=cosine_score.view(cosine_score.size()[0],1)

        twt = batch[0].to(device)
        #news= batch[1].to(device)

        #print('text.size:',twt.size())
        #print('news.size:',news.size())

        #cosine_similarity=cosine_similarity.to(device)
        label = batch[1].to(device)

        #print("label", label, type(label),label.size()) #torch.Size([32])
        #label = label.unsqueeze(1)
        #print("label", label, type(label),label.size())
        #predictions = model(batch.text).squeeze(1)
        #predictions = model(text)
        predictions = model(twt)#,cosine_similarity)

        #cosine_score_view=cosine_score.view(cosine_score.size()[0],1)



        #print('cosine_similarity.size:',cosine_score.size())
        #predictions=torch.cat((predictions,cosine_score_view), dim = 1)
        #print('predictions.size:',predictions.size())
        loss = criterion(predictions, label)
    
        acc, macro_f1 = binary_accuracy(torch.argmax(predictions, dim = 1), label)

        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        epoch_macro += macro_f1.item()
    return epoch_loss / len(iterator), epoch_acc / len(iterator), epoch_macro / len(iterator)

def evaluate(model, iterator, criterion):
    epoch_loss = 0
    epoch_acc = 0
    epoch_macro = 0
    model.eval()
    
    with torch.no_grad():
    
        #for batch in iterator:
        for step, batch in enumerate(iterator):    
            #des = batch[0].to(device)
            #loc = batch[1].to(device)
            #netRT = batch[0].to(device)
            #netMT = batch[1].to(device)
            twt = batch[0].to(device)
            #news= batch[1].to(devifce)
            label = batch[1].to(device)
            #predictions = model(batch.text).squeeze(1)
            predictions = model(twt)
            #loss = criterion(predictions, batch.label)
            loss = criterion(predictions, label)
            #acc = binary_accuracy(predictions, batch.label)
            acc, macro_f1 = binary_accuracy(torch.argmax(predictions, dim = 1), label)
            epoch_loss += loss.item()
            epoch_acc += acc.item()
            epoch_macro += macro_f1.item()
    return epoch_loss / len(iterator), epoch_acc / len(iterator), epoch_macro / len(iterator)


def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

def save_plots(train_losses, val_losses, train_f1, val_f1, train_accs, val_accs,test_accs,test_f1s):
    """Plot

        Plot two figures: loss vs. epoch and accuracy vs. epoch
    """
    n = len(train_losses)
    xs = np.arange(1,n+1,1)
    xs = xs.astype(int)

    # plot train and val losses
    fig, ax = plt.subplots()
    ax.plot(xs, train_losses, '--', linewidth=2, label='train loss')
    ax.plot(xs, val_losses, '-', linewidth=2, label='validation loss')
    #ax.set_xlim(0, 10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend(loc='upper right')
    plt.savefig('../Project2/figs/'+savingname+'_Loss.png')

    # plot train and val f1-score
    #plt.clf()
    fig, ax = plt.subplots()
    ax.plot(xs, train_f1, '--', linewidth=2, label='train')
    ax.plot(xs, val_f1, '-', linewidth=2, label='validation')
    ax.plot(xs, test_f1s, '-', linewidth=2, label='test')
    
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Macro-avg F1")
    ax.legend(loc='lower right')
    plt.savefig('../Project2/figs/'+savingname+'_Macro-avgF1.png')
    
    # plot train and val accuracy
    #plt.clf()
    fig, ax = plt.subplots()
    ax.plot(xs, train_accs, '--', linewidth=2, label='train')
    ax.plot(xs, val_accs, '-', linewidth=2, label='validation')
    ax.plot(xs, test_accs, '-', linewidth=2, label='test')
    #ax.set_xlim(0, 10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Accuracy")
    ax.legend(loc='lower right')
    plt.savefig('../Project2/figs/'+savingname+'_ACC.png')

def extract_domain(x):
    '''
    e.g. x='http://www.bbc.co.uk'
    '''
    ext = tldextract.extract(x)
    return ext.registered_domain




def obtain_users(_df):
    
    _df['domain'] = _df['urls'].apply(lambda x: extract_domain(x))
    ndf = _df[_df['domain']!='']
    #non-credible domains https://iffy.news/index/
    data1=pd.read_csv('../Project2/domain/data.csv')
    ndf1=ndf[ndf['domain'].isin(data1['Domain'])]
    data0=pd.read_csv('../Project2/domain/cre.csv')
    ndf0=ndf[ndf['domain'].isin(data0['domain'])]
    nndf=pd.concat([ndf0,ndf1])
    lst0=ndf0.user_screen_name.tolist()
    lst1=ndf1.user_screen_name.tolist()
    _users=list(set(nndf['user_screen_name']))
    
    return _users

if __name__ == '__main__':
    
    
        name1 , name2 = 'The Democratic','The Publican'
        #if (name1 != 'badbots') | (name2 != 'badhumans'):
        print('name1:',name1)
        print('name2:',name2)
        #name1='badbots'
        #name2='badhumans'#'badhumans'#'goodbots'
        smaller_sample = 500
        batch_size = 16
        savingname='degreeRank'+name1+'VS'+name2+'_QAnon_TEXT_weighted_directed_batch'+str(batch_size)+'violinIndex'+'TokenLength>30'+'Token=4000'
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        print('Training')
        print('Device:',device)
        which_time = 0
        N_EPOCHS = 10
        HIDDEN_DIM = 300 
        OUTPUT_DIM = 3
        N_LAYERS = 2
        BIDIRECTIONAL = True
        DROPOUT = 0.5 

        #news.columns=['original_url','resolved_url','news','domain']
        #news.to_csv('../Project2/biden/BidenNews.csv',index=None)
        #news=pd.read_csv('../Project2/biden/BidenNews.csv')
        ndf=gf=df=pd.read_csv('../Project2/biden/biden_selected.csv')
        ndf.dropna(subset=['text'],inplace=True)
        #tem=pd.read_csv('../Project3/gf.csv')
        #tem.drop_duplicates(subset=['user_screen_name'],inplace=True)
        modularity=pd.read_csv('../Project2/biden/biden_networkx.csv')
        modularity=modularity.rename(columns={'Id':'user_screen_name'})
        
        #news=news[news['news']!='']
        #news['domain'] = news['resolved_url'].apply(lambda x: extract_domain(x))
        #badwords=["Please click here if you are not redirected","That’s an error.\n\nWe're sorry","This page appears when Google automatically","Sorry, the page you're looking for cannot be","Forbidden\n\nYou don't","ERROR_NEWS","Not Found\n\n","Subscribe\n\nGet the","We've detected you are on","You are here » Home » New Search"]

        #for each in tqdm(badwords):
        #    news=news[~news['news'].str.contains(each)]
        #    print(news.shape)
        #news['tokens']=news['news'].str.split()
        #print(news[news['tokens'].str.len()>10].shape)
        #news=news[news['tokens'].str.len()>30]
        #print('# of length of news >30',news.shape)

        usertypes=['user_screen_name','retweeted_status_screen_name','user_mentions_screen_names']
        rank=0
        topn=1000000
        
        #ndf=updatecol(ndf,tem,'cap.english','user_screen_name')
        
        ndf=updatecol(ndf,modularity,'modularity_class','user_screen_name')
        
        #news.drop_duplicates(subset=['original_url'],inplace=True)
        
        #ndf =updatecol_seperate(ndf,news,'domain','urls','original_url')
        
        #ndf =updatecol_seperate(ndf,news,'news','urls','original_url')
        
        #ndf.to_csv('../Project2/biden/biden_metadata.csv',index=None)
        
        

        usersp=obtain_users(ndf)
        
        ndf = ndf[ndf['user_screen_name'].isin(usersp)]
        
        
        
        #所有users
        #ndf['cap.english'] = pd.to_numeric(ndf['cap.english'])
        #ddf=ndf[ndf['cap.english']>0.7]
        
        nodes1=ndf[ndf['modularity_class']==38]['user_screen_name'].drop_duplicates().tolist()#democrat
        nodes2=ndf[ndf['modularity_class']==52]['user_screen_name'].drop_duplicates().tolist()#republics

        df1=ndf[ndf['user_screen_name'].isin(nodes1)]
        df2=ndf[ndf['user_screen_name'].isin(nodes2)]

        print(name1+' with democratic users:',len(set(df1[usertypes[rank]])))
        print(name2+' with republican users:',len(set(df2[usertypes[rank]])))
        
        print(df1.columns)


        #df1=get_textdf(df1)
        #df2=get_textdf(df2)
        
        
        df1['labels']=1#democrat
        df2['labels']=0#republics
        
        
        
            
        num_lst=[500,name2,name1]
        Nums=[smaller_sample, len(set(df2[usertypes[rank]])), len(set(df1[usertypes[rank]]))]
        num = min(Nums)
        print(num_lst[Nums.index(num)],' is the smallest!')
        
        
        # when we have news we use this part
        df1p=rank_indegree(df1,modularity,usertypes,rank)
        df1p=df1p.head(num)
        #df1p=prepro(df1p,'news')
        #df1p=prepro(df1p,'text')
        
        
        
        df2=rank_indegree(df2,modularity,usertypes,rank)
        df2=df2.head(num)
        #df2=prepro(df2,'news')
        #df2=prepro(df2,'text')
        
        kdf=df=pd.concat([df1p,df2])
        print('Processing finished!')
        
        
        # when we do not have news:
        #kdf = pd.concat([df1,df2])
# Out:
# name1: The Democratic
# name2: The Publican
# Training
# Device: cpu
# The Democratic with democratic users: 79422
# The Publican with republican users: 61501
# Index(['user_screen_name', 'created_at', 'retweeted_status_screen_name',
#        'text', 'urls', 'hashtags', 'modularity_class', 'domain'],
#       dtype='object')
# 500  is the smallest!
# /Users/lawrencexu/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:771: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/lawrencexu/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:772: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/lawrencexu/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/lawrencexu/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py:7511: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = expressions.where(mask, this, that)
# /Users/lawrencexu/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:332: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Processing finished!

# %%
#os.environ['CUDA_VISIBLE_DEVICES'] = '1, 2, 3' 
#....to install apex...
#pip install -v --no-cache-dir ./
from nltk import bigrams
import networkx as nx
def extract_domain(x):
    '''
    e.g. x='http://www.bbc.co.uk'
    '''
    ext = tldextract.extract(x)
    return ext.registered_domain

def retrieveRTMT(_df,n2vRT,n2vMT):
    '''
    #_names: nodes' name in RT or MT network
    '''
    
    dfRT=pd.DataFrame(n2vRT.wv.vectors,index=n2vRT.wv.index2entity)
    dfMT=pd.DataFrame(n2vMT.wv.vectors,index=n2vMT.wv.index2entity)
    RT=dfRT[dfRT.index.isin(_df['user_screen_name'])].values
    MT=dfMT[dfMT.index.isin(_df['user_screen_name'])].values
    
    
    RT=torch.tensor(RT)
    MT=torch.tensor(MT)
    return RT, MT

def prepro(ndf,col):
    
    import re
    def remove_rt(query):
        query=re.sub(r"\brt", "", query)
        return query
    ndf[col]=ndf[col].progress_apply(lambda x: remove_rt(x))

    def tokenizer(_text):
        return TweetTokenizer().tokenize(_text)

    ndf[col]=ndf[col].progress_apply(lambda x:tokenizer(x))

    from nltk.corpus import stopwords
    STOPWORDS=stopwords.words('english')
    def remove_stop(_text):
        return ' '.join([x for x in _text if x not in STOPWORDS])

    ndf[col]=ndf[col].progress_apply(lambda x: remove_stop(x))
    
    def preprocessing(string): 

        text=clean(string,lower=True, no_emails=True,no_numbers=True,no_punct=True,no_digits=False,no_currency_symbols=True,
                   replace_with_number="",
                   no_urls=True,replace_with_url="",
                   replace_with_email="",
                   replace_with_currency_symbol="")

        return text
    ndf[col]=ndf[col].progress_apply(lambda x: preprocessing(x))
    
    def remove_emoji(string):
        p.set_options(p.OPT.EMOJI, p.OPT.SMILEY)
        
        return p.clean(string)
    ndf[col]=ndf[col].progress_apply(lambda x: remove_emoji(x))
    
    ndf.reset_index(inplace=True,drop=True)
    return ndf

torch.manual_seed(1)
torch.cuda.manual_seed(1)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.enabled = False
np.random.seed(1)


def makefolder(save):
    if  os.path.exists(save) == False:
        os.makedirs(save)
    else:
        print('Floder:',save,'Exsit!')
    return save
def get_intersection(_df,_intersecion):
    for each  in ['source','target']:

        _df=_df[_df[each].isin(_intersecion)]
    return _df

def fast_node2vec(_df,_save,_file,saving_name,epochs):
    '''
    _df:retweetdf,mentiondf
    _save:saving folder path
    _file:csv name, e.g., vaccine, mask
    saving_name: RT or MT
    '''
    
    _tuples=_df.to_records(index=False)

    _lst=list(_tuples)

    _graph = Graph(_lst, directed=True, weighted=True)

    _n2v = Node2Vec(_graph, dim=300, walk_length=100, context=10, p=2.0, q=0.5, workers=-1)
    
    _n2v.train(epochs=epochs)

    _n2v.wv.save(_save+_file+'_'+saving_name+'.wv')
    return _n2v

def updatecol(df1,df2,colname,index):
    df1[colname]=''

    df1.set_index(index,inplace=True)

    df2.set_index(index,inplace=True)

    df1.update(df2)

    df1.reset_index(inplace=True)
    df2.reset_index(inplace=True)
    return df1

def updatecol_seperate(df1,df2,colname,index1,index2):
    df1[colname]=''

    df1.set_index(index1,inplace=True)

    df2.set_index(index2,inplace=True)

    df1.update(df2)

    df1.reset_index(inplace=True)
    df2.reset_index(inplace=True)
    return df1



def preproNetwork(_df,nettype,topn,Need,_name):
    '''
    target: 'retweeted_status_screen_name' or 'user_mentions_screen_names'
    return topn indegree dataframe
    _name: QAnon or Biden
    '''
    if nettype=='RT':
        target= 'retweeted_status_screen_name' 
    elif nettype=='MT':
        target= 'user_mentions_screen_names'
        
    file=_name
    save='../Project2/'+file+'_data_processed/'
    makefolder(save)
        
    #_df=_df.rename(columns={'user_screen_name':'users'})
    _df=_df[['user_screen_name',target]]
    _df.dropna(subset=[target],inplace=True)
    _df[target]=_df[target].str.replace('\'','')
    _df[target]=_df[target].apply(lambda x: x.split(','))
    _df=_df.explode([target])
    _df=_df[['user_screen_name',target]]
    #_df.columns=['source','target']
    
    
    _df=_df.explode([target])
    
    G=nx.from_pandas_edgelist(_df,source='user_screen_name',target=target,create_using=nx.DiGraph())

    nx.write_gexf(G, save+nettype+ '.gexf')
    mdf=pd.DataFrame(G.in_degree)
    mdf.columns=['Allusers','indegree']
    kdf=mdf.sort_values('indegree',ascending=False).head(topn)
    kdf.to_csv('../Project2/QAnon_data_processed/top'+str(topn)+nettype+'indegree.csv',index=None)
    #print(_df.columns)
    #print(kdf.columns)
    ndf=updatecol_seperate(_df,kdf,'indegree','user_screen_name','Allusers')
    ldf=ndf[ndf['indegree']!='']
    ldf['indegree']=ldf['indegree'].astype(int)
    ldf=ldf.sort_values('indegree',ascending=False)
    
    #produce node2vec
    if Need==True:
        __df=_df.groupby(['user_screen_name',target]).size().reset_index()
        __df=__df.rename(columns={0:'weight'})
        n2v=fast_node2vec(__df, save, file+'_'+nettype+'_weighted',nettype,500)
    else:
        n2v=None
    return ldf, n2v

def rank_indegree(_df1,_indegree,usertypes,rank):
    _df1p=updatecol_seperate(_df1,_indegree,'indegree',usertypes[rank],'user_screen_name')
    _df1p['indegree']=pd.to_numeric(_df1p['indegree'])
    #df1p['indegree']=df1p['indegree'].astype(int)
    _df1p=_df1p.sort_values('indegree',ascending=False).drop_duplicates(usertypes[rank])
    #print(df1p.shape)
    return _df1p


def get_textdf(_df):
    #_df=_df[['user_screen_name','text','news']]
    #_df=_df.groupby(by='user_screen_name').agg(text=("text", lambda x: ",".join(set(x))))
    #_df.reset_index(inplace=True)
    
    _t1=_df.groupby(by='user_screen_name').agg(text=("text", lambda x: ",".join(set(x))))

    _t2=_df.groupby(by='user_screen_name').agg(news=("news", lambda x: ",".join(set(x))))
    
    _t1['news']=''
    
    _t1.update(_t2)
    
    _t1.reset_index(inplace=True)
    return _t1

class cos_feature:
    def __init__(self, text, news):
        self.long_roberta = long_roberta
        self.text = text
        self.news = news

    def cos_similarity(self):

        with torch.no_grad():
            embedding = self.long_roberta(self.text)[0]
        return embedding

    def emb_similarity(self):

        emb1 = self.cos_similarity(self.text)
        emb2 = self.cos_similarity(self.news)
        emb1 = emb1.cpu().detach().numpy()
        emb2  = emb2.cpu().detach().numpy()
        print('tweet:',emb1.shape)
        print('news:', emb2.shape)
        Y = cdist(emb1[0], emb2[0], 'cosine')[0][0]
        cos_sim = 1.0 - Y
        print('similarity:',cos_sim)
        return cos_sim

class ROBERTALSTMSentiment(nn.Module):
        def __init__(self,
                    long_roberta,
                    hidden_dim,
                    output_dim,
                    n_layers,
                    bidirectional,
                    dropout):
            
            super().__init__()
            
            self.long_roberta = long_roberta
            
            embedding_dim = long_roberta.config.to_dict()['hidden_size'] #768
                
            self.rnn = nn.LSTM(embedding_dim,
                            hidden_dim,
                            num_layers = n_layers,
                            bidirectional = bidirectional,
                            batch_first = True,
                            dropout = 0 if n_layers < 2 else dropout)
            self.dropout = nn.Dropout(dropout)
            self.attn_fc = Attention(hidden_dim * 2 if bidirectional else hidden_dim) #attention layer from torchnlp
            self.out = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, output_dim)


        def forward(self, text):
            with torch.no_grad():
                embedded = self.long_roberta(text)[0]
            lstm_out, (hidden, c_n) = self.rnn(embedded)

            if self.rnn.bidirectional: #add dropout
                hidden = self.dropout(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1))
            else:
                hidden = self.dropout(hidden[-1,:,:])
  
            attn_out = self.attn_fc(hidden.unsqueeze(1), lstm_out)
           
            return attn_out[0].squeeze(1)

# Tokenize all of the sentences and map the tokens to thier word IDs.
def token_id_twt(sentences):
        input_ids = []
        attention_masks = []

        # For every sentence...
        for sent in sentences:
            # `encode_plus` will:
            #   (1) Tokenize the sentence.
            #   (2) Prepend the `[CLS]` token to the start.
            #   (3) Append the `[SEP]` token to the end.
            #   (4) Map tokens to their IDs.
            #   (5) Pad or truncate the sentence to `max_length`
            #   (6) Create attention masks for [PAD] tokens.
            encoded_dict = longformer_tokenizer.encode_plus(
                                sent,                      # Sentence to encode.
                                add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                                max_length = 4000,           # Pad & truncate all sentences.
                                pad_to_max_length = True,
                                return_attention_mask = True,   # Construct attn. masks.
                                truncation=True, #explicitely truncate examples to max length. #my add
                                return_tensors = 'pt',     # Return pytorch tensors.
                        )

            # Add the encoded sentence to the list.    
            input_ids.append(encoded_dict['input_ids'])
            #print(type(input_ids[0]), input_ids[0], input_ids[0].size())
            #sys.exit()

            # And its attention mask (simply differentiates padding from non-padding).
            attention_masks.append(encoded_dict['attention_mask'])

        # Convert the lists into tensors.
        input_ids = torch.cat(input_ids, dim=0)
        attention_masks = torch.cat(attention_masks, dim=0)
        #labels = torch.tensor(labels)

    #     # Print sentence 0, now as a list of IDs.
    #     print('Original: ', sentences_train[0])
    #     print('Token IDs:', input_ids_train[0])
        return input_ids, attention_masks

class NetworkMLP(nn.Module):
    def __init__(self):
        super(NetworkMLP, self).__init__() 
        self.fc1 = nn.Linear(300, 150)
            
    def forward(self, X):
        z1 = self.fc1(X)
        return z1 

class JointModel(nn.Module):
    
    def __init__(self,hidden_dim, output_dim, n_layers, bidirectional, dropout):
        super().__init__()
        self.model_net = NetworkMLP()
        self.model_twt = ROBERTALSTMSentiment(long_roberta, HIDDEN_DIM, OUTPUT_DIM, N_LAYERS, BIDIRECTIONAL, DROPOUT)
        self.fc1 = nn.Linear(600, 600)
        self.fc2 = nn.Linear(600, output_dim) #original
        self.dropout = nn.Dropout(dropout)


    def forward(self, x_t): 
        prediction_twt = self.model_twt(x_t)
        #prediction_twtNews = self.model_twt(x_tNews)
       
        #concat_pred = torch.cat((prediction_twt, prediction_twtNews), 1)
        output = self.fc1(prediction_twt)
        
        output = self.dropout(output) # add dropout
        output = self.fc2(F.relu(output)) #original
        #output = self.dropout(output)#add dropout
        #output = self.fc3(F.relu(output))
        return output
        
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def binary_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """

    #round predictions to the closest integer
    #rounded_preds = torch.round(torch.sigmoid(preds))
    #rounded_preds = torch.round(preds)
    correct = (preds == y).float() #convert into float for division 
    acc = correct.sum() / len(correct)
    
    from sklearn.metrics import f1_score
    macro_f1 = f1_score(y.to("cpu"), preds.to("cpu"), average='macro')
    #print("macro_f1", macro_f1)

    return acc, macro_f1


def train(model, iterator, optimizer, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    epoch_macro = 0
    model.train()
    for step, batch in enumerate(iterator):    
    #for batch in iterator:
        #print("batch", batch)
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        #   b_input_ids = batch[0].to(device)
        #   b_input_mask = batch[1].to(device)
        #   b_labels = batch[2].to(device)

        optimizer.zero_grad()
        
        #netRT = batch[0].to(device)
        #netMT = batch[1].to(device)
        #feature1=batch[0]
        #print('feature1:',feature1)
        #feature2=batch[1]
        #cosine_score=emb_similarity(feature1, feature2)
        #cosine_score_view=cosine_score.view(cosine_score.size()[0],1)

        twt = batch[0].to(device)
        #news= batch[1].to(device)

        #print('text.size:',twt.size())
        #print('news.size:',news.size())

        #cosine_similarity=cosine_similarity.to(device)
        label = batch[1].to(device)

        #print("label", label, type(label),label.size()) #torch.Size([32])
        #label = label.unsqueeze(1)
        #print("label", label, type(label),label.size())
        #predictions = model(batch.text).squeeze(1)
        #predictions = model(text)
        predictions = model(twt)#,cosine_similarity)

        #cosine_score_view=cosine_score.view(cosine_score.size()[0],1)



        #print('cosine_similarity.size:',cosine_score.size())
        #predictions=torch.cat((predictions,cosine_score_view), dim = 1)
        #print('predictions.size:',predictions.size())
        loss = criterion(predictions, label)
    
        acc, macro_f1 = binary_accuracy(torch.argmax(predictions, dim = 1), label)

        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        epoch_macro += macro_f1.item()
    return epoch_loss / len(iterator), epoch_acc / len(iterator), epoch_macro / len(iterator)

def evaluate(model, iterator, criterion):
    epoch_loss = 0
    epoch_acc = 0
    epoch_macro = 0
    model.eval()
    
    with torch.no_grad():
    
        #for batch in iterator:
        for step, batch in enumerate(iterator):    
            #des = batch[0].to(device)
            #loc = batch[1].to(device)
            #netRT = batch[0].to(device)
            #netMT = batch[1].to(device)
            twt = batch[0].to(device)
            #news= batch[1].to(devifce)
            label = batch[1].to(device)
            #predictions = model(batch.text).squeeze(1)
            predictions = model(twt)
            #loss = criterion(predictions, batch.label)
            loss = criterion(predictions, label)
            #acc = binary_accuracy(predictions, batch.label)
            acc, macro_f1 = binary_accuracy(torch.argmax(predictions, dim = 1), label)
            epoch_loss += loss.item()
            epoch_acc += acc.item()
            epoch_macro += macro_f1.item()
    return epoch_loss / len(iterator), epoch_acc / len(iterator), epoch_macro / len(iterator)


def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

def save_plots(train_losses, val_losses, train_f1, val_f1, train_accs, val_accs,test_accs,test_f1s):
    """Plot

        Plot two figures: loss vs. epoch and accuracy vs. epoch
    """
    n = len(train_losses)
    xs = np.arange(1,n+1,1)
    xs = xs.astype(int)

    # plot train and val losses
    fig, ax = plt.subplots()
    ax.plot(xs, train_losses, '--', linewidth=2, label='train loss')
    ax.plot(xs, val_losses, '-', linewidth=2, label='validation loss')
    #ax.set_xlim(0, 10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend(loc='upper right')
    plt.savefig('../Project2/figs/'+savingname+'_Loss.png')

    # plot train and val f1-score
    #plt.clf()
    fig, ax = plt.subplots()
    ax.plot(xs, train_f1, '--', linewidth=2, label='train')
    ax.plot(xs, val_f1, '-', linewidth=2, label='validation')
    ax.plot(xs, test_f1s, '-', linewidth=2, label='test')
    
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Macro-avg F1")
    ax.legend(loc='lower right')
    plt.savefig('../Project2/figs/'+savingname+'_Macro-avgF1.png')
    
    # plot train and val accuracy
    #plt.clf()
    fig, ax = plt.subplots()
    ax.plot(xs, train_accs, '--', linewidth=2, label='train')
    ax.plot(xs, val_accs, '-', linewidth=2, label='validation')
    ax.plot(xs, test_accs, '-', linewidth=2, label='test')
    #ax.set_xlim(0, 10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Accuracy")
    ax.legend(loc='lower right')
    plt.savefig('../Project2/figs/'+savingname+'_ACC.png')

def bihashtagGraph(_wdf0,topic,_i):
    terms_bigram = [list(bigrams(tweet)) for tweet in _wdf0['hashtags']]
    d=[x for x in terms_bigram if x!=[]]
    lst=[]
    for each in d:
        if len(each)==0:
            lst.append(each)
        else:
            [lst.append(x) for x in each]

    hadf=pd.DataFrame(lst)

    K=nx.from_pandas_edgelist(hadf,0,1)

    nx.write_gexf(K,'../Project2/'+topic+'/'+str(_i)+'.gexf')
    return hadf,K

if __name__ == '__main__':
        name1 , name2 = 'badbots','goodbots'
        topic = 'biden'
        #if (name1 != 'badbots') | (name2 != 'badhumans'):
        print('name1:',name1)
        print('name2:',name2)
        #name1='badbots'
        #name2='badhumans'#'badhumans'#'goodbots'
        smaller_sample = 500
        batch_size = 16
        savingname='degreeRank'+name1+'VS'+name2+'_biden_TEXT_weighted_directed_batch'+str(batch_size)+'violinIndex'+'TokenLength>30'+'Token=4000'
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        print('Training')
        print('Device:',device)
        which_time = 0
        N_EPOCHS = 10
        HIDDEN_DIM = 300 
        OUTPUT_DIM = 3
        N_LAYERS = 2
        BIDIRECTIONAL = True
        DROPOUT = 0.5 

        #news.columns=['original_url','resolved_url','news','domain']
        #news.to_csv('../Project2/biden/BidenNews.csv',index=None)
        #news=pd.read_csv('../Project2/biden/BidenNews.csv')
        #news=news[news['news']!='']
        #news['domain'] = news['resolved_url'].apply(lambda x: extract_domain(x))
        #badwords=["Please click here if you are not redirected","That’s an error.\n\nWe're sorry","This page appears when Google automatically","Sorry, the page you're looking for cannot be","Forbidden\n\nYou don't","ERROR_NEWS","Not Found\n\n","Subscribe\n\nGet the","We've detected you are on","You are here » Home » New Search"]

        #for each in tqdm(badwords):
        #    news=news[~news['news'].str.contains(each)]
        #    print(news.shape)
        #news['tokens']=news['news'].str.split()
        #print(news[news['tokens'].str.len()>10].shape)
        #news=news[news['tokens'].str.len()>30]
        #print('# of length of news >30',news.shape)

        #usertypes=['user_screen_name','retweeted_status_screen_name','user_mentions_screen_names']
        #rank=0
        #topn=1000000
        #n2vRT = KeyedVectors.load('../Project2/QAnon_data_processed/QAnon_RT_weighted_RT.wv')
        #n2vMT = KeyedVectors.load('../Project2/QAnon_data_processed/QAnon_MT_weighted_MT.wv')

        #indegree=pd.read_csv('../Project2/QAnon_data_processed/top'+str(topn)+'RT'+'indegree.csv')
        ndf=gf=df=pd.read_csv('../Project2/biden/biden_selected.csv')
        ndf=ndf[ndf['hashtags'].notna()]
        ndf['hashtags']=ndf['hashtags'].str.replace('\'','')

        ndf['hashtags']=ndf['hashtags'].str.lower()
        ndf['hashtags']=ndf['hashtags'].str.replace(' ','')
        ndf['hashtags']=ndf['hashtags'].str.split(',')


        hdf,G=bihashtagGraph(ndf,topic,'biden_hashtag')
        

        
        
        
        '''#ndf.reset_index(inplace=True)
        
        tem=pd.read_csv('../Project3/gf.csv')
        tem.drop_duplicates(subset=['user_screen_name'],inplace=True)
        
        modularity=pd.read_csv('../Project2/biden/biden_networkx.csv')
        modularity=modularity.rename(columns={'Id':'user_screen_name'})
        
        
        ndf=updatecol(ndf,tem,'cap.english','user_screen_name')
        
        ndf=updatecol(ndf,modularity,'modularity_class','user_screen_name')
        
        news.drop_duplicates(subset=['original_url'],inplace=True)
        
        ndf =updatecol_seperate(ndf,news,'domain','urls','original_url')
        
        ndf =updatecol_seperate(ndf,news,'news','urls','original_url')
        
        #ndf.to_csv('../Project2/biden/biden_metadata.csv',index=None)
        
        
        
        
        #nodes1=pd.read_csv('../Project2/QAnon_data_processed/'+name1+'_QAnon_news_users.csv')['user_screen_name']#pd.read_csv('../Project2/QAnon_data_processed/badbots_QAnon_news_users.csv')['user_screen_name']
        #nodes2=pd.read_csv('../Project2/QAnon_data_processed/'+name2+'_QAnon_news_users.csv')['user_screen_name']#pd.read_csv('../Project2/QAnon_data_processed/badhumans_QAnon_news_users.csv')['user_screen_name']
        ndf['cap.english'] = pd.to_numeric(ndf['cap.english'])
        ddf=ndf[ndf['cap.english']>0.7]
        nodes1=ddf[ddf['modularity_class']==38]['user_screen_name'].drop_duplicates().tolist()#democrat
        nodes2=ddf[ddf['modularity_class']==52]['user_screen_name'].drop_duplicates().tolist()#republics

        df1=ddf[ddf['user_screen_name'].isin(nodes1)]
        df2=ddf[ddf['user_screen_name'].isin(nodes2)]

        print(name1+' with democratic users:',len(set(df1[usertypes[rank]])))
        print(name2+' with republican users:',len(set(df2[usertypes[rank]])))


        df1=get_textdf(df1)
        df2=get_textdf(df2)
        
        df1['labels']=1#democrat
        df2['labels']=0#republics
        
        
        num_lst=[500,name2,name1]
        Nums=[smaller_sample, len(set(df2[usertypes[rank]])), len(set(df1[usertypes[rank]]))]
        num = min(Nums)
        print(num_lst[Nums.index(num)],' is the smallest!')
        
        
        # when we have news we use this part
        df1p=rank_indegree(df1,modularity,usertypes,rank)
        df1p=df1p.head(num)
        df1p=prepro(df1p,'news')
        df1p=prepro(df1p,'text')
        
        
        
        df2=rank_indegree(df2,modularity,usertypes,rank)
        df2=df2.head(num)
        df2=prepro(df2,'news')
        df2=prepro(df2,'text')
        
        kdf=df=pd.concat([df1p,df2])
        print('Processing finished!')
        
        
        # when we do not have news:
        #kdf = pd.concat([df1,df2])
        '''
# Out:
# name1: badbots
# name2: goodbots
# Training
# Device: cpu
# /Users/lawrencexu/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:575: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/lawrencexu/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:577: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/lawrencexu/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:578: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/lawrencexu/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:579: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
1+1
# Out:
# 2

# %%
from fastnode2vec import Graph, Node2Vec
def fast_node2vec(_df):
    '''
    _df:retweetdf,mentiondf
    _save:saving folder path
    _file:csv name, e.g., vaccine, mask
    saving_name: RT or MT
    '''
    
    _tuples=_df.to_records(index=False)

    _lst=list(_tuples)

    _graph = Graph(_lst, directed=False, weighted=False)

    _n2v = Node2Vec(_graph, dim=300, walk_length=100, context=10, p=2.0, q=0.5, workers=-1)
    
    _n2v.train(epochs=300)

    
    return _n2v

# %%
model=fast_node2vec(hdf)
# Out:
# Reading graph: 100%|██████████| 835738/835738 [00:03<00:00, 233529.49it/s]
# Training: 100%|██████████| 18425100/18425100 [01:51<00:00, 165448.07it/s]

# %%
model.wv.save('../Project2/biden/hashtag_co_occurrence_n2v.wv')
model= KeyedVectors.load('../Project2/biden/hashtag_co_occurrence_n2v.wv')

# %%
def convert_vec(x):
    
        if len(x)==0:
            return model.get_vector(x[0])
        else:
            try:
                _lst= [model.get_vector(y) for y in x]
                _sum=0
                for each in _lst:
                    _sum=_sum+each
                return _sum
            except Exception as e:
                print(e)
            return None

# %%
ndf['hashtags']=ndf['hashtags'].apply(lambda x: ','.join(x))
# Out:
# /Users/lawrencexu/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ndf0=ndf.groupby(by='user_screen_name').agg(hashtags=("hashtags", lambda x: ",".join(set(x)))).reset_index()

# %%
ndf0['hashtags']=ndf0['hashtags'].str.split(',')

# %%
#ndf0.groupby(['user_screen_name','hashtags'])['hashtags'].apply(list).reset_index(name='new')

#ndf1=ndf0.groupby(['user_screen_name'])['hashtags'].apply(list).reset_index()
#ndf1.shape

# %%
ndf0['vec']=ndf0['hashtags'].apply(lambda x: convert_vec(x))
# Out:
# "Key 'titumorning' not present"
# "Key 'ccspig' not present"
# "Key '10decretospresidecialesdebiden' not present"
# "Key 'openinternet' not present"
# "Key 'datomonitor' not present"
# "Key 'likebiden' not present"
# "Key 'redwave22' not present"
# "Key 'ñametwitter' not present"
# "Key 'thebuzz' not present"
# "Key 'higherself' not present"
# "Key 'morningrushatl' not present"
# "Key 'everylifemattered' not present"
# "Key 'intro12y2' not present"
# "Key 'jimjordanisuseless' not present"
# "Key 'pagsparody' not present"
# "Key 'drzekeemaunuel' not present"
# "Key 'no_to_biden' not present"
# "Key 'summitnews' not present"
# "Key 'divert' not present"
# "Key 'firstamaskthenamark' not present"
# "Key 'hispantv' not present"
# "Key 'redwave22' not present"
# "Key 'boycottbidentonight' not present"
# "Key '19threpresents' not present"
# "Key 'tonedeaftom' not present"
# "Key 'holywordexpo' not present"
# "Key 'idonttrusttrump' not present"
# "Key 'prodeathgop' not present"
# "Key 'americanmarxist' not present"
# "Key 'kingtundeed' not present"
# "Key 'trumpbomboozledpresident' not present"
# "Key 'biden20202' not present"
# "Key 'tf' not present"
# "Key 'removechinafronun' not present"
# "Key 'intellectualgenocide' not present"
# "Key 'wpa' not present"
# "Key 'bafoon' not present"
# "Key 'covidhell' not present"
# "Key 'virusrally' not present"
# "Key 'noticiasbbc' not present"
# "Key 'americanresueplan' not present"
# "Key 'votejoefortheeconomy' not present"
# "Key 'captbrettcrozier' not present"
# "Key '45wasrightagain' not present"
# "Key 'worldpopulation' not present"
# "Key 'bidenquemalteveo' not present"
# "Key 'whereyoubeen' not present"
# "Key 'bigpharmagate' not present"
# "Key 'fox59morning' not present"
# "Key 'kimmel' not present"
# "Key 'joestupidbiden' not present"
# "Key 'daddydonny' not present"
# "Key '45fb6330ede75b7a82e6bba5dfc470d6' not present"
# "Key 'gop2012' not present"
# "Key 'illegitimateimpeachedpresident' not present"
# "Key 'becausewebsitematters' not present"
# "Key 'bumblesbiden' not present"
# "Key '6percent' not present"
# "Key 'makeamericacaliforniaagain' not present"
# "Key 'remembebiden' not present"
# "Key 'трамп' not present"
# "Key 'trumppresidencyisover' not present"
# "Key 'amoral' not present"
# "Key 'trumpkillsteachers' not present"
# "Key 'lowlife_degenerate' not present"
# "Key '6minutos' not present"
# "Key 'trumpbetrayedourtroops' not present"
# "Key 'propogandapotus' not present"
# "Key 'viraltime' not present"
# "Key 'socialistdemocrat' not present"
# "Key 'marksimone' not present"
# "Key 'sharethevaccine' not present"
# "Key 'asgarideyangınvar' not present"
# "Key 'bumblesbiden' not present"
# "Key 'joedontknow' not present"
# "Key 'explain2020' not present"
# "Key 'multistem' not present"
# "Key 'cancelkimmel' not present"
# "Key 'innovativeexpresscare' not present"
# "Key 'kazofmupdates' not present"
# "Key 'bidendidnotwin' not present"
# "Key 'dumprepublicans2020' not present"
# "Key 'developing' not present"
# "Key 'warmonger' not present"
# "Key 'scipol' not present"
# "Key 'aarcoinforma' not present"
# "Key 'bidn' not present"
# "Key 'newsomatnoon' not present"
# "Key 'rememberlelanijordan' not present"
# "Key 'freeamerica' not present"
# "Key 'fondationidenticar' not present"
# "Key 'conservativecafeteriacatholics' not present"
# "Key 'notaleaderjustaliberal' not present"
# "Key 'infografía' not present"
# "Key 'faketrumpecomony' not present"
# "Key 'publiced' not present"
# "Key 'superspreadermarjorie' not present"
# "Key '15oct' not present"
# "Key 'proscience' not present"
# "Key 'covid19coverup' not present"
# "Key 'thedailyconsultant' not present"
# "Key 'actionsspeaklouder' not present"
# "Key 'notalltherebiden' not present"
# "Key 'whateverbidendecides' not present"
# "Key 'mediation' not present"
# "Key 'amuqrp' not present"
# "Key 'amxinforma' not present"
# "Key 'marketedge' not present"
# "Key 'hispantv' not present"
# "Key 'vocesysonidos' not present"
# "Key 'sputnikvesesperanza' not present"
# "Key 'drittenwelle' not present"
# "Key 'bbw5' not present"
# "Key 'apfactchecks' not present"
# "Key 'bideninalandslide2020' not present"
# "Key 'joebidenwillhealamerica' not present"
# "Key 'redwave22' not present"
# "Key 'scientificsolutions' not present"
# "Key 'dailypoint' not present"
# "Key 'cyberdigest' not present"
# "Key 'ghoulabbott' not present"
# "Key 'virusrally' not present"
# "Key 'auobedinburghceilidh' not present"
# "Key 'erasingwomen' not present"
# "Key 'aznoticias' not present"
# "Key 'covidsverige' not present"
# "Key 'thisisnotaninsultbut' not present"
# "Key 'bidenharris202o' not present"
# "Key 'gsaemily' not present"
# "Key 'youlie' not present"
# "Key 'nationalmask' not present"
# "Key 'accesolatino' not present"
# "Key 'acenewsdesk' not present"
# "Key 'crowdfunding' not present"
# "Key 'coronavirus_vaccine' not present"
# "Key 'seguridadpública' not present"
# "Key 'audiences' not present"
# "Key 'olympiauniongospelmission' not present"
# "Key 'unfollowbobo' not present"
# "Key 'creepysleepyjoebiden' not present"
# "Key 'claserpm01' not present"
# "Key 'comm225' not present"
# "Key 'sevenout' not present"
# "Key 'covid19hoy' not present"
# "Key 'mockingbirdmedia' not present"
# "Key 'ndigital' not present"
# "Key 'declarationforamericandemocracy' not present"
# "Key 'californiawildfires' not present"
# "Key 'covid19hoy' not present"
# "Key 'covid19hoy' not present"
# "Key 'voiceswithvision' not present"
# "Key 'happynaijablog' not present"
# "Key 'pésaj' not present"
# "Key 'stoptesting' not present"
# "Key 'orangetwittler' not present"
# "Key 'consumerprotection' not present"
# "Key 'fuckivanka' not present"
# "Key 'vanguardnews' not present"
# "Key 'reconciliaciónypaz' not present"
# "Key '𝐍𝐨𝐭𝐢𝐜𝐢𝐚𝐬' not present"
# "Key 'killingoffhisbase' not present"
# "Key 'inspirational' not present"
# "Key 'coronavirusarv' not present"
# "Key 'bigpharmagate' not present"
# "Key 'sir' not present"
# "Key 'enunminuto' not present"
# "Key 'saintvalentin2021' not present"
# "Key 'covidjoebiden' not present"
# "Key 'topblu' not present"
# "Key 'hispantv' not present"
# "Key 'silverstimulus' not present"
# "Key '17feb' not present"
# "Key '4oct' not present"
# "Key 'emergingtech' not present"
# "Key 'traitertrump' not present"
# "Key 'sosmanaus' not present"
# "Key 'tactics' not present"
# "Key 'alertainternacional' not present"
# "Key 'psmfnpu2020' not present"
# "Key 'lovepresidentbiden' not present"
# "Key 'weatherchannel' not present"
# "Key 'pushbidenleft' not present"
# "Key 'fox31now' not present"
# "Key 'ndigital' not present"
# "Key 'coronavirusroundup' not present"
# "Key 'loco' not present"
# "Key 'bidenotrump' not present"
# "Key 'traitortrumpregime' not present"
# "Key 'اقاله_وزير_التعليم' not present"
# "Key 'velshiacrossamerica' not present"
# "Key 'reconciliaciónypaz' not present"
# "Key 'danielgollan' not present"
# "Key 'swampmonsters' not present"
# "Key 'redwave22' not present"
# "Key 'news_allexandredm' not present"
# "Key 'trea45on' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'theartofthedeal' not present"
# "Key 'coronaviruscovid19joebidenvaccineessentialworkers' not present"
# "Key 'bidenterrorists' not present"
# "Key 'alsegundomx' not present"
# "Key 'اوميكرون_قارعه_عالميه' not present"
# "Key 'democratcovidreliefbill' not present"
# "Key 'wrayfbicoverup' not present"
# "Key 'reconciliaciónypaz' not present"
# "Key 'hispantv' not present"
# "Key 'eastla' not present"
# "Key '2020presidentialprimaries' not present"
# "Key 'freezombiebiden' not present"
# "Key 'ambazonia' not present"
# "Key 'firstladybiden' not present"
# "Key 'blackstar' not present"
# "Key 'eviltrump' not present"
# "Key 'fearvirus' not present"
# "Key 'trumpisafool' not present"
# "Key '1764project' not present"
# "Key 'bidendenial' not present"
# "Key 'democratmob' not present"
# "Key 'lsm' not present"
# "Key 'travelbanindia' not present"
# "Key 'twitterisabubble' not present"
# "Key 'freesirousasgari' not present"
# "Key 'trumpvirusdeathtoll160k' not present"
# "Key 'lyinking' not present"
# "Key 'womengetitdone' not present"
# "Key 'closeenough' not present"
# "Key 'joedontknow' not present"
# "Key 'repugnicans' not present"
# "Key 'runjoerun' not present"
# "Key 'vocesysonidos' not present"
# "Key 'vocesysonidos' not present"
# "Key '29abr' not present"
# "Key 'socialsecurityandmedicare' not present"
# "Key 'pakistanday' not present"
# "Key 'trillionspendingbill' not present"
# "Key 'anccom' not present"
# "Key 'oiljoebiden' not present"
# "Key 'usapresidentjoebiden' not present"
# "Key 'prisoners_in_danger' not present"
# "Key 'bidenobamavideo' not present"
# "Key 'slo' not present"
# "Key 'ndigital' not present"
# "Key 'andyvermaut' not present"
# "Key 'trumpregime' not present"
# "Key 'angeleyes' not present"
# "Key 'itsahoax' not present"
# "Key 'joedontknow' not present"
# "Key 'trumpgopbioterrorist' not present"
# "Key 'distributedcampaign' not present"
# "Key 'kumparannews' not present"
# "Key 'futturnauta' not present"
# "Key 'sankalpit' not present"
# "Key 'joedontknow' not present"
# "Key 'joedontknow' not present"
# "Key 'wearamaskny' not present"
# "Key 'inforac1' not present"
# "Key 'trumpexitarv' not present"
# "Key 'trea45on' not present"
# "Key 'joebidenwillhealamerica' not present"
# "Key 'frightenforthosepacked' not present"
# "Key 'getupdc' not present"
# "Key 'anthraxjoe' not present"
# "Key 'hypocrisynews' not present"
# "Key 'vaccineforamerica' not present"
# "Key 'iamvotingforbidenbecause' not present"
# "Key 'redskinsnamechange' not present"
# "Key 'hispantv' not present"
# "Key 'mundiales' not present"
# "Key 'countrysuper' not present"
# "Key 'hispantv' not present"
# "Key 'freedomfr' not present"
# "Key 'escapetoplutotv' not present"
# "Key 'debatetrumpbiden2020' not present"
# "Key '86whitmer' not present"
# "Key 'applenewstoday' not present"
# "Key 'apuntesúltimahora' not present"
# "Key 'selectivememory' not present"
# "Key 'gotrump2020' not present"
# "Key 'focuspress' not present"
# "Key 'day49' not present"
# "Key 'bidensaveslives' not present"
# "Key 'thinkbernievotewarren' not present"
# "Key 'pmfall2020' not present"
# "Key 'bigpharmagate' not present"
# "Key 'brayden' not present"
# "Key 'uspoliticsusnewsworldnewsjoebidencoronavirus' not present"
# "Key 'pureevil' not present"
# "Key 'trumpenfuhrer' not present"
# "Key 'ganobiden' not present"
# "Key 'preschools' not present"
# "Key 'pullingthestrings' not present"
# "Key 'taxnews' not present"
# "Key 'pmjoy' not present"
# "Key 'covidconga' not present"
# "Key 'meindrumpf' not present"
# "Key 'पहला_टीका_मोदी_को' not present"
# "Key 'matriceseconómicas' not present"
# "Key 'nikesatanshoes' not present"
# "Key 'supertuesdayii' not present"
# "Key 'americanfrontlinenurses' not present"
# "Key 'crockofshit' not present"
# "Key 'inviertaconexpertos' not present"
# "Key 'govhalfmast' not present"
# "Key 'assyriansforbiden' not present"
# "Key '2020cosmobiology' not present"
# "Key 'deliriousdonald' not present"
# "Key 'masksoffmaskson' not present"
# "Key 'firedrbirx' not present"
# "Key 'emol' not present"
# "Key 'usss' not present"
# "Key 'fastthinking' not present"
# "Key 'freetestkits' not present"
# "Key 'dunmore' not present"
# "Key 'republicangovs' not present"
# "Key 'impeachmtg' not present"
# "Key 'bolívarespueblo' not present"
# "Key 'offtherails' not present"
# "Key 'wherearethedemocrats' not present"
# "Key 'aurehope' not present"
# "Key 'redwave22' not present"
# "Key 'crazy45' not present"
# "Key 'texasnews' not present"
# "Key 'donaldthecherrypicker' not present"
# "Key 'eveofinauguration' not present"
# "Key 'sameastheoldplan' not present"
# "Key 'inauguraciónbiden' not present"
# "Key 'mondaymorningqb' not present"
# "Key 'patriotsarethrowingthefingteaintheriver' not present"
# "Key 'joebidencalm' not present"
# "Key 'tercerretirosincocina' not present"
# "Key 'trumpplayingtheelectoralcollegegame' not present"
# "Key 'ignore' not present"
# "Key 'joedontknow' not present"
# "Key 'warveterans' not present"
# "Key 'runningforsenator' not present"
# "Key 'impeachedpresidentdonaldjtrump' not present"
# "Key 'lunchtimelive' not present"
# "Key 'americast' not present"
# "Key 'gopfilth' not present"
# "Key 'tnatw' not present"
# "Key 'commuter' not present"
# "Key 'fukkinmagattraitors' not present"
# "Key 'endsanctuarycities' not present"
# "Key 'itstimetotellthetruth' not present"
# "Key 'primaryprevention' not present"
# "Key 'bidenpresidencycurescovid' not present"
# "Key 'yougojoe' not present"
# "Key 'bidensidaresultados' not present"
# "Key '29ene' not present"
# "Key 'batallaporlasaludylavida' not present"
# "Key 'idiotsinthewhitehouse' not present"
# "Key 'creditbailoutbill' not present"
# "Key 'abolition' not present"
# "Key 'joebidenlive' not present"
# "Key 'askbacely' not present"
# "Key 'operationbuildbackbetter' not present"
# "Key 'stuckwithbiden' not present"
# "Key 'realityendorsedbernie' not present"
# "Key 'lambdalambdalambda' not present"
# "Key 'coronavirusroundup' not present"
# "Key 'bigpharmagate' not present"
# "Key 'rockefellerlockstep2010' not present"
# "Key 'ncvoters' not present"
# "Key 'vocesysonidos' not present"
# "Key 'neverpedodementiajoe' not present"
# "Key 'dumblasio' not present"
# "Key 'bidenroits' not present"
# "Key 'redwave22' not present"
# "Key 'bidentrumpchess' not present"
# "Key 'vanguardnews' not present"
# "Key 'coronavirusplandemic' not present"
# "Key 'abolishcitizensunited' not present"
# "Key 'votebidenharristosavedemocracy' not present"
# "Key 'freezombiebiden' not present"
# "Key 'mesainternacional' not present"
# "Key 'reassures' not present"
# "Key 'careact' not present"
# "Key 'bigpharmagate' not present"
# "Key 'joebabrahamlincbiden' not present"
# "Key 'dimwitdonnie' not present"
# "Key 'whoffice4kids' not present"
# "Key 'thankyoupete' not present"
# "Key 'bigpharmagate' not present"
# "Key 'bumblesbiden' not present"
# "Key 'bumblesbiden' not present"
# "Key 'killingamerica' not present"
# "Key 'bidenisdonaldselectionnightmare' not present"
# "Key 'e132fdbedbf25a078f12b826d55a0f2e' not present"
# "Key 'cognitivelythere' not present"
# "Key 'covidiotsincongress' not present"
# "Key 'bigpharmagate' not present"
# "Key 'mentsch' not present"
# "Key 'accelerationism' not present"
# "Key 'bestarticle' not present"
# "Key 'wartimerapper' not present"
# "Key 'vacatintrvl' not present"
# "Key 'goodstart' not present"
# "Key 'buildbackbetterbiopreparedness' not present"
# "Key 'implementbidenplannow' not present"
# "Key 'reconciliaciónypaz' not present"
# "Key 'freedomfr' not present"
# "Key 'mobilemedical' not present"
# "Key 'ourtimenow' not present"
# "Key 'terminalcancer' not present"
# "Key 'dolua' not present"
# "Key 'bidenjokes' not present"
# "Key 'hoaxhate' not present"
# "Key 'hiprimary' not present"
# "Key 'americavstrump' not present"
# "Key 'despicabledems' not present"
# "Key 'courageisbeautiful' not present"
# "Key 'redwave22' not present"
# "Key 'rephermancain' not present"
# "Key 'führerjoebiden' not present"
# "Key 'calljoe' not present"
# "Key 'imho' not present"
# "Key 'americavstrump' not present"
# "Key 'bidenmustquitnow' not present"
# "Key 'americanpeoplevstrump' not present"
# "Key 'bidendeathtracker' not present"
# "Key 'msnbcnn' not present"
# "Key 'ash2020' not present"
# "Key 'quetheshotgunnoise' not present"
# "Key 'hfgmarkets' not present"
# "Key 'bidenbuttigieg2020' not present"
# "Key 'fortherecord' not present"
# "Key 'sciencepolicy' not present"
# "Key 'blockquote' not present"
# "Key 'freedomfr' not present"
# "Key 'hispantv' not present"
# "Key 'readlocal' not present"
# "Key 'foolaid' not present"
# "Key 'stoptesting' not present"
# "Key 'faucityrant' not present"
# "Key 'wuppertal' not present"
# "Key 'maislidas' not present"
# "Key 'mañanasblu' not present"
# "Key 'aficanamerican' not present"
# "Key 'instacartstrike' not present"
# "Key 'eurgbp' not present"
# "Key 'votebidenharristosaveyourlife' not present"
# "Key 'blockquote' not present"
# "Key 'bigpharmagate' not present"
# "Key 'bidenterrorists' not present"
# "Key 'idi' not present"
# "Key 'joedontknow' not present"
# "Key 'bidencannotwin' not present"
# "Key 'bigpharmagate' not present"
# "Key 'strain' not present"
# "Key 'bomdiabrasil' not present"
# "Key 'post3930' not present"
# "Key 'bumblesbiden' not present"
# "Key 'joedontknow' not present"
# "Key 'lalatewhat' not present"
# "Key 'thewuhanvirus' not present"
# "Key 'pollme' not present"
# "Key 'pennsylvaniavotesbidenharris' not present"
# "Key 'covid19negative' not present"
# "Key 'handsoffalexsaab' not present"
# "Key 'whereisjoebidenhiding' not present"
# "Key 'politicalfauci' not present"
# "Key 'cooperativaencasa' not present"
# "Key 'lionmedia' not present"
# "Key 'neolibs' not present"
# "Key 'flashbacktuesday' not present"
# "Key 'moedas' not present"
# "Key 'tuckems' not present"
# "Key '2020stuff' not present"
# "Key 'dropfox' not present"
# "Key 'bumblesbiden' not present"
# "Key 'sentomcotton' not present"
# "Key 'cameltoeharris' not present"
# "Key '200millionvaccines' not present"
# "Key 'liberalarts' not present"
# "Key 'browardcounty' not present"
# "Key 'joesupport2k' not present"
# "Key 'hackerzone9' not present"
# "Key 'wltx' not present"
# "Key 'midiapodre' not present"
# "Key 'bidensfoodcrisis' not present"
# "Key 'breakingkenyanews' not present"
# "Key 'famerica' not present"
# "Key 'armrreport' not present"
# "Key 'replacetrump' not present"
# "Key 'bwcom' not present"
# "Key 'britaintrump' not present"
# "Key 'lyingbbc' not present"
# "Key 'thistimenextyeari' not present"
# "Key 'vge' not present"
# "Key 'trumpvirusdeathtoll238k' not present"
# "Key 'fucktrump2021' not present"
# "Key 'planettrump' not present"
# "Key 'youareeitherwithusoryouareagainstus' not present"
# "Key 'logicfail' not present"
# "Key 'absenteelee' not present"
# "Key 'rncsuperspreader' not present"
# "Key 'bigpharmagate' not present"
# "Key 'fukthegqp' not present"
# "Key 'finreg' not present"
# "Key 'brookingsblueprints' not present"
# "Key 'oshacompliance' not present"
# "Key 'beenadickdonald' not present"
# "Key 'trea45on' not present"
# "Key 'liberalnews' not present"
# "Key 'laziestpresidentever' not present"
# "Key 'stumparepublican' not present"
# "Key 'papadopoulos' not present"
# "Key 'mosen' not present"
# "Key 'roseville' not present"
# "Key 'إيران' not present"
# "Key 'burningitdahn' not present"
# "Key 'buen' not present"
# "Key 'cslive' not present"
# "Key 'reflation' not present"
# "Key 'bidenbows2teachers' not present"
# "Key 'tent' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'gettingshitdonelikearealpresident' not present"
# "Key 'beijengbiden' not present"
# "Key 'alertafake' not present"
# "Key 'vocesysonidos' not present"
# "Key 'señalinformativa' not present"
# "Key 'covidroundsca' not present"
# "Key 'hispantv' not present"
# "Key 'baizuo' not present"
# "Key '4yourmorning' not present"
# "Key 'ctmpodcast' not present"
# "Key 'notnotfakenews' not present"
# "Key 'redwave22' not present"
# "Key 'thursdayafternoon' not present"
# "Key 'nls2021' not present"
# "Key 'weatherchannel' not present"
# "Key 'cdflaborlaw' not present"
# "Key 'cdn37' not present"
# "Key 'bumblesbiden' not present"
# "Key 'childtaxcredits' not present"
# "Key 'cysticfibrosis' not present"
# "Key 'bigpharmagate' not present"
# "Key 'covidroundsca' not present"
# "Key 'albaesvida' not present"
# "Key 'cornovirus' not present"
# "Key 'bidenlivesmatter' not present"
# "Key 'joeisafighter' not present"
# "Key 'sneakthiefs' not present"
# "Key 'ussurgeongeneral' not present"
# "Key 'cnnprimeramañana' not present"
# "Key 'bidenmiracles' not present"
# "Key 'ambazonia' not present"
# "Key 'wastewater' not present"
# "Key 'bumblesbiden' not present"
# "Key 'dontliveinfear' not present"
# "Key 'uswunity' not present"
# "Key 'bumblesbiden' not present"
# "Key 'lapoderosa' not present"
# "Key 'idrather_thanvotefortrump' not present"
# "Key 'investigatefortdetrick' not present"
# "Key 'arstnews' not present"
# "Key 'convicttrumpsaveamerica' not present"
# "Key 'itsnotabouthealth' not present"
# "Key 'obamabidenspygatebuilding2020' not present"
# "Key 'resolutedesk' not present"
# "Key 'bleachandlight' not present"
# "Key 'bideniswrong' not present"
# "Key 'nuestromundo' not present"
# "Key 'nuestromundo' not present"
# "Key 'cdntodaynews' not present"
# "Key 'últimahoraluz' not present"
# "Key 'mfpds' not present"
# "Key 'flyovercountrybumpkins' not present"
# "Key 'gopisthepartyofno' not present"
# "Key 'acpcjkdl' not present"
# "Key 'abc7ny' not present"
# "Key 'myresponse' not present"
# "Key 'bumblesbiden' not present"
# "Key 'cooperativaencasa' not present"
# "Key 'paddywhackery' not present"
# "Key 'reddawn' not present"
# "Key 'delasemana' not present"
# "Key 'gunvote' not present"
# "Key 'joebidentotherescue' not present"
# "Key 'lyingedit' not present"
# "Key 'lyingdogface' not present"
# "Key 'hora20' not present"
# "Key '26mar' not present"
# "Key 'redwave22' not present"
# "Key 'cubainformatiza' not present"
# "Key 'immunitydenier' not present"
# "Key 'ourworld' not present"
# "Key 'nodrbirxonbidencovidteam' not present"
# "Key 'economicreform' not present"
# "Key 'hispantv' not present"
# "Key 'sputnikvesesperanza' not present"
# "Key 'bunkerboytrumpisamoron' not present"
# "Key 'notmycorpse' not present"
# "Key 'coronacorruption' not present"
# "Key 'captainbrettcrozier' not present"
# "Key 'covidbarbie' not present"
# "Key 'bigpharmagate' not present"
# "Key 'marinemomforbiden' not present"
# "Key 'rncsuperspreader' not present"
# "Key 'treasonoustraitortrump' not present"
# "Key 'kimmel' not present"
# "Key 'brokenpromisebiden' not present"
# "Key 'naturalimmunitymatters' not present"
# "Key 'correctingtherecord' not present"
# "Key 'nocompromise' not present"
# "Key 'stoptesting' not present"
# "Key 'whyimnotvotingforbiden' not present"
# "Key 'nooversight' not present"
# "Key 'ivotedblue' not present"
# "Key 'intenttoharm' not present"
# "Key 'jfkjrmarathon' not present"
# "Key 'captainbrettcrozier' not present"
# "Key 'rudeasspeople' not present"
# "Key 'insanlymental' not present"
# "Key 'passtheheroesactnow' not present"
# "Key 'bourse' not present"
# "Key 'paraquetengaseldato' not present"
# "Key 'hispantv' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'bigpharmagate' not present"
# "Key 'takeoutthewhitetrash' not present"
# "Key 'taintedadrenochrome' not present"
# "Key 'haveatit' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'educatorsforjoe' not present"
# "Key 'jabcult' not present"
# "Key 'luvguv' not present"
# "Key 'trumpnoleader' not present"
# "Key 'novemberelections' not present"
# "Key 'facingthefuture' not present"
# "Key 'blockquote' not present"
# "Key 'approximately' not present"
# "Key 'joedontknow' not present"
# "Key 'failior_biden' not present"
# "Key 'bigpharmagate' not present"
# "Key 'thebidencrimefamily' not present"
# "Key 'trumpsliespeopledie' not present"
# "Key 'worsetrumpever' not present"
# "Key 'chessemoji' not present"
# "Key 'stoptesting' not present"
# "Key 'resumendenoticias' not present"
# "Key 'uspoliticsusnewsworldnewsjoebidencoronavirus' not present"
# "Key 'makeabluepromise' not present"
# "Key 'chumidiot' not present"
# "Key 'bumblesbiden' not present"
# "Key 'bidenisforbbiden' not present"
# "Key 'chimpanzee' not present"
# "Key 'abc7alertdesk' not present"
# "Key 'clochards' not present"
# "Key 'americanmade' not present"
# "Key 'bidenhasnoclue' not present"
# "Key 'not4' not present"
# "Key 'showmetheletter' not present"
# "Key 'juggernaut' not present"
# "Key 'devopsish' not present"
# "Key 'liberalnews' not present"
# "Key 'touchyfeelybiden' not present"
# "Key 'polydent' not present"
# "Key 'istandwithtomilahren' not present"
# "Key 'universnews' not present"
# "Key 'realdoctors' not present"
# "Key 'bidenmaskoff' not present"
# "Key 'tommychong' not present"
# "Key 'cooperativacontigo' not present"
# "Key 'bidenhasnoclue' not present"
# "Key 'trumpisimpotent' not present"
# "Key 'strokedout' not present"
# "Key 'liveleak' not present"
# "Key 'thegrimreaper' not present"
# "Key 'ciudadaníard' not present"
# "Key 'killerdementiajoe' not present"
# "Key 'abortiontillbirth' not present"
# "Key 'bumblesbiden' not present"
# "Key 'trumptulsaokraly' not present"
# "Key 'votingpowerladiesofusa' not present"
# "Key 'trumpcatastrophe' not present"
# "Key 'joeshit' not present"
# "Key 'nicetry' not present"
# "Key 'bumblesbiden' not present"
# "Key 'crazytimes' not present"
# "Key 'lunaticleftist' not present"
# "Key 'chinesewhistleblower' not present"
# "Key '29ene' not present"
# "Key 'new2q' not present"
# "Key 'redwave22' not present"
# "Key 'redwave22' not present"
# "Key 'covidaudit' not present"
# "Key 'contortions' not present"
# "Key 'dnc_convention' not present"
# "Key 'evilcheats' not present"
# "Key 'colossalnews' not present"
# "Key 'topdeldía' not present"
# "Key 'delaweb' not present"
# "Key 'todaysvoicestues' not present"
# "Key 'spi' not present"
# "Key 'christsmas' not present"
# "Key 'bidenistryingtokillyou' not present"
# "Key 'bhinoticias' not present"
# "Key 'bidenterrorists' not present"
# "Key 'fireteacherunions' not present"
# "Key 'facingthefuture' not present"
# "Key 'proudbluehen' not present"
# "Key 'nadal' not present"
# "Key 'malarkeyjoe' not present"
# "Key 'selectivememory' not present"
# "Key 'pequeñosnegocios' not present"
# "Key 'especialcoronavirus' not present"
# "Key 'mrdementia' not present"
# "Key 'cnt' not present"
# "Key 'suite550' not present"
# "Key 'isolatecovid' not present"
# "Key 'acusación' not present"
# "Key 'corruptgopsenate' not present"
# "Key 'toldyouso' not present"
# "Key 'cooperativaencasa' not present"
# "Key 'coppednews' not present"
# "Key 'redwave22' not present"
# "Key 'lamoranca' not present"
# "Key 'coronanomics' not present"
# "Key 'jakpost' not present"
# "Key 'swampwatch' not present"
# "Key 'sleepycreepysleazyjoe' not present"
# "Key 'ny22' not present"
# "Key 'ecpimco' not present"
# "Key 'chairmanxi' not present"
# "Key 'buldbackbetter' not present"
# "Key 'pollsdontmatter' not present"
# "Key 'gopfilth' not present"
# "Key 'lentemundial' not present"
# "Key 'criminalcommission' not present"
# "Key 'downsyndrome' not present"
# "Key 'demonrat' not present"
# "Key 'lettexasruntexas' not present"
# "Key 'criteriotelocuenta' not present"
# "Key 'breathe' not present"
# "Key 'nooriginalthought' not present"
# "Key 'stoptesting' not present"
# "Key 'trumpislikeachild' not present"
# "Key 'bidenboomer' not present"
# "Key '4vertices' not present"
# "Key 'redwave22' not present"
# "Key 'votebidenharrisforlife' not present"
# "Key 'bidenwasntbriefed' not present"
# "Key 'dopeydo' not present"
# "Key 'stfujoe' not present"
# "Key 'bidenharrislandslides' not present"
# "Key 'coronavirusarv' not present"
# "Key 'fall20mcj10211' not present"
# "Key 'dearmrbiden' not present"
# "Key 'goviral' not present"
# "Key 'bidenisbought' not present"
# "Key '2grosze' not present"
# "Key 'thetopical' not present"
# "Key 'joedontknow' not present"
# "Key 'trump_pence' not present"
# "Key 'ndigital' not present"
# "Key 'univeralbasicincome' not present"
# "Key 'theantichrist' not present"
# "Key 'covid19newsupdate' not present"
# "Key 'bidensusks' not present"
# "Key 'denews' not present"
# "Key 'endborders' not present"
# "Key 'saluddh' not present"
# "Key 'patientsfirst' not present"
# "Key 'joebidenwillhealamerica' not present"
# "Key 'presidentpence' not present"
# "Key 'vivalahermandadvenezuelairán' not present"
# "Key 'bidenwarrenkickdtass' not present"
# "Key 'ridingtotheerwithbiden' not present"
# "Key 'covid19hoy' not present"
# "Key 'croockedjoebiden' not present"
# "Key 'trumpcoward' not present"
# "Key 'naziamericanfuhrertrump' not present"
# "Key 'farmersforbiden' not present"
# "Key 'diariodequintanaroo' not present"
# "Key 'opinions' not present"
# "Key 'proudofdems' not present"
# "Key 'vaccinesupply' not present"
# "Key 'uniteandfight' not present"
# "Key 'primariesarentover' not present"
# "Key 'ballsdeepintobiden' not present"
# "Key 'dysom' not present"
# "Key 'trumpdeathtoll84k' not present"
# "Key 'wakeupclt' not present"
# "Key 'tocatchabiden' not present"
# "Key 'tweetrepeat' not present"
# "Key 'fatantichrist' not present"
# "Key 'taxtherrich' not present"
# "Key 'tipstostrengthenimmunity' not present"
# "Key 'assessmenthq' not present"
# "Key 'mg440' not present"
# "Key 'wearevotingforbidenbecause' not present"
# "Key 'trvmpuss2020' not present"
# "Key 'alacortelaechaelpueblo' not present"
# "Key 'nbcct' not present"
# "Key 'yalesph' not present"
# "Key 'theshitty' not present"
# "Key 'fox59morning' not present"
# "Key 'joethehoe' not present"
# "Key 'liberalshills' not present"
# "Key 'thebidenway' not present"
# "Key 'globalcovidresponse' not present"
# "Key 'rct' not present"
# "Key 'coronabriefing' not present"
# "Key 'justliketrump' not present"
# "Key 'teamtrumponline' not present"
# "Key '1american' not present"
# "Key 'hispantv' not present"
# "Key 'illiterate' not present"
# "Key 'darrenkerisky' not present"
# "Key 'trumpwantsusdeadblackpeople' not present"
# "Key 'robberbaron' not present"
# "Key 'barrioadentro18aniversario' not present"
# "Key 'teacherappreciationday' not present"
# "Key 'bigpharmagate' not present"
# "Key '3martinilunch' not present"
# "Key 'reinstatefairnessdoctrine' not present"
# "Key 'chinacrats' not present"
# "Key 'proximatepotus46' not present"
# "Key 'uday' not present"
# "Key 'gobiggobidengetbetter' not present"
# "Key 'numbnuts' not present"
# "Key 'redwave22' not present"
# "Key 'boringbiden' not present"
# "Key 'bigpharmagate' not present"
# "Key '̵m̵e̵t̵o̵o̵' not present"
# "Key 'chriswallace4biden' not present"
# "Key 'weriseagain' not present"
# "Key 'mileg' not present"
# "Key 'freeamerica' not present"
# "Key 'freetwitter' not present"
# "Key 'todayexplained' not present"
# "Key 'bidenhypocracy101' not present"
# "Key 'badbiden' not present"
# "Key 'coronavirusarv' not present"
# "Key 'badnews' not present"
# "Key 'pandemicchoas' not present"
# "Key 'demforce2020' not present"
# "Key 'periodismops' not present"
# "Key 'democratassholes' not present"
# "Key '4yourmorning' not present"
# "Key 'vragenuurtje' not present"
# "Key 'funnynotfunny' not present"
# "Key 'meanjoebiden' not present"
# "Key 'redwave22' not present"
# "Key 'builditbackbetter' not present"
# "Key 'legalvotesmatter' not present"
# "Key 'coronavirusarv' not present"
# "Key 'wallacetrumpinterview' not present"
# "Key 'screwbiden' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'wakeupclt' not present"
# "Key 'bobbyeberle' not present"
# "Key 'cowardlygop' not present"
# "Key 'honorouramerican100000' not present"
# "Key 'bumblesbiden' not present"
# "Key 'bipolarbiden' not present"
# "Key 'xterior' not present"
# "Key 'nowayjoe' not present"
# "Key 'joebidenwillhealamerica' not present"
# "Key 'worstpresidenteveristrump' not present"
# "Key 'thebidencrimefamily' not present"
# "Key 'fearflu' not present"
# "Key 'hibernationversusrecession' not present"
# "Key 'artsandentertainment' not present"
# "Key 'rncc2020' not present"
# "Key 'larvitamcfarquhar' not present"
# "Key 'cuomodeathtoll' not present"
# "Key 'trumpforprison2022' not present"
# "Key 'vaxupillinois' not present"
# "Key 'joedontknow' not present"
# "Key 'scotusopusdei6' not present"
# "Key 'voteforbidentosaveamerica' not present"
# "Key 'trumpdebt' not present"
# "Key 'atandocabos' not present"
# "Key 'birxit' not present"
# "Key 'natgas' not present"
# "Key 'ripdnc' not present"
# "Key '2020yearofmorons' not present"
# "Key 'bidentaxincrease' not present"
# "Key 'bumblesbiden' not present"
# "Key 'bidenboy' not present"
# "Key 'michiganprioritiespoll' not present"
# "Key 'drstephan' not present"
# "Key 'helpnashismael' not present"
# "Key 'texasnews' not present"
# "Key 'mundodd' not present"
# "Key 'redwave22' not present"
# "Key 'bigpharmagate' not present"
# "Key 'boomerdoomer' not present"
# "Key 'bigpharmagate' not present"
# "Key 'coronavirusarv' not present"
# "Key 'nationalvaccinemandate' not present"
# "Key 'radiocubana' not present"
# "Key '30abr' not present"
# "Key 'contraluz' not present"
# "Key 'internacionalet' not present"
# "Key 'bidenterrorists' not present"
# "Key 'lapatillausa' not present"
# "Key 'endirecto' not present"
# "Key 'shameonthenavy' not present"
# "Key 'datum' not present"
# "Key 'thedilleyshow' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'globalpandemicplan' not present"
# "Key 'stopfollowingpoliticians' not present"
# "Key '29sept' not present"
# "Key 'thehprchronicles' not present"
# "Key 'cyberdigest' not present"
# "Key 'maia' not present"
# "Key 'redwave22' not present"
# "Key 'bidencurescovid' not present"
# "Key 'feeblejoebiden' not present"
# "Key 'bidenzuela' not present"
# "Key 'cognativedecline' not present"
# "Key 'weneedbidenharris' not present"
# "Key 'scottyfommarketing' not present"
# "Key '10marzo' not present"
# "Key '3rdratepresident' not present"
# "Key 'lyingedit' not present"
# "Key 'redwave22' not present"
# "Key 'bidendeathtracker' not present"
# "Key 'president_elect' not present"
# "Key 'fakenewspresident' not present"
# "Key 'jm' not present"
# "Key 'papajoe' not present"
# "Key 'republicanflu' not present"
# "Key '美疾控中心更新指引接種兩劑疫苗者毋須戴口罩' not present"
# "Key 'dorchester' not present"
# "Key 'boldpredictionsfortrump' not present"
# "Key 'bigpharmagate' not present"
# "Key 'bidenslushfund' not present"
# "Key 'trumphaslosthismind' not present"
# "Key 'bumblesbiden' not present"
# "Key 'dailyfreshpicks' not present"
# "Key 'expendables' not present"
# "Key 'notmyunclejoe' not present"
# "Key 'multimasking' not present"
# "Key 'istandwithblacktrumpsupporters' not present"
# "Key 'asianvirus' not present"
# "Key 'putkidsfirst' not present"
# "Key 'kbsv' not present"
# "Key 'drmarcomrtz' not present"
# "Key 'bidenwatch' not present"
# "Key 'impfnachweis' not present"
# "Key 'zoominauguration' not present"
# "Key 'پابەندین' not present"
# "Key 'detectingdeception' not present"
# "Key 'lyingedit' not present"
# "Key 'blacklivesdontmatter' not present"
# "Key 'amercia' not present"
# "Key 'coughingjoebiden' not present"
# "Key 'joedontknow' not present"
# "Key 'anzac' not present"
# "Key 'dadsmask' not present"
# "Key 'virusrally' not present"
# "Key 'gropinjoebiden' not present"
# "Key 'oxymoron' not present"
# "Key 'tencommandments' not present"
# "Key 'fixitforyou' not present"
# "Key 'plaguechic' not present"
# "Key 'senkamalaharris' not present"
# "Key 'tvirus' not present"
# "Key 'rubyprincess' not present"
# "Key 'giveitupjoe' not present"
# "Key 'resistancelive' not present"
# "Key 'bigpharmagate' not present"
# "Key 'edninforma' not present"
# "Key 'efeusa2020' not present"
# "Key 'bigpharmagate' not present"
# "Key 'egapmemberinthenews' not present"
# "Key 'videosafp' not present"
# "Key 'mrsamerica' not present"
# "Key 'fibonacci' not present"
# "Key 'coronavirusesp' not present"
# "Key '15oct' not present"
# "Key 'cleanenergydevelopment' not present"
# "Key 'predidentbiden' not present"
# "Key 'whew' not present"
# "Key 'unc' not present"
# "Key 'hoesmad' not present"
# "Key 'bidenharristrainwreck2020' not present"
# "Key 'eaglenews' not present"
# "Key 'wuhanjoe' not present"
# "Key 'inqbaters' not present"
# "Key 'guestpostservice' not present"
# "Key 'guestpostservice' not present"
# "Key 'redwave22' not present"
# "Key 'purereparations' not present"
# "Key 'hispantv' not present"
# "Key 'leftistloons' not present"
# "Key 'económicainforma' not present"
# "Key 'noexcuse' not present"
# "Key 'unvaccinatedassholes' not present"
# "Key 'wheresourdividendandrew' not present"
# "Key 'foxnewsa' not present"
# "Key 'stephanopoulos' not present"
# "Key 'toma' not present"
# "Key 'cacas' not present"
# "Key 'heyjoe' not present"
# "Key 'victiminchief' not present"
# "Key 'coberturabiden' not present"
# "Key 'edosocialsnewsupdate' not present"
# "Key 'bienbellopuesj' not present"
# "Key 'hispantv' not present"
# "Key 'sholeperformance' not present"
# "Key '20january2021' not present"
# "Key 'kidnaptorturerendition' not present"
# "Key 'lodice' not present"
# "Key 'quantum' not present"
# "Key 'latres' not present"
# "Key 'internacionalcf' not present"
# "Key 'confidencial' not present"
# "Key 'edelmundo' not present"
# "Key '31jul' not present"
# "Key 'notiaudio' not present"
# "Key '17feb' not present"
# "Key 'elsoldecórdoba' not present"
# "Key 'porsisetepasó' not present"
# "Key 'elsoldeorizaba' not present"
# "Key '18abr' not present"
# "Key 'elintermedio' not present"
# "Key 'bumblesbiden' not present"
# "Key 'coronavirusroundup' not present"
# "Key 'presidentelizabethwarren' not present"
# "Key 'elelombardia' not present"
# "Key 'elemolise' not present"
# "Key 'stoptesting' not present"
# "Key 'joebidenwillhealamerica' not present"
# "Key 'gasolinaparaelpueblo' not present"
# "Key 'nebulizers' not present"
# "Key 'ndigital' not present"
# "Key 'redwave22' not present"
# "Key 'voteforafuture' not present"
# "Key 'impeachthemotherfuqqer' not present"
# "Key 'shutupjoebiden' not present"
# "Key 'joedontknow' not present"
# "Key 'lamochiladekike' not present"
# "Key 'natgas' not present"
# "Key 'lomasleido' not present"
# "Key 'rechazo' not present"
# "Key 'bidenday1' not present"
# "Key 'theinvestigationofjoebiden' not present"
# "Key 'envoyespecial' not present"
# "Key 'epicentromundial' not present"
# "Key 'lavueltaalmundoen5noticias' not present"
# "Key 'reporterdiary' not present"
# "Key 'coronavirusalert' not present"
# "Key 'weneedubi' not present"
# "Key 'hailtothechief' not present"
# "Key 'basementcentral' not present"
# "Key 'nporadio1' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'redwave22' not present"
# "Key 'analisisvrgas' not present"
# "Key 'careact' not present"
# "Key 'cooperativaencasa' not present"
# "Key 'übersterblichkeit' not present"
# "Key 'emergingtech' not present"
# "Key 'cooperativacontigo' not present"
# "Key 'dontrumps' not present"
# "Key 'accelerationism' not present"
# "Key 'lyingedit' not present"
# "Key 'cincywx' not present"
# "Key 'gse570' not present"
# "Key '15oct' not present"
# "Key 'theleaderpodcast' not present"
# "Key 'pandemicissues' not present"
# "Key 'trumpskatrina' not present"
# "Key 'whyivax' not present"
# "Key 'fourpinocchios' not present"
# "Key 'exitzerozombie' not present"
# "Key 'éxitonoticias' not present"
# "Key 'thesocialdilemma' not present"
# "Key 'bigpharmagate' not present"
# "Key 'boringbiden' not present"
# "Key 'viajarausa' not present"
# "Key 'hispantv' not present"
# "Key 'bussinessasusual' not present"
# "Key 'fbidenver' not present"
# "Key 'redwave22' not present"
# "Key 'bleachhoax' not present"
# "Key 'bideninalandslide2020' not present"
# "Key 'weareallvulnerable' not present"
# "Key 'stoptheshutdown' not present"
# "Key 'coronavirusarv' not present"
# "Key 'fox48news' not present"
# "Key 'fox59morning' not present"
# "Key 'bidendropouttulsi' not present"
# "Key 'sctweets' not present"
# "Key 'cooperativaencasa' not present"
# "Key 'cnt' not present"
# "Key 'coronavirusbiowar' not present"
# "Key 'itsatrap' not present"
# "Key 'hispantv' not present"
# "Key 'deporable' not present"
# "Key 'begunah' not present"
# "Key 'cv1984' not present"
# "Key 'majorityofdemocratsdontwantslowjoetorun' not present"
# "Key 'covid19hoy' not present"
# "Key 'redstatemedia' not present"
# "Key 'bidenterrorists' not present"
# "Key 'westworld' not present"
# "Key 'eleckbiden' not present"
# "Key 'redwave22' not present"
# "Key 'randominaugurationfacts' not present"
# "Key 'faultlines' not present"
# "Key 'globalistjoe' not present"
# "Key 'democratsaredictators' not present"
# "Key 'wallswork' not present"
# "Key 'trumpvirusdonald' not present"
# "Key 'joebidenhasbloodonhishands' not present"
# "Key 'americanresc' not present"
# "Key 'makeamericagreatagain2020' not present"
# "Key 'kwch12' not present"
# "Key 'bidenisdonaldselectionnightmare' not present"
# "Key 'religiously' not present"
# "Key 'symptomsmatter' not present"
# "Key 'styxhexenhammer666' not present"
# "Key 'hispantv' not present"
# "Key 'jakpost' not present"
# "Key 'elcacaspedofilo' not present"
# "Key 'prensasicaria' not present"
# "Key 'dolt45' not present"
# "Key 'sorrytoburstyourbubble' not present"
# "Key 'bumblesbiden' not present"
# "Key 'comeandmakeme' not present"
# "Key 'covid19hoy' not present"
# "Key 'financenews' not present"
# "Key 'bbcgms' not present"
# "Key 'jpmcinstitute' not present"
# "Key 'dmocratscovid19' not present"
# "Key 'mn07' not present"
# "Key 'rightwinghatemob' not present"
# "Key 'elizaberhwarren' not present"
# "Key 'deanlies' not present"
# "Key 'fakecheck' not present"
# "Key 'hollywoodtelevision' not present"
# "Key 'endsanctuarycities' not present"
# "Key 'endthisuncivilwar' not present"
# "Key 'bidenfightscovidharderin2weeks' not present"
# "Key 'fldeovirtualprotest' not present"
# "Key 'headlinethatcaughtmyeye' not present"
# "Key 'finfluencer' not present"
# "Key 'joebidenwillhealamerica' not present"
# "Key 'redwave22' not present"
# "Key 'righttolife' not present"
# "Key 'timetofightcovid' not present"
# "Key 'bumblesbiden' not present"
# "Key 'pmfall2020' not present"
# "Key 'lierinchief' not present"
# "Key 'hidinbidin' not present"
# "Key 'corporatesocialism' not present"
# "Key 'atikukawai' not present"
# "Key 'trumpviruscheck' not present"
# "Key 'lyinking' not present"
# "Key 'transición2021' not present"
# "Key 'nfergus' not present"
# "Key 'senatorjohnson' not present"
# "Key 'bidenterrorists' not present"
# "Key 'diariopresidencialeseeuu' not present"
# "Key 'gasolinaparaelpueblo' not present"
# "Key 'oldjoebiden' not present"
# "Key 'enopinión' not present"
# "Key 'whoisthesorelosernow' not present"
# "Key 'realcreepytrumpjustwanttaxcutsforhisrichallies' not present"
# "Key 'mitchmoscow' not present"
# "Key 'freelabel' not present"
# "Key 'domingofreemansdv' not present"
# "Key 'rva' not present"
# "Key 'freedomsphoenix' not present"
# "Key 'thepublicoption' not present"
# "Key 'bumblesbiden' not present"
# "Key 'bidenisdonaldselectionnightmare' not present"
# "Key 'trumpvirusdisaster' not present"
# "Key 'fuelcell' not present"
# "Key 'bigpharmagate' not present"
# "Key 'pleasegojoe' not present"
# "Key 'sap' not present"
# "Key 'trumpvirusdeathtoll198k' not present"
# "Key 'horseshit' not present"
# "Key 'notvotingfortrumporbiden' not present"
# "Key 'joebidendom4a' not present"
# "Key 'dontbelievetrump' not present"
# "Key 'globalmidweekword' not present"
# "Key 'controllingthespread' not present"
# "Key 'planolula' not present"
# "Key 'dontcaliforniaourcountry' not present"
# "Key 'trumpisgolfing' not present"
# "Key '给中国十亿无产阶级' not present"
# "Key 'pakistanday' not present"
# "Key 'lapatillausa' not present"
# "Key 'donniedolittle' not present"
# "Key 'bumblesbiden' not present"
# "Key 'casestudy' not present"
# "Key 'supermarketnews' not present"
# "Key 'enopinión' not present"
# "Key 'joicesordida' not present"
# "Key 'victorian' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'hispantv' not present"
# "Key 'lapatillausa' not present"
# "Key 'americansinparis' not present"
# "Key 'hispantv' not present"
# "Key 'ambulancechaser' not present"
# "Key 'forgivestudentdebt' not present"
# "Key 'corrupteddisgracedobamabiden' not present"
# "Key 'freedomfr' not present"
# "Key 'trumphadiqop' not present"
# "Key 'bidendisappointment' not present"
# "Key 'pmjt' not present"
# "Key '600diasdesecuestro' not present"
# "Key 'bidenterrorists' not present"
# "Key 'bidenisawinner' not present"
# "Key 'votaporbiden' not present"
# "Key '300electorates' not present"
# "Key 'diaperbaby' not present"
# "Key 'bankconservation' not present"
# "Key 'republicanmotherfuckers' not present"
# "Key 'teachers4biden' not present"
# "Key 'ge2020' not present"
# "Key 'trumpcatastrophe' not present"
# "Key 'realcriminals' not present"
# "Key 'bidenisdonaldselectionnightmare' not present"
# "Key 'bidenmurderer' not present"
# "Key 'secondstimulus' not present"
# "Key 'topenews' not present"
# "Key 'begintheunity' not present"
# "Key 'sleepyclub' not present"
# "Key 'sunrisers' not present"
# "Key 'wuhanjoe' not present"
# "Key 'morrisons' not present"
# "Key 'foolaid' not present"
# "Key 'bidenterrorists' not present"
# "Key 'cluelessped' not present"
# "Key 'whereamibiden' not present"
# "Key 'deluca' not present"
# "Key 'edicao8' not present"
# "Key '45administration' not present"
# "Key 'giro555' not present"
# "Key 'redwave22' not present"
# "Key 'defundbigeducation' not present"
# "Key 'ワクチンの接種計画' not present"
# "Key 'ポリオワクチン' not present"
# "Key 'spiritually' not present"
# "Key 'welcometochina' not present"
# "Key '2kmonthly' not present"
# "Key 'debatenight2020' not present"
# "Key 'transitiontogreatmess' not present"
# "Key 'reporteusa' not present"
# "Key 'bernieteam' not present"
# "Key 'supportbidenharris2win' not present"
# "Key 'pleasehelpus' not present"
# "Key 'redwave22' not present"
# "Key 'marinemomforbiden' not present"
# "Key 'bumblesbiden' not present"
# "Key 'medicaremedicaidsecondarypayerlegalservices' not present"
# "Key 'emol' not present"
# "Key 'govexecdaily' not present"
# "Key 'gayit' not present"
# "Key 'halts' not present"
# "Key 'perthnews' not present"
# "Key 'whomatters' not present"
# "Key 'ldfps' not present"
# "Key 'youthvote' not present"
# "Key 'murdochguttermedia' not present"
# "Key 'unitedstatesofausterity' not present"
# "Key 'communitydriven' not present"
# "Key 'cowardtraitorretrumplicans' not present"
# "Key 'childsafety' not present"
# "Key 'cardinalwiltong' not present"
# "Key 'worthlessconversation' not present"
# "Key 'proudofdems' not present"
# "Key 'girlpower' not present"
# "Key 'trumpvandalism' not present"
# "Key 'mineła20' not present"
# "Key 'releasealexsaab' not present"
# "Key 'joeblowhardbiden' not present"
# "Key 'istandwithtulsu' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'whew' not present"
# "Key 'giuramento' not present"
# "Key 'reconciliaciónypaz' not present"
# "Key 'sanbiden' not present"
# "Key 'superspredator' not present"
# "Key 'pandemichoax' not present"
# "Key 'bringmanufacturinghome' not present"
# "Key 'cooperativacontigo' not present"
# "Key 'whitehousenews' not present"
# "Key '19threpresents' not present"
# "Key 'freezombiebiden' not present"
# "Key 'ygprotectjennie' not present"
# "Key 'holocaustofpassivity' not present"
# "Key 'partypoliticspod' not present"
# "Key 'jobsday' not present"
# "Key 'fathitler' not present"
# "Key 'conronavirus' not present"
# "Key 'endsanctuarycities' not present"
# "Key 'hstodaymag' not present"
# "Key 'ndigital' not present"
# "Key 'fridayvigilexpo' not present"
# "Key 'drhabib_tokyo_olympics' not present"
# "Key 'vulnerablefamily' not present"
# "Key 'justmandate' not present"
# "Key 'clochards' not present"
# "Key 'withholdyourvote' not present"
# "Key 'iamvotingforbiden' not present"
# "Key 'publichealthpsas' not present"
# "Key 'proudlyvoted4' not present"
# "Key 'blockquote' not present"
# "Key 'girldad' not present"
# "Key 'bidentoxicsupporters' not present"
# "Key 'msnbctownhall' not present"
# "Key 'ukrainebribery' not present"
# "Key 'wyboryprezydenckie' not present"
# "Key 'gesundermenschenverstand' not present"
# "Key 'ppl' not present"
# "Key 'coranaturkiye' not present"
# "Key 'lincolnwomen' not present"
# "Key 'bidenukraine' not present"
# "Key 'hnn' not present"
# "Key 'americanmade' not present"
# "Key 'goopgroupgooping' not present"
# "Key 'employervac' not present"
# "Key 'weallgrievewithyou' not present"
# "Key 'trumpdeathtoll117k' not present"
# "Key 'diversitymatters' not present"
# "Key 'edweek' not present"
# "Key 'rpolitics' not present"
# "Key 'buildingacommonfuture' not present"
# "Key 'askdrb' not present"
# "Key 'eldebatedelsiglo' not present"
# "Key 'bernietobidencuzpandemic' not present"
# "Key 'crucitas' not present"
# "Key 'cancelaprilfools' not present"
# "Key 'whyivax' not present"
# "Key 'redwave22' not present"
# "Key 'notrust' not present"
# "Key 'stoptesting' not present"
# "Key 'gropeydopeyjoebiden' not present"
# "Key 'lopezcorruptoinepto' not present"
# "Key 'dearjoe' not present"
# "Key '31jul' not present"
# "Key 'stopobama' not present"
# "Key 'redwave22' not present"
# "Key 'þríeyki' not present"
# "Key 'hail' not present"
# "Key 'comradebenedicttrump' not present"
# "Key 'dementiajoestrikesagain' not present"
# "Key 'news18bulletin' not present"
# "Key 'protestorsrioters' not present"
# "Key 'braindeadshithead' not present"
# "Key 'buildbackworse' not present"
# "Key 'redcovid' not present"
# "Key 'lapoderosa' not present"
# "Key 'joedontknow' not present"
# "Key 'healthenation' not present"
# "Key 'kmov' not present"
# "Key 'rockstar' not present"
# "Key 'rgvforbiden' not present"
# "Key 'mercuryretrograde' not present"
# "Key 'themorninggrindwithshayandshyne' not present"
# "Key 'hirambe' not present"
# "Key 'redwave22' not present"
# "Key 'thatsnotwhatasymptomaticmeans' not present"
# "Key 'tableoftitans' not present"
# "Key 'handsoffalexsaab' not present"
# "Key 'handsoffalexsaab' not present"
# "Key 'notfakeunfortunately' not present"
# "Key 'iaffecho' not present"
# "Key 'sendindiavaccines' not present"
# "Key 'careact' not present"
# "Key 'lawancovid19' not present"
# "Key 'joedontknow' not present"
# "Key 'covid19hoy' not present"
# "Key 'ercot' not present"
# "Key 'corteinformativo' not present"
# "Key 'periodismoenmovimiento' not present"
# "Key 'thepentagon' not present"
# "Key '中国是屁眼' not present"
# "Key 'deathpaneldoctor' not present"
# "Key 'omicroninamerica' not present"
# "Key 'thiswastheplansaidnoone' not present"
# "Key 'boyrockabama' not present"
# "Key 'coronavirusroundup' not present"
# "Key 'shapeupsandshots' not present"
# "Key 'controlovirus' not present"
# "Key 'cognitivedeclinedon' not present"
# "Key 'bigpharmagate' not present"
# "Key 'bigpharmagate' not present"
# "Key 'ffk' not present"
# "Key 'disbarrudy' not present"
# "Key 'fuckofffauci' not present"
# "Key 'politvaccine' not present"
# "Key 'claynation' not present"
# "Key '러쉬파퍼구입처' not present"
# "Key 'banvaccinepassports' not present"
# "Key 'americanvoters' not present"
# "Key 'giveashitnow' not present"
# "Key 'removejoebiden' not present"
# "Key 'bigpharmagate' not present"
# "Key 'onday1' not present"
# "Key 'endsanctuarycities' not present"
# "Key '11sep' not present"
# ...
# "Key 'sinalexnohaydialogo' not present"
# "Key 'itrustjoebiden' not present"
# "Key 'baghdadbarbie' not present"
# "Key 'joebidenshand' not present"
# "Key 'focuspress' not present"
# "Key 'showmetheletter' not present"
# "Key 'unitedstatessenate' not present"
# "Key 'redwave22' not present"
# "Key 'bideniswrong' not present"
# "Key 'safebreath' not present"
# "Key 'sehitlerimizvar' not present"
# "Key 'fuckbigpharma' not present"
# "Key 'lyingedit' not present"
# "Key 'm4asaveslives' not present"
# "Key 'stop_chinese_government' not present"
# "Key 'hispantv' not present"
# "Key 'bumblesbiden' not present"
# "Key 'yomommagate' not present"
# "Key 'supremecourtdebacle' not present"
# "Key 'boycottkina' not present"
# "Key 'hispantv' not present"
# "Key 'bumblesbiden' not present"
# "Key 'whatbidensaid' not present"
# "Key 'lapatillausa' not present"
# "Key 'coronavirustemporary' not present"
# "Key 'closetnschools' not present"
# "Key 'morgellons' not present"
# "Key 'bolívarespueblo' not present"
# "Key 'qnn' not present"
# "Key '20million' not present"
# "Key 'elwashingtonpost' not present"
# "Key 'votingbymail' not present"
# "Key 'redwave22' not present"
# "Key 'tobiaslevels' not present"
# "Key 'notmydictator' not present"
# "Key 'demforce2020' not present"
# "Key 'redwave22' not present"
# "Key 'wethepeopledemand' not present"
# "Key 'bidenforpresidentnow' not present"
# "Key 'whereisjoebidenhiding' not present"
# "Key 'factsandlogic' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'leotheleek' not present"
# "Key 'kimmel' not present"
# "Key 'noshowberniebros' not present"
# "Key 'welpcaroma' not present"
# "Key 'asacalifornian' not present"
# "Key 'nobraincellsnetwork' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'redwave22' not present"
# "Key 'vanguardnews' not present"
# "Key 'ஜாதிப்பெயரை' not present"
# "Key 'mfn' not present"
# "Key 'jakpost' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'longreads' not present"
# "Key 'endirecto' not present"
# "Key 'derelicttrump' not present"
# "Key 'singlepayermedicareforall' not present"
# "Key 'bumblesbiden' not present"
# "Key 'reconciliaciónypaz' not present"
# "Key 'dementiadonnie' not present"
# "Key 'bigpharmagate' not present"
# "Key 'winrural' not present"
# "Key 'ordinarypeople' not present"
# "Key 'nofuelpricehike' not present"
# "Key 'peacefulprotests' not present"
# "Key 'audacityofrecklessness' not present"
# "Key 'gopfilth' not present"
# "Key 'byebyetrump2020' not present"
# "Key 'individualone' not present"
# "Key 'for2020' not present"
# "Key 'knowbidennobiden' not present"
# "Key 'onlyinnigeria' not present"
# "Key 'navalhonor' not present"
# "Key 'voteharrisbiden2020' not present"
# "Key 'divisive' not present"
# "Key 'metball' not present"
# "Key 'medicareforsome' not present"
# "Key 'rssideology' not present"
# "Key 'bigpharmagate' not present"
# "Key 'healingthenation' not present"
# "Key 'mypresidentberniesanders' not present"
# "Key 'blessing' not present"
# "Key 'oooohhhhshitbidenbustedvirus' not present"
# "Key 'lockthetrumps' not present"
# "Key 'creepyjoeandthehoe2020' not present"
# "Key 'joedontknow' not present"
# "Key 'asílotuiteó' not present"
# "Key 'foolmeonce' not present"
# "Key 'wewantjoebiden' not present"
# "Key 'whatabouttara' not present"
# "Key 'bidenpiggybank' not present"
# "Key 'bidenisdonaldselectionnightmare' not present"
# "Key 'dontdoabiden' not present"
# "Key 'kimmel' not present"
# "Key 'bidenwouldvetom4a' not present"
# "Key 'smallpoxblankets' not present"
# "Key 'pedopotus' not present"
# "Key 'slamminmedia' not present"
# "Key 'tairffs' not present"
# "Key '8days' not present"
# "Key 'mitchmcconnellhelped' not present"
# "Key '18again' not present"
# "Key 'redwave22' not present"
# "Key 'whosaveturkishstudents' not present"
# "Key 'grotesque' not present"
# "Key 'smartlistners' not present"
# "Key 'fuck_you_joe_biden' not present"
# "Key 'thebidenshow' not present"
# "Key 'bitchmnuchin' not present"
# "Key 'passcovidreliefpackage' not present"
# "Key 'joedontknow' not present"
# "Key 'arrestillegitimatebiden' not present"
# "Key 'confirmationbias' not present"
# "Key 'notifynyc' not present"
# "Key 'womengetitdone' not present"
# "Key 'bidenlameexcuses' not present"
# "Key 'fldeovirtualprotest' not present"
# "Key 'somd' not present"
# "Key 'trumpsfakechristianity' not present"
# "Key 'votebidenorstarve' not present"
# "Key 'joehasacovid19plan' not present"
# "Key 'redwave22' not present"
# "Key 'bumblesbiden' not present"
# "Key 'siempreinformado' not present"
# "Key '4tatransformación' not present"
# "Key 'goblue2020' not present"
# "Key 'alive' not present"
# "Key 'electberniesandersnotjoebiden' not present"
# "Key 'badlogic' not present"
# "Key 'redwave22' not present"
# "Key 'blitheringidiot' not present"
# "Key 'artlines' not present"
# "Key 'bumblesbiden' not present"
# "Key 'orangeclown' not present"
# "Key 'verystablegenius' not present"
# "Key 'stoptesting' not present"
# "Key 'ndigital' not present"
# "Key 'trumpass' not present"
# "Key 'ukr' not present"
# "Key 'failureofleadership' not present"
# "Key 'hydroxycut' not present"
# "Key 'mwahaha' not present"
# "Key 'uswunity' not present"
# "Key 'joedontknow' not present"
# "Key 'pennnsylvania' not present"
# "Key 'trumpforceone' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'chancegardener' not present"
# "Key 'bidenwhitmerwins' not present"
# "Key 'boringbiden' not present"
# "Key 'bigpharmagate' not present"
# "Key 'joeknowscorruption' not present"
# "Key 'mnews' not present"
# "Key 'poutrage' not present"
# "Key 'lieoftheyear' not present"
# "Key 'whatsnewinwashington' not present"
# "Key 'sgbotbreakingnews' not present"
# "Key 'demforce2020' not present"
# "Key 'theartofthepander' not present"
# "Key 'lyingliarslie' not present"
# "Key 'fxcktrump' not present"
# "Key 'factchecktrump' not present"
# "Key 'mostpopularpresidentever' not present"
# "Key 'amuqrp' not present"
# "Key 'nuclearcode' not present"
# "Key 'unitytest' not present"
# "Key 'maskplea' not present"
# "Key 'snldebateskit' not present"
# "Key 'bumblesbiden' not present"
# "Key 'endcult45' not present"
# "Key 'orangemonster' not present"
# "Key 'redwave22' not present"
# "Key 'selfishbiden' not present"
# "Key 'fakeblondie' not present"
# "Key 'murdochmafia' not present"
# "Key 'joebidenhasbloodonhishands' not present"
# "Key 'bidenhi' not present"
# "Key 'slumptrump' not present"
# "Key 'actualchange' not present"
# "Key 'bidenforpresidentnov2020' not present"
# "Key 'bumblesbiden' not present"
# "Key 'trumpdom' not present"
# "Key 'democracyindanger' not present"
# "Key 'cautionyespanicno' not present"
# "Key 'qnn' not present"
# "Key 'bolsonaropresidenteate2026' not present"
# "Key 'antifaterroist' not present"
# "Key 'pressecbarbie' not present"
# "Key 'lyingpostrump' not present"
# "Key 'vaccinateall' not present"
# "Key 'bidenshow' not present"
# "Key 'bumblesbiden' not present"
# "Key 'nomoregopincompetence' not present"
# "Key 'iamthankfulfor' not present"
# "Key 'banthedogandcatmeattrade' not present"
# "Key 'nolibertyinusauntil2020electionfraudexposedreverseddecertified' not present"
# "Key 'tastytweets' not present"
# "Key 'covid19hoy' not present"
# "Key 'returnofthemack' not present"
# "Key 'socalledpotus' not present"
# "Key 'trumphealthcare' not present"
# "Key 'whatsyourplan' not present"
# "Key 'joedontknow' not present"
# "Key 'tcsenmovimiento' not present"
# "Key 'cancelfox' not present"
# "Key 'moscowron' not present"
# "Key 'biden2022' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'technologytimes' not present"
# "Key 'itakenoresponsiblity' not present"
# "Key 'lockhimup4unity' not present"
# "Key 'demforce2020' not present"
# "Key 'sycopence' not present"
# "Key 'tempodunia' not present"
# "Key 'publicationoftheday' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'gaffemachine' not present"
# "Key '30abr' not present"
# "Key 'hispantv' not present"
# "Key 'adrenechrome' not present"
# "Key 'lyingedit' not present"
# "Key 'riverapp' not present"
# "Key 'badlyphrased' not present"
# "Key 'mathrubhumi' not present"
# "Key 'translation' not present"
# "Key 'disabilityinthenews' not present"
# "Key 'atlnews' not present"
# "Key '2manyfacestrudeau' not present"
# "Key 'bdnmb' not present"
# "Key 'changinghighered' not present"
# "Key 'liberalhate' not present"
# "Key 'dispatchpodcast' not present"
# "Key 'evilneversleeps' not present"
# "Key 'gopchairwoman' not present"
# "Key 'oldvideo' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'confirmation' not present"
# "Key 'thenews' not present"
# "Key 'illigitimatebiden' not present"
# "Key 'officialwhitehouseportrait' not present"
# "Key 'americavstrump' not present"
# "Key 'missyouliz' not present"
# "Key 'saynotosocialism' not present"
# "Key 'weirdnews' not present"
# "Key 'chinagenocide' not present"
# "Key 'uncwjourno' not present"
# "Key 'trumpforceone' not present"
# "Key 'fpucretro' not present"
# "Key 'disqualifying' not present"
# "Key 'dumpthechumptrump' not present"
# "Key 'forusvoters' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'joeshit' not present"
# "Key 'vr4smallbiz' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'dumbenough' not present"
# "Key 'bigpharmagate' not present"
# "Key 'selectivememory' not present"
# "Key 'rescuedtheuseconomy' not present"
# "Key 'floridaneedsfederalintervention' not present"
# "Key 'greatesthits' not present"
# "Key 'demsinsane' not present"
# "Key '30abr' not present"
# "Key 'nextadministration' not present"
# "Key 'ncatprwritingspring2021' not present"
# "Key 'kimmel' not present"
# "Key 'sgf' not present"
# "Key 'trumpvirusdeathtoll375k' not present"
# "Key 'bidenbernie2020' not present"
# "Key 'coronavirusexpert' not present"
# "Key 'giveitupjoe' not present"
# "Key 'massiveparallelinfection' not present"
# "Key 'rottenorange' not present"
# "Key 'hr40' not present"
# "Key 'aigwontpay' not present"
# "Key 'picciano' not present"
# "Key 'sit' not present"
# "Key 'emailingmyvote' not present"
# "Key 'joebidennotmypresident' not present"
# "Key 'circlebackjen' not present"
# "Key 'hairylegs' not present"
# "Key 'bidenisdonaldselectionnightmare' not present"
# "Key 'chicagoboys' not present"
# "Key 'bidenisdonaldselectionnightmare' not present"
# "Key 'alliterationforthewin' not present"
# "Key 'wr' not present"
# "Key 'noticiastrece' not present"
# "Key 'bidenisdonaldselectionnightmare' not present"
# "Key 'celebrityeclipse' not present"
# "Key 'blackfacebiden' not present"
# "Key 'cooperativaencasa' not present"
# "Key '𝗖𝗢𝗩𝗜𝗗𝟭𝟵' not present"
# "Key 'survivingparents' not present"
# "Key 'trtportuguese' not present"
# "Key 'trtespanol' not present"
# "Key 'shhhhhhhhhhhhhhhhhhhh' not present"
# "Key 'stoptesting' not present"
# "Key 'eugenecapitolhillhero' not present"
# "Key 'superpredators2020' not present"
# "Key 'redwave22' not present"
# "Key 'trumpfarewelltour' not present"
# "Key 'realmenwearamask' not present"
# "Key 'washingron' not present"
# "Key 'savesmallbusiness' not present"
# "Key 'firetornadoes' not present"
# "Key 'bigpharmagate' not present"
# "Key 'sleepyjoespeaks' not present"
# "Key 'sputnikvesesperanza' not present"
# "Key 'two_masks' not present"
# "Key 'cooperativaencasa' not present"
# "Key 'tuneinbrasil' not present"
# "Key 'bumblefuckslowjoe' not present"
# "Key 'bidengore' not present"
# "Key 'bigpharmagate' not present"
# "Key 'bigpharmagate' not present"
# "Key 'malignantnarcissism' not present"
# "Key 'bidencoviddeathtracker' not present"
# "Key 'nopardonfortrump' not present"
# "Key 'اقاله_وزير_التعليم' not present"
# "Key 'downtoearth' not present"
# "Key 'ucinursing' not present"
# "Key 'udel' not present"
# "Key 'jakpost' not present"
# "Key 'bidengetsstuffdone' not present"
# "Key 'qiudprojoe' not present"
# "Key 'ugo' not present"
# "Key 'rebuildwithbiden' not present"
# "Key 'umassmemorial' not present"
# "Key 'rudymelts' not present"
# "Key 'políticalocal' not present"
# "Key 'universnews' not present"
# "Key 'thenickmajorshow' not present"
# "Key 'políticalocal' not present"
# "Key 'políticalocal' not present"
# "Key 'welldone' not present"
# "Key 'midnightglobalwatch' not present"
# "Key 'usatodaycongress' not present"
# "Key 'chickenlittles' not present"
# "Key 'hive' not present"
# "Key 'aurehope' not present"
# "Key 'sinalexnohaydialogo' not present"
# "Key 'hefty' not present"
# "Key 'lockdowntrivia' not present"
# "Key 'yangforpresident' not present"
# "Key 'hashtags' not present"
# "Key 'bidenisdonaldselectionnightmare' not present"
# "Key 'evan1c' not present"
# "Key 'trumplied365kdied' not present"
# "Key 'topblu' not present"
# "Key 'preserveamericapac' not present"
# "Key 'vanguardnews' not present"
# "Key 'cautionyespanicno' not present"
# "Key 'bigpharmagate' not present"
# "Key 'sputnikvesesperanza' not present"
# "Key '28abr' not present"
# "Key '1agos' not present"
# "Key '27feb' not present"
# "Key 'itabuna' not present"
# "Key 'freeeducationforall' not present"
# "Key 'cooperativaencasa' not present"
# "Key 'hispantv' not present"
# "Key 'reconciliaciónypaz' not present"
# "Key 'vocesysonidos' not present"
# "Key 'givethankstopresidenttrump' not present"
# "Key 'adarshcredit' not present"
# "Key 'coronavirusarv' not present"
# "Key 'bidentopdebateexcuses' not present"
# "Key 'eua2020' not present"
# "Key '5abr' not present"
# "Key 'goddamn' not present"
# "Key 'vlenxx' not present"
# "Key 'tybiden' not present"
# "Key 'laligamitica' not present"
# "Key 'federalcovidresponse' not present"
# "Key 'redwave22' not present"
# "Key 'bush43' not present"
# "Key 'consumerprotection' not present"
# "Key 'britainvsafrica' not present"
# "Key 'gaslightingbiden' not present"
# "Key 'bidendanastetapmusuhislam' not present"
# "Key 'livenewsindia' not present"
# "Key 'trumpliesamericansdieofcovid' not present"
# "Key 'redwave22' not present"
# "Key 'layaboutcohen' not present"
# "Key 'commonthread' not present"
# "Key 'bigpharmagate' not present"
# "Key 'maskmandateswork' not present"
# "Key 'nocorporatebailouts' not present"
# "Key 'wakeupclt' not present"
# "Key 'hispantv' not present"
# "Key 'ndigital' not present"
# "Key 'budenvaccine' not present"
# "Key '46thiefinchief' not present"
# "Key 'bigpharmagate' not present"
# "Key '22trillion' not present"
# "Key 'bloodontrumphands' not present"
# "Key 'whitmanwalkervoice' not present"
# "Key 'timmurtaugh' not present"
# "Key 'nomojoe' not present"
# "Key 'griftersgottagrift' not present"
# "Key 'willaxnoticias' not present"
# "Key 'bidenisdonaldselectionnightmare' not present"
# "Key 'powerfulally' not present"
# "Key 'bumblesbiden' not present"
# "Key 'petojoe' not present"
# "Key 'laserbeam' not present"
# "Key 'rncsuperspreader' not present"
# "Key 'myedgeprop' not present"
# "Key 'dumprepublicans2020' not present"
# "Key 'legitimatepresident' not present"
# "Key 'inauguraladdress' not present"
# "Key 'pols116' not present"
# "Key 'redwave22' not present"
# "Key 'trumpregimeisvileandevil' not present"
# "Key 'facingthefuture' not present"
# "Key '3whatsnew' not present"
# "Key 'afganistanclusterfuck' not present"
# "Key 'yalesph' not present"
# "Key 'protectnativeamericans' not present"
# "Key 'redwave22' not present"
# "Key 'jakpost' not present"
# "Key 'bigpharmagate' not present"
# "Key 'hutnerbiden' not present"
# "Key 'lordlunatic' not present"
# "Key 'getupdc' not present"
# "Key 'bidencognitivedeficit' not present"
# "Key 'scrotey' not present"
# "Key 'bidenstyranny' not present"
# "Key 'cdcisdumb' not present"
# "Key 'russiannationalconvention' not present"
# "Key 'enprimeraplana' not present"
# "Key '116gov' not present"
# "Key 'mentaltrump' not present"
# "Key 'vpelect' not present"
# "Key 'annotated' not present"
# "Key 'healthpolicyvalentines' not present"
# "Key 'bidengolfedamericacoughed' not present"
# "Key 'maatregelen' not present"
# "Key 'uranus' not present"
# "Key 'trupmlifetimepresidentamerica' not present"
# "Key 'polyglots' not present"
# "Key 'hakkımıhelaletmiyorum' not present"
# "Key '拜登上任' not present"
# "Key 'removethemall' not present"
# "Key 'removerondesantis' not present"
# "Key 'cooperativaencasa' not present"
# "Key '31jul' not present"
# "Key 'bumblesbiden' not present"
# "Key 'ndigital' not present"
# "Key '女性' not present"
# "Key 'blockquote' not present"
# "Key 'youthvote' not present"
# "Key 'bidenliedpeoplewilldie' not present"
# "Key 'baghdadbarbie' not present"
# "Key 'libor' not present"
# "Key 'talktothehand' not present"
# "Key 'usaforbiden' not present"
# "Key 'bumblesbiden' not present"
# "Key 'keephuntersafe' not present"
# "Key 'resistmaskfatigue' not present"
# "Key 'bigpharmagate' not present"
# "Key 'baizuo' not present"
# "Key 'faux45' not present"
# "Key 'redwave22' not present"

# %%
modularity=pd.read_csv('../Project2/biden/biden_networkx.csv')
modularity=modularity.rename(columns={'Id':'user_screen_name'})
nodes1=modularity[modularity['modularity_class']==38]['user_screen_name'].drop_duplicates().tolist()#democrat
nodes2=modularity[modularity['modularity_class']==52]['user_screen_name'].drop_duplicates().tolist()#republics

# %%
ndf0=ndf0[ndf0['hashtags'].notna()]
ndf1=ndf0.rename(columns={'domain':'vec'})

ndf1.dropna(subset=['vec'], inplace=True)

ndf1.reset_index(inplace=True,drop=True)

_data=pd.DataFrame()

for i in tqdm(range(ndf1.shape[0])):
    _df=pd.DataFrame(ndf1['vec'][i]).T
    _data=pd.concat([_data,_df])


_data['user_screen_name']=ndf1['user_screen_name'].tolist()

data=_data

#name1=gf[gf['modularity_class']==0]['user_screen_name']
#name0=gf[gf['modularity_class']==96]['user_screen_name']

#name1 , name2 = 'badbots','goodbots'
#nodes1=pd.read_csv('../Project2/QAnon_data_processed/'+name1+'_QAnon_news_users.csv')['user_screen_name']#pd.read_csv('../Project2/QAnon_data_processed/badbots_QAnon_news_users.csv')['user_screen_name']
#nodes2=pd.read_csv('../Project2/QAnon_data_processed/'+name2+'_QAnon_news_users.csv')['user_screen_name']#pd.read_csv('../Project2/QAnon_data_processed/badhumans_QAnon_news_users.csv')['user_screen_name']


data.loc[data['user_screen_name'].isin(nodes1),'labels']=1

data.loc[data['user_screen_name'].isin(nodes2),'labels']=0

print(data.shape)
# Out:
# 100%|██████████| 130764/130764 [1:47:04<00:00, 20.35it/s]
# (130764, 302)

# %%
data.to_csv('../Project2/biden/data_labeled.csv',index=None)

# %%
data.dropna(subset=['labels'],inplace=True)

# %%
import seaborn as sns
from sklearn.manifold import TSNE
import time
import matplotlib.pyplot as plt
# %matplotlib inline

def export_tSNE(_data,save):
    _array = _data.iloc[:,0:300].to_numpy()
    time_start = time.time()
    tsne = TSNE(n_components=2, verbose=1, random_state=42)
    z = tsne.fit_transform(_array) 
    print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

    df = pd.DataFrame()
    df["y"] = _data.labels
    df["comp-1"] = z[:,0]
    df["comp-2"] = z[:,1]

    sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),data=df).set(title="Hashtag tSNE projection") 
    plt.savefig('../Project2/biden/figs/tSNE_hashtag_'+save+'_.pdf')

# %%
export_tSNE(data,'total_users')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 38295 samples in 0.010s...
# [t-SNE] Computed neighbors for 38295 samples in 42.046s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 38295
# [t-SNE] Computed conditional probabilities for sample 2000 / 38295
# [t-SNE] Computed conditional probabilities for sample 3000 / 38295
# [t-SNE] Computed conditional probabilities for sample 4000 / 38295
# [t-SNE] Computed conditional probabilities for sample 5000 / 38295
# [t-SNE] Computed conditional probabilities for sample 6000 / 38295
# [t-SNE] Computed conditional probabilities for sample 7000 / 38295
# [t-SNE] Computed conditional probabilities for sample 8000 / 38295
# [t-SNE] Computed conditional probabilities for sample 9000 / 38295
# [t-SNE] Computed conditional probabilities for sample 10000 / 38295
# [t-SNE] Computed conditional probabilities for sample 11000 / 38295
# [t-SNE] Computed conditional probabilities for sample 12000 / 38295
# [t-SNE] Computed conditional probabilities for sample 13000 / 38295
# [t-SNE] Computed conditional probabilities for sample 14000 / 38295
# [t-SNE] Computed conditional probabilities for sample 15000 / 38295
# [t-SNE] Computed conditional probabilities for sample 16000 / 38295
# [t-SNE] Computed conditional probabilities for sample 17000 / 38295
# [t-SNE] Computed conditional probabilities for sample 18000 / 38295
# [t-SNE] Computed conditional probabilities for sample 19000 / 38295
# [t-SNE] Computed conditional probabilities for sample 20000 / 38295
# [t-SNE] Computed conditional probabilities for sample 21000 / 38295
# [t-SNE] Computed conditional probabilities for sample 22000 / 38295
# [t-SNE] Computed conditional probabilities for sample 23000 / 38295
# [t-SNE] Computed conditional probabilities for sample 24000 / 38295
# [t-SNE] Computed conditional probabilities for sample 25000 / 38295
# [t-SNE] Computed conditional probabilities for sample 26000 / 38295
# [t-SNE] Computed conditional probabilities for sample 27000 / 38295
# [t-SNE] Computed conditional probabilities for sample 28000 / 38295
# [t-SNE] Computed conditional probabilities for sample 29000 / 38295
# [t-SNE] Computed conditional probabilities for sample 30000 / 38295
# [t-SNE] Computed conditional probabilities for sample 31000 / 38295
# [t-SNE] Computed conditional probabilities for sample 32000 / 38295
# [t-SNE] Computed conditional probabilities for sample 33000 / 38295
# [t-SNE] Computed conditional probabilities for sample 34000 / 38295
# [t-SNE] Computed conditional probabilities for sample 35000 / 38295
# [t-SNE] Computed conditional probabilities for sample 36000 / 38295
# [t-SNE] Computed conditional probabilities for sample 37000 / 38295
# [t-SNE] Computed conditional probabilities for sample 38000 / 38295
# [t-SNE] Computed conditional probabilities for sample 38295 / 38295
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.332291
# [t-SNE] KL divergence after 1000 iterations: 2.219626
# t-SNE done! Time elapsed: 307.2631058692932 seconds

# %%
smaller_sample=500
Nums=[smaller_sample, data.groupby('labels').size().reset_index().loc[0,0], data.groupby('labels').size().reset_index().loc[1,0]]
num = min(Nums)
num_lst=[500,name2,name1]
print(num_lst[Nums.index(num)],' is the smallest!')

data.groupby('labels').size().reset_index().loc[0,0]

data.groupby('labels').size().reset_index().loc[1,0]

ndf_c=data[data.labels==0]

ndf_n=data[data.labels==1]

ndf_c=ndf_c.sample(num)

ndf_n=ndf_n.sample(num)

df=pd.concat([ndf_c,ndf_n])
print('Processing finished!')
array=df.iloc[:,0:300].to_numpy()
# Out:
# 500  is the smallest!
# Processing finished!

# %%
topic
# Out:
# 'biden'

# %%
export_tSNE(df,str(num)+topic)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.000s...
# [t-SNE] Computed neighbors for 1000 samples in 0.043s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.329597
# [t-SNE] KL divergence after 1000 iterations: 0.855119
# t-SNE done! Time elapsed: 8.50478196144104 seconds

# %%
data['labels']=data['labels'].apply('int32')

# %%
def split_data(_df):
    np.random.seed(42)
    msk = np.random.rand(len(_df)) < 0.8
    df_train = _df[msk]
    df_left = _df[~msk]
    np.random.seed(42)
    msk = np.random.rand(len(df_left)) < 0.5
    df_valid = df_left[msk]
    df_test = df_left[~msk]

    print(df.shape)
    print('train:',df_train.shape)
    print('validation',df_valid.shape)
    print('test',df_test.shape)

    # Get the lists of sentences and their labels.
    
    training_data = torch.from_numpy(df_train.iloc[:,0:300].to_numpy())
    validation_data = torch.from_numpy(df_valid.iloc[:,0:300].to_numpy())
    testing_data = torch.from_numpy(df_test.iloc[:,0:300].to_numpy())
    
    labels_train = torch.tensor(df_train['labels'].to_numpy())
    labels_valid = torch.tensor(df_valid['labels'].to_numpy())
    labels_test = torch.tensor(df_test['labels'].to_numpy()) 
    
    
    _train_dataset = TensorDataset(training_data, labels_train)
    _val_dataset =   TensorDataset(validation_data, labels_valid)
    _test_dataset =  TensorDataset(testing_data, labels_test)
    
    
    return _train_dataset, _val_dataset, _test_dataset #df_train, df_valid, df_test, labels_train, labels_valid, labels_test

# %%
train_dataset, val_dataset, test_dataset= split_data(data)
# Out:
# (1000, 302)
# train: (30683, 302)
# validation (3840, 302)
# test (3772, 302)

# %% [markdown]
# # Domain2Vec training

# %%
import wandb
class NetworkMLP(nn.Module):
    def __init__(self):
        super(NetworkMLP, self).__init__() 
        self.fc1 = nn.Linear(300, 150)
            
    def forward(self, X):
        z1 = self.fc1(X)
        return z1 

class JointModel(nn.Module):
    
    def __init__(self,hidden_dim, output_dim, n_layers, bidirectional, dropout):
        super().__init__()
        self.model_net = NetworkMLP()
        self.fc1 = nn.Linear(150*1, 600)
        self.fc2 = nn.Linear(600, output_dim) #original
        self.dropout = nn.Dropout(dropout)


    def forward(self, _net): 
        prediction= self.model_net(_net)
        
        #prediction_twtNews = self.model_twt(x_tNews)
       
        #concat_pred = torch.cat((prediction_RT, prediction_MT), 1)
        output = self.fc1(prediction)
        
        output = self.dropout(output) # add dropout
        output = self.fc2(F.relu(output)) #original
        #output = self.dropout(output)#add dropout
        #output = self.fc3(F.relu(output))
        return output
        
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def binary_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """

    #round predictions to the closest integer
    #rounded_preds = torch.round(torch.sigmoid(preds))
    #rounded_preds = torch.round(preds)
    correct = (preds == y).float() #convert into float for division 
    acc = correct.sum() / len(correct)
    
    from sklearn.metrics import f1_score
    macro_f1 = f1_score(y.to("cpu"), preds.to("cpu"), average='macro')
    #print("macro_f1", macro_f1)

    return acc, macro_f1


def train(model, iterator, optimizer, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    epoch_macro = 0
    model.train()
    for step, batch in enumerate(iterator):    
    #for batch in iterator:
        #print("batch", batch)
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        #   b_input_ids = batch[0].to(device)
        #   b_input_mask = batch[1].to(device)
        #   b_labels = batch[2].to(device)

        optimizer.zero_grad()
        
        net = batch[0].to(device)
        #netMT = batch[1].to(device)
        #feature1=batch[0]
        #print('feature1:',feature1)
        #feature2=batch[1]
        #cosine_score=emb_similarity(feature1, feature2)
        #cosine_score_view=cosine_score.view(cosine_score.size()[0],1)

        #twt = batch[0].to(device)
        #news= batch[1].to(device)

        #print('text.size:',twt.size())
        #print('news.size:',news.size())

        #cosine_similarity=cosine_similarity.to(device)
        label = batch[1].to(device)

        #print("label", label, type(label),label.size()) #torch.Size([32])
        #label = label.unsqueeze(1)
        #print("label", label, type(label),label.size())
        #predictions = model(batch.text).squeeze(1)
        #predictions = model(text)
        predictions = model(net)#,cosine_similarity)

        #cosine_score_view=cosine_score.view(cosine_score.size()[0],1)



        #print('cosine_similarity.size:',cosine_score.size())
        #predictions=torch.cat((predictions,cosine_score_view), dim = 1)
        #print('predictions.size:',predictions.size())
        label = label.type(torch.LongTensor)

        
        loss = criterion(predictions, label)
    
        acc, macro_f1 = binary_accuracy(torch.argmax(predictions, dim = 1), label)

        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        epoch_macro += macro_f1.item()
    return epoch_loss / len(iterator), epoch_acc / len(iterator), epoch_macro / len(iterator)

def evaluate(model, iterator, criterion):
    epoch_loss = 0
    epoch_acc = 0
    epoch_macro = 0
    model.eval()
    
    with torch.no_grad():
    
        #for batch in iterator:
        for step, batch in enumerate(iterator):    
            #des = batch[0].to(device)
            #loc = batch[1].to(device)
            net = batch[0].to(device)
            #netMT = batch[1].to(device)
            #twt = batch[0].to(device)
            #news= batch[1].to(devifce)
            label = batch[1].to(device)
            #predictions = model(batch.text).squeeze(1)
            label = label.type(torch.LongTensor)
            predictions = model(net)
            #loss = criterion(predictions, batch.label)
            loss = criterion(predictions, label)
            #acc = binary_accuracy(predictions, batch.label)
            acc, macro_f1 = binary_accuracy(torch.argmax(predictions, dim = 1), label)
            epoch_loss += loss.item()
            epoch_acc += acc.item()
            epoch_macro += macro_f1.item()
    return epoch_loss / len(iterator), epoch_acc / len(iterator), epoch_macro / len(iterator)


def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

def save_plots(train_losses, val_losses, train_f1, val_f1, train_accs, val_accs,test_accs,test_f1s):
    """Plot

        Plot two figures: loss vs. epoch and accuracy vs. epoch
    """
    n = len(train_losses)
    xs = np.arange(1,n+1,1)
    xs = xs.astype(int)

    # plot train and val losses
    fig, ax = plt.subplots()
    ax.plot(xs, train_losses, '--', linewidth=2, label='train loss')
    ax.plot(xs, val_losses, '-', linewidth=2, label='validation loss')
    #ax.set_xlim(0, 10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend(loc='upper right')
    plt.savefig('../Project2/biden/figs/'+savingname+'_Loss.png')

    # plot train and val f1-score
    #plt.clf()
    fig, ax = plt.subplots()
    ax.plot(xs, train_f1, '--', linewidth=2, label='train')
    ax.plot(xs, val_f1, '-', linewidth=2, label='validation')
    ax.plot(xs, test_f1s, '-', linewidth=2, label='test')
    
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Macro-avg F1")
    ax.legend(loc='lower right')
    plt.savefig('../Project2/biden/figs/'+savingname+'_Macro-avgF1.png')
    
    # plot train and val accuracy
    #plt.clf()
    fig, ax = plt.subplots()
    ax.plot(xs, train_accs, '--', linewidth=2, label='train')
    ax.plot(xs, val_accs, '-', linewidth=2, label='validation')
    ax.plot(xs, test_accs, '-', linewidth=2, label='test')
    #ax.set_xlim(0, 10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Accuracy")
    ax.legend(loc='lower right')
    plt.savefig('../Project2/biden/figs/'+savingname+'_ACC.png')

# %%
name1 , name2 = 'democrats','republicans'
#if (name1 != 'badbots') | (name2 != 'badhumans'):
print('name1:',name1)
print('name2:',name2)
#name1='badbots'
#name2='badhumans'#'badhumans'#'goodbots'
smaller_sample = 500
batch_size = 16
savingname=name1+'VS'+name2+'_Biden_hashtags_'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Training')
print('Device:',device)
which_time = 0
N_EPOCHS = 10
HIDDEN_DIM = 300 
OUTPUT_DIM = 3
N_LAYERS = 2
BIDIRECTIONAL = True
DROPOUT = 0.5
# Out:
# name1: democrats
# name2: republicans
# Training
# Device: cpu

# %%
train_dataloader = DataLoader(
                    train_dataset,  # The training samples.
                    sampler = RandomSampler(train_dataset), # Select batches randomly
                    batch_size = batch_size # Trains with this batch size.
                )
validation_dataloader = DataLoader(
            val_dataset, # The validation samples.
            sampler = SequentialSampler(val_dataset), # Pull out batches sequentially.
            batch_size = batch_size # Evaluate with this batch size.
        )
test_dataloader = DataLoader(
            test_dataset, # The validation samples.
            sampler = SequentialSampler(test_dataset), # Pull out batches sequentially.
            batch_size = batch_size # Evaluate with this batch size.
        ) 

model = JointModel(HIDDEN_DIM, OUTPUT_DIM, N_LAYERS, BIDIRECTIONAL,DROPOUT)
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()
criterion = criterion.to(device) 
wandb.login()
wandb.init(project='Project2_joint',name=savingname)#wandb.init(project='Project2_joint',name=savingname+'_'+str(eachtime))
wandb.config = {
        "epochs": N_EPOCHS,
        "batch_size": batch_size
        }

resume_training = False
if resume_training == True:
    eachtime = 0
    which_time = 6
    path= '../Project2/pt/'+savingname+'_'+str(eachtime)+'/'
    checkpoint = torch.load(path+str(which_time)+'.pt')
    model.load_state_dict(checkpoint)
model = model.to(device)





pt=makefolder('../Project2/pt/'+savingname+'/')#pt=makefolder('../Project2/pt/'+savingname+'_'+str(eachtime)+'/')
pt_best=makefolder('../Project2/pt_best/'+savingname+'/')#pt_best=makefolder('../Project2/pt_best/'+savingname+'_'+str(eachtime)+'/')


best_valid_loss = float('inf')
per_epoch_train_loss = []
per_epoch_val_loss = []
per_epoch_train_f1 = []
per_epoch_val_f1 = []
per_epoch_train_acc = []
per_epoch_val_acc = []

for epoch in range(which_time, N_EPOCHS):
    print(epoch)

    start_time = time.time()

    train_loss, train_acc, train_f1 = train(model, train_dataloader, optimizer, criterion)
    valid_loss, valid_acc, valid_f1 = evaluate(model, validation_dataloader, criterion)

    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    per_epoch_train_loss.append(train_loss)
    per_epoch_val_loss.append(valid_loss)
    per_epoch_train_f1.append(train_f1)
    per_epoch_val_f1.append(valid_f1)
    per_epoch_train_acc.append(train_acc)
    per_epoch_val_acc.append(valid_acc)
    Val_aver_acc=mean(per_epoch_val_acc)
    Val_aver_f1=mean(per_epoch_val_f1)


    if valid_loss <= best_valid_loss:
        best_valid_loss = valid_loss
        print("best model saved in epoch :", epoch+1 )
        torch.save(model.state_dict(), pt_best +str(epoch+1)+'.pt')
    torch.save(model.state_dict(), pt +'/'+str(epoch+1)+'.pt')

    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f} | Train macro-avg-f1: {train_f1*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f} |  Val. macro-avg-f1: {valid_f1*100:.2f}%')
    print(f'\t Aver. ACC: {Val_aver_acc*100:.2f}%')
    wandb.log({'Max Val Acc':max(per_epoch_val_acc),'Average Val. Acc': Val_aver_acc,'Val. accuracy': valid_acc, 'Val. loss': valid_loss,'Val. macro-avg-f1':valid_f1})


Test_Acc = []
Test_f1=[]
for epoch in range(N_EPOCHS):
    model.load_state_dict(torch.load(pt+str(epoch+1)+'.pt')) 
    test_loss, test_acc, test_f1 = evaluate(model, test_dataloader, criterion)

    Test_Acc.append(test_acc)
    Test_f1.append(test_f1)
    Test_aver_acc=mean(Test_Acc)
    Test_test_f1=mean(Test_f1)
    print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f} | Test macro-avg-f1: {test_f1*100:.2f}%')
    print(f'\t Aver. TEST ACC: {Test_aver_acc*100:.2f}%')
    wandb.log({'Max TEST Acc':max(Test_Acc),'Average TEST Acc': Test_aver_acc,'Test accuracy': test_acc, 'Test loss': test_loss,'Test macro-avg-f1':Test_test_f1})
wandb.finish()
save_plots(per_epoch_train_loss, per_epoch_val_loss, per_epoch_train_f1, 
per_epoch_val_f1, per_epoch_train_acc, per_epoch_val_acc,Test_Acc,Test_f1)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: lawrencexu (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/lawrencexu/Project2_joint/runs/3f7qveas" target="_blank">democratsVSrepublicans_Biden_hashtags_</a></strong> to <a href="https://wandb.ai/lawrencexu/Project2_joint" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 0
# best model saved in epoch : 1
# Epoch: 01 | Epoch Time: 0m 7s
# 	Train Loss: 0.502 | Train Acc: 77.29 | Train macro-avg-f1: 75.24%
# 	 Val. Loss: 0.412 |  Val. Acc: 83.65 |  Val. macro-avg-f1: 82.50%
# 	 Aver. ACC: 83.65%
# 1
# best model saved in epoch : 2
# Epoch: 02 | Epoch Time: 0m 7s
# 	Train Loss: 0.408 | Train Acc: 83.60 | Train macro-avg-f1: 82.52%
# 	 Val. Loss: 0.391 |  Val. Acc: 84.97 |  Val. macro-avg-f1: 83.98%
# 	 Aver. ACC: 84.31%
# 2
# best model saved in epoch : 3
# Epoch: 03 | Epoch Time: 0m 7s
# 	Train Loss: 0.398 | Train Acc: 84.43 | Train macro-avg-f1: 83.41%
# 	 Val. Loss: 0.391 |  Val. Acc: 85.31 |  Val. macro-avg-f1: 84.24%
# 	 Aver. ACC: 84.64%
# 3
# best model saved in epoch : 4
# Epoch: 04 | Epoch Time: 0m 7s
# 	Train Loss: 0.381 | Train Acc: 84.85 | Train macro-avg-f1: 83.87%
# 	 Val. Loss: 0.386 |  Val. Acc: 85.26 |  Val. macro-avg-f1: 84.26%
# 	 Aver. ACC: 84.80%
# 4
# best model saved in epoch : 5
# Epoch: 05 | Epoch Time: 0m 6s
# 	Train Loss: 0.372 | Train Acc: 85.20 | Train macro-avg-f1: 84.28%
# 	 Val. Loss: 0.376 |  Val. Acc: 85.55 |  Val. macro-avg-f1: 84.59%
# 	 Aver. ACC: 84.95%
# 5
# best model saved in epoch : 6
# Epoch: 06 | Epoch Time: 0m 7s
# 	Train Loss: 0.365 | Train Acc: 85.58 | Train macro-avg-f1: 84.62%
# 	 Val. Loss: 0.370 |  Val. Acc: 85.49 |  Val. macro-avg-f1: 84.53%
# 	 Aver. ACC: 85.04%
# 6
# Epoch: 07 | Epoch Time: 0m 6s
# 	Train Loss: 0.358 | Train Acc: 86.03 | Train macro-avg-f1: 85.10%
# 	 Val. Loss: 0.371 |  Val. Acc: 85.49 |  Val. macro-avg-f1: 84.50%
# 	 Aver. ACC: 85.10%
# 7
# Epoch: 08 | Epoch Time: 0m 6s
# 	Train Loss: 0.354 | Train Acc: 86.29 | Train macro-avg-f1: 85.33%
# 	 Val. Loss: 0.398 |  Val. Acc: 85.49 |  Val. macro-avg-f1: 84.54%
# 	 Aver. ACC: 85.15%
# 8
# best model saved in epoch : 9
# Epoch: 09 | Epoch Time: 0m 6s
# 	Train Loss: 0.344 | Train Acc: 86.46 | Train macro-avg-f1: 85.56%
# 	 Val. Loss: 0.354 |  Val. Acc: 86.17 |  Val. macro-avg-f1: 85.20%
# 	 Aver. ACC: 85.27%
# 9
# Epoch: 10 | Epoch Time: 0m 6s
# 	Train Loss: 0.343 | Train Acc: 86.59 | Train macro-avg-f1: 85.63%
# 	 Val. Loss: 0.358 |  Val. Acc: 86.33 |  Val. macro-avg-f1: 85.37%
# 	 Aver. ACC: 85.37%
# Test Loss: 0.409 | Test Acc: 84.27 | Test macro-avg-f1: 83.20%
# 	 Aver. TEST ACC: 84.27%
# Test Loss: 0.392 | Test Acc: 84.64 | Test macro-avg-f1: 83.69%
# 	 Aver. TEST ACC: 84.45%
# Test Loss: 0.392 | Test Acc: 85.14 | Test macro-avg-f1: 84.12%
# 	 Aver. TEST ACC: 84.68%
# Test Loss: 0.387 | Test Acc: 85.27 | Test macro-avg-f1: 84.31%
# 	 Aver. TEST ACC: 84.83%
# Test Loss: 0.376 | Test Acc: 85.16 | Test macro-avg-f1: 84.25%
# 	 Aver. TEST ACC: 84.90%
# Test Loss: 0.375 | Test Acc: 85.55 | Test macro-avg-f1: 84.67%
# 	 Aver. TEST ACC: 85.00%
# Test Loss: 0.379 | Test Acc: 85.45 | Test macro-avg-f1: 84.35%
# 	 Aver. TEST ACC: 85.07%
# Test Loss: 0.401 | Test Acc: 85.72 | Test macro-avg-f1: 84.83%
# 	 Aver. TEST ACC: 85.15%
# Test Loss: 0.363 | Test Acc: 86.26 | Test macro-avg-f1: 85.34%
# 	 Aver. TEST ACC: 85.27%
# Test Loss: 0.374 | Test Acc: 85.90 | Test macro-avg-f1: 85.03%
# 	 Aver. TEST ACC: 85.34%
# <br/>Waiting for W&B process to finish, PID 96854... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>Average TEST Acc</td><td>▁▂▄▅▅▆▆▇██</td></tr><tr><td>Average Val. Acc</td><td>▁▄▅▆▆▇▇▇██</td></tr><tr><td>Max TEST Acc</td><td>▁▂▄▅▅▅▅▆██</td></tr><tr><td>Max Val Acc</td><td>▁▄▅▅▆▆▆▆██</td></tr><tr><td>Test accuracy</td><td>▁▂▄▅▄▅▅▆█▇</td></tr><tr><td>Test loss</td><td>█▅▅▅▃▃▃▇▁▃</td></tr><tr><td>Test macro-avg-f1</td><td>▁▂▄▅▅▆▆▇██</td></tr><tr><td>Val. accuracy</td><td>▁▄▅▅▆▆▆▆██</td></tr><tr><td>Val. loss</td><td>█▅▅▅▄▃▃▆▁▁</td></tr><tr><td>Val. macro-avg-f1</td><td>▁▅▅▅▆▆▆▆██</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>Average TEST Acc</td><td>0.85336</td></tr><tr><td>Average Val. Acc</td><td>0.85372</td></tr><tr><td>Max TEST Acc</td><td>0.86264</td></tr><tr><td>Max Val Acc</td><td>0.86328</td></tr><tr><td>Test accuracy</td><td>0.85902</td></tr><tr><td>Test loss</td><td>0.37446</td></tr><tr><td>Test macro-avg-f1</td><td>0.8438</td></tr><tr><td>Val. accuracy</td><td>0.86328</td></tr><tr><td>Val. loss</td><td>0.35795</td></tr><tr><td>Val. macro-avg-f1</td><td>0.85371</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">democratsVSrepublicans_Biden_hashtags_</strong>: <a href="https://wandb.ai/lawrencexu/Project2_joint/runs/3f7qveas" target="_blank">https://wandb.ai/lawrencexu/Project2_joint/runs/3f7qveas</a><br/>
# Find logs at: <code>./wandb/run-20220406_114323-3f7qveas/logs</code><br/>

# %%
re=pd.DataFrame([[Val_aver_acc,Test_aver_acc, Val_aver_f1,Test_test_f1]],columns=['Avg. Val. Acc.','Avg. Test.Acc','Avg. Val. macro-avg-f1','Avg. Test. macro-avg-f1'])
re.to_csv('../Project2/biden/hashtag_classification_results.csv',index=None)

# %%
re
# Out:
#    Avg. Val. Acc.  Avg. Test.Acc  Avg. Val. macro-avg-f1  \
# 0        0.853724       0.853363                0.843691
#
#    Avg. Test. macro-avg-f1
# 0                 0.843803

# %% [markdown]
# # check domain label

# %%
biden_co_occur_df=pd.read_csv('../Project2/biden/biden_co_occur.csv')
nodes1=pd.read_csv('../Project2/domain/data.csv')['Domain'].tolist()
nodes2=pd.read_csv('../Project2/domain/cre.csv')['domain'].tolist()

# %%
biden_co_occur_df.loc[biden_co_occur_df['Id'].isin(nodes1),'flag']='non-credible'

# %%
biden_co_occur_df.loc[biden_co_occur_df['Id'].isin(nodes2),'flag']='credible'

# %%
biden_co_occur_df[biden_co_occur_df['modularity_class']==0].groupby('flag').size()
# Out:
# flag
# credible        208
# non-credible      1
# dtype: int64

# %%
(208+1)/(208-1)
# Out:
# 1.0096618357487923

# %%
import numpy as np
biden_co_occur_df[biden_co_occur_df['modularity_class']==0].isna().sum()
# Out:
# Id                    0
# Label                 0
# timeset             499
# modularity_class      0
# degree                0
# flag                290
# dtype: int64

# %%
biden_co_occur_df[biden_co_occur_df['modularity_class']==1].groupby('flag').size()
# Out:
# flag
# credible        64
# non-credible    46
# dtype: int64

# %%
import numpy as np
biden_co_occur_df[biden_co_occur_df['modularity_class']==1].isna().sum()
# Out:
# 282
# Id                    0
# Label                 0
# timeset             282
# modularity_class      0
# degree                0
# flag                172
# dtype: int64

# %%
(64+46)/(64-46)
# Out:
# 6.111111111111111

# %%
import pandas
dfn1=pd.DataFrame(nodes1)
dfn1.columns=['user_screen_name']
dfn1['label']='pro-QAnon'

dfn2=pd.DataFrame(nodes2)
dfn2.columns=['user_screen_name']
dfn2['label']='anti-QAnon'

dfn=pd.concat([dfn1,dfn2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9ab26ced1f77> in <module>()
# ----> 1 dfn1=pd.DataFrame(nodes1)
#       2 dfn1.columns=['user_screen_name']
#       3 dfn1['label']='pro-QAnon'
#       4
#       5 dfn2=pd.DataFrame(nodes2)
#
# NameError: name 'pd' is not defined

# %%
dfn.to_csv('../Project2/domain/user_label.csv',index=None)

# %%
K=nx.read_gexf('../Project2/domain/domain.gexf')

# %%
kdf=nx.to_pandas_edgelist(K,'source','target')

# %%
nodes1=pd.read_csv('../Project2/domain/data.csv')['Domain'].tolist()
nodes2=pd.read_csv('../Project2/domain/cre.csv')['domain'].tolist()

# %%
kdf.loc[kdf['source'].isin(nodes1),'Flag']='pro-QAnon'

# %%
kdf.loc[kdf['source'].isin(nodes2),'Flag']='anti-QAnon'

# %%
kdf.to_csv('../Project2/domain/edge_list.csv',index=None)

# %%
nx.write_gexf(G,'../Project2/domains.gexf')

# %%
_K=nx.from_pandas_edgelist(_hadf,0,1)

# %%
ndf0['urls'].drop_duplicates().shape
# Out:
# (21,)

# %%
# accuracy goodbots
n1=df2['user_screen_name'].shape[0]
temp = mdf[mdf['class'] == 'center users']
n2=temp[temp['users'].isin(df2['user_screen_name'])].shape[0]
n2/n1
# Out:
# 0.648

# %%
n2
# Out:
# 324

# %%
gf
# Out:
#                                                      urls user_screen_name  \
# 0                                                     NaN  leahbirdjohnso2
# 1                                                     NaN     GolfingJohn_
# 2                                                     NaN        SoHappy33
# 3                                                     NaN    Bigbillshater
# 4                                                     NaN          cinspy6
# ...                                                   ...              ...
# 316830                      https://youtu.be/v2naoIVtEHc'  scampbell123451
# 316831                     'https://youtu.be/JFxYgPlsLbI'  scampbell123451
# 316832                      'https://youtu.be/lAbKoxYVXPI  scampbell123451
# 316833  https://www.bitchute.com/video/HeC0tHZDX7dk/?f...        michae1c1
# 316834   'https://breaking911.com/breaking-ohio-dept-o...        michae1c1
#
#                    tweet_id           created_at  \
# 0       1230285097896677377  2020-02-20 09:16:39
# 1       1230287431636848640  2020-02-20 09:25:55
# 2       1230288536588496896  2020-02-20 09:30:19
# 3       1230289861564882944  2020-02-20 09:35:35
# 4       1230294587605946375  2020-02-20 09:54:22
# ...                     ...                  ...
# 316830  1263121624057995265  2020-05-20 23:57:17
# 316831  1263121624057995265  2020-05-20 23:57:17
# 316832  1263121624057995265  2020-05-20 23:57:17
# 316833  1288640359220772865  2020-07-30 09:59:38
# 316834  1288640359220772865  2020-07-30 09:59:38
#
#                                                      text  \
# 0       rt @golfingjohn_: get the popcorn ready! the c...
# 1       rt @golfingjohn_: get the popcorn ready! the c...
# 2       rt @golfingjohn_: get the popcorn ready! the c...
# 3       rt @1love_america: get the popcorn ready! the ...
# 4       rt @1love_america: get the popcorn ready! the ...
# ...                                                   ...
# 316830  rt @scampbell123451: recent videos: deep state...
# 316831  rt @scampbell123451: recent videos: deep state...
# 316832  rt @scampbell123451: recent videos: deep state...
# 316833  rt @jjppatriot:  fauci and the deep state big ...
# 316834  rt @jjppatriot:  fauci and the deep state big ...
#
#         in_reply_to_status_id_str  in_reply_to_user_id_str  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
# 2                             NaN                      NaN
# 3                             NaN                      NaN
# 4                             NaN                      NaN
# ...                           ...                      ...
# 316830                        NaN                      NaN
# 316831                        NaN                      NaN
# 316832                        NaN                      NaN
# 316833                        NaN                      NaN
# 316834                        NaN                      NaN
#
#         in_reply_to_screen_name  latitude  longitude  ...  lang  \
# 0                           NaN       NaN        NaN  ...    en
# 1                           NaN       NaN        NaN  ...    en
# 2                           NaN       NaN        NaN  ...    en
# 3                           NaN       NaN        NaN  ...    en
# 4                           NaN       NaN        NaN  ...    en
# ...                         ...       ...        ...  ...   ...
# 316830                      NaN       NaN        NaN  ...    en
# 316831                      NaN       NaN        NaN  ...    en
# 316832                      NaN       NaN        NaN  ...    en
# 316833                      NaN       NaN        NaN  ...    en
# 316834                      NaN       NaN        NaN  ...    en
#
#         resolved_domain                                       resolved_url  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 316830      youtube.com  https://www.youtube.com/watch?v=v2naoIVtEHc%27...
# 316831      youtube.com  https://www.youtube.com/watch?v=v2naoIVtEHc%27...
# 316832      youtube.com  https://www.youtube.com/watch?v=v2naoIVtEHc%27...
# 316833     bitchute.com  https://www.bitchute.com/video/HeC0tHZDX7dk/?f...
# 316834     bitchute.com  https://www.bitchute.com/video/HeC0tHZDX7dk/?f...
#
#                                                      news cap.english  \
# 0                                                     NaN         NaN
# 1                                                     NaN         NaN
# 2                                                     NaN    0.787400
# 3                                                     NaN         NaN
# 4                                                     NaN         NaN
# ...                                                   ...         ...
# 316830                                                NaN    0.779582
# 316831                                                NaN    0.779582
# 316832                                                NaN    0.779582
# 316833  Reason\n\nSelect reason Abhorrent Violence Ani...         NaN
# 316834  Reason\n\nSelect reason Abhorrent Violence Ani...         NaN
#
#        display_scores.english.overall  modularity_class indegree outdegree  \
# 0                                 NaN                 0        0         3
# 1                                 NaN                 0       48         7
# 2                                 1.7                 0        0         2
# 3                                 NaN                 0        0         5
# 4                                 NaN                 0        0         2
# ...                               ...               ...      ...       ...
# 316830                            1.6                 0        9         2
# 316831                            1.6                 0        9         2
# 316832                            1.6                 0        9         2
# 316833                            NaN                 0        0         2
# 316834                            NaN                 0        0         2
#
#         degree
# 0            3
# 1           55
# 2            2
# 3            5
# 4            2
# ...        ...
# 316830      11
# 316831      11
# 316832      11
# 316833       2
# 316834       2
#
# [316835 rows x 40 columns]

# %%
import speedtest
import datetime
import csv
import time
import logging
try:
    s = speedtest.Speedtest()

    with open('test.csv', mode='w') as speedcsv:
        csv_writer = csv.DictWriter(speedcsv, fieldnames=['time', 'downspeed', 'upspeed'])
        csv_writer.writeheader()
        while True:
            time_now = datetime.datetime.now().strftime("%H:%M:%S")
            downspeed = round((round(s.download()) / 1048576), 2)
            upspeed = round((round(s.upload()) / 1048576), 2)
            csv_writer.writerow({
                'time': time_now,
                'downspeed': downspeed,
                "upspeed": upspeed
            })
            # 60 seconds sleep
            time.sleep(60)
except Exception as e:
            logging.error('Exception raised.')
            logging.error(e)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-173-a0d5937541b4> in <module>()
#      20             })
#      21             # 60 seconds sleep
# ---> 22             time.sleep(60)
#      23 except Exception as e:
#      24             logging.error('Exception raised.')
#
# KeyboardInterrupt:

# %%
text='http://google&p'

'google' & 'amp' in text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-8a08a399ba52> in <module>()
#       1 text='http://google&p'
#       2
# ----> 3 'google' & 'amp' in text
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
